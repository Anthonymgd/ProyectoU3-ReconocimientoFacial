# %% [markdown]
# <center><h1>Inteligencia Artificial</header1></center>

# %% [markdown]
# Presentado por: <br>
# - Anthony Mauricio Goyes Díaz  <br>
# - Bryan Alfredo Solórzano Montero <br>
#
# Fecha: 13/08/2022

# %% [markdown]
# # Importación de librerias necesarias

# %%
'''Se importa la libreria os'''
import os
'''Se importa la libreria cv2'''
import cv2
'''Se importa la libreria numpy'''
import numpy as np
'''Se importa la libreria PIL'''
from PIL import Image
'''Se importa la libreria pylot'''
import matplotlib.pyplot as plt
'''Se importa la libreria model_selection'''
from sklearn.model_selection import train_test_split
'''Se establece el nivel de codificación'''
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
'''Se importa la libreria tf utils''' 
from tensorflow.keras.utils import to_categorical
'''Se importa la libreria tf'''
from tensorflow.keras import layers, models
'''Se importa la libreria tf'''
import tensorflow as tf
'''Se importa la libreria metrics'''
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
'''Se importa la libreria tf keras'''
from tensorflow import keras
'''Se importa la libreria keras.models'''
from keras.models import Sequential
'''Se importa la libreria kesa.layers'''
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
'''Se importa la libreria tf.keras.layers'''
from tensorflow.keras.layers import BatchNormalization
'''Se importa la libreria tf.keras.callbacks'''
from tensorflow.python.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Cargar y exploración del Dataset

# %%
'''Se establece la ruta general de espacio de trabajo'''
os.chdir('C:/Users/Personal/IA/ProyectoU3/')

# %%
'''Se genera una variable con un número para que actúe como aleatorio'''
semilla_aleatoria = 49
'''Se establece la ruta de las imágenes'''
ruta_imagenes = "./Estudiantes_datos_fondoEliminadoNLM"
'''Se muestra los directorios (clases) del dataset'''
nombre_clases = os.listdir(ruta_imagenes)
'''Se ordenan en orden alfabético (AZ - az)'''
nombre_clases.sort()
'''Se muestran las clases del dataset'''
print('Las clases del dataset son: \n' + str(nombre_clases))
# Out:
# Las clases del dataset son:
# ['Anthony Goyes', 'Ariel Chabla', 'Bryan Solorzano', 'Davila Raymond', 'Fernando Masache', 'Genesis Heredia', 'Hector Cedenio', 'Jhon Zambrano', 'Joan Cevallos', 'Johana Salazar', 'Jordan Espinosa', 'Jorge Borrero', 'Jose Ruiz', 'Kevin Paute', 'Leonardo Borja', 'LucioCarlos', 'Lucy Mosquera', 'Luis Olalla', 'Maria Jose Parraga', 'Melany Lopez', 'Mercy Arrobo', 'Nataly Acosta', 'Selena Enriquez', 'Selena Rivas', 'Solano Wilmer', 'Steven Barragan']

# %%
def cargar_imagenes_etiquetas(clases):
    """Permite registrar las imagenes y categorías en un arreglo, aplicando transformaciones de color con opencv.

    Argumentos:
        clases (List): Una lista o arreglo de cadenas de texto que identifican a las clases del problema.

    Returna:
        Dos arreglos, uno para contener a las imagenes y otro para sus etiquetas
    """
    '''Arreglo vacío que almacenará las fotos'''
    imagenes = []
    '''Arreglo vacío que almacenará las etiquetas'''
    etiquetas = []
    '''Se crea un bloque que recorrerá cada clase'''
    for iterador, clase in enumerate(clases):
        '''Se crea un bloque que recorrerá cada elemento por clase'''
        for image_name in os.listdir(ruta_imagenes+"/"+clase):
            '''Se almacena la imagen leída mediante opencv'''
            imagen = cv2.imread(ruta_imagenes+"/"+clase+"/"+image_name)
            '''Se establece el formato de color en RGB'''
            imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
            img_array = Image.fromarray(imagen, 'RGB')
            '''Se añade a la lista de imágenes la imagen'''
            imagenes.append(np.array(imagen))
            '''Se añade el número del ciclo como mecanismo de label-encoder para las etiquetas'''
            etiquetas.append(iterador)
    return imagenes, etiquetas

'''Se llama la función creada y se almacenan los resultados en dos variables (para fotos y etiquetas)'''
imagenes, etiquetas = cargar_imagenes_etiquetas(nombre_clases)
'''Se imprime el número de imagenes cargadas'''
print("No. de imagenes y categorías cargadas = ",len(imagenes),"\nNo. de etiquetas cargadas = ",len(etiquetas))
print(type(imagenes),type(etiquetas))
# Out:
# No. de imagenes y categorías cargadas =  2445
# No. de etiquetas cargadas =  2445
# <class 'list'> <class 'list'>

# %%
'''Se convierte la lista en un arreglo de imágenes'''
imagenes = np.array(imagenes)
'''Se convierte la lista en un arreglo de etiquetas'''
etiquetas = np.array(etiquetas)

'''Se imprime las dimensiones de la imagen y etiquetas'''
print("Dimensión de la imagen = ",imagenes.shape,"\nDimensión de la etiqueta = ",etiquetas.shape)
print(type(imagenes),type(etiquetas))
# Out:
# Dimensión de la imagen =  (2445, 100, 100, 3)
# Dimensión de la etiqueta =  (2445,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
def mostrar_imagenes_aleatorias(imagenes, etiquetas):
    """Permite imprimir randómicamente una imagen por cada clase con título y sus dimensiones.

    Argumentos:
        ruta_imagenes (str): Una cadena de texto que identifica el.

    Returna:
        No retorna nada
    """
    '''Se establece las dimensiones de contendor del gráfico'''  
    plt.figure(1 , figsize = (15 , 20))
    '''Se establece una variable contador'''
    n = 0 
    '''Se genera un ciclo que iterará cada imagen'''
    for iterador in range(15):
        '''Se aumentan en una uniadad del contador'''
        n += 1 
        '''Se genera un número aleatorio'''
        numero_aleatario = np.random.randint(0 , imagenes.shape , 1)
        '''Se establece la distribución del contenedor gráfico'''
        plt.subplot(5 , 3 , n)
        '''Se ajusta la separación de altura y anchura'''
        plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
        '''Se muestra una imagen de forma aletoria'''
        plt.imshow(imagenes[numero_aleatario[0]])
        '''Se genera el título de cada imagen'''
        plt.title('No. Clase : {}'.format(etiquetas[numero_aleatario[0]]))
        '''Se deshabilita la visualización de los ejes'''
        plt.axis('off')
    '''Se muestra el contenedor gráfico'''
    plt.show()
'''Se llama al método generado anteriormente'''
mostrar_imagenes_aleatorias(imagenes, etiquetas)

# %% [markdown]
# ## Preparando la data para la generación del modelo CNN

# %%
'''Se modifica el tipo de dato para imágenes y etiquetas'''
imagenes = imagenes.astype(np.float32)
etiquetas = etiquetas.astype(np.int32)
imagenes =  imagenes/255
print("Dimensión de las imágenes después de normalizar= ",imagenes.shape)
print("Dimensión de las etiquetas= ",etiquetas.shape)
# Out:
# Dimensión de las imágenes después de normalizar=  (2445, 100, 100, 3)
# Dimensión de las etiquetas=  (2445,)

# %%
'''Barajando los datos'''
'''Primer paso'''
numero_aleatorio = np.arange(imagenes.shape[0])
print("Valores antes de barajear = ",numero_aleatorio)

'''Barajando todos los valores igualmente espaciados en la lista almacenada aleatoriamente'''
np.random.seed(semilla_aleatoria)
np.random.shuffle(numero_aleatorio)
print("\nValores después de barajear = ",numero_aleatorio)
# Out:
# Valores antes de barajear =  [   0    1    2 ... 2442 2443 2444]
#
# Valores después de barajear =  [   4 1581 1474 ...  424 1709  426]

# %%
'''Segundo paso'''
'''Barajendo las imágenes y los datos de las etiquetas correspondientes en las dos listas'''
imagenes = imagenes[numero_aleatorio]
etiquetas = etiquetas[numero_aleatorio]

print("Dimensiones de la imagen después de barajear = ",imagenes.shape,"\nDimensiones de " +
    "las etiquetas después de barajear = ",etiquetas.shape)
# Out:
# Dimensiones de la imagen después de barajear =  (2445, 100, 100, 3)
# Dimensiones de las etiquetas después de barajear =  (2445,)

# %% [markdown]
# ## Se divide el dataset en entrenamiento y prueba

# %%
'''Se divide el dataset en entrenamiento y prueba (30%)'''
train_fotos, test_fotos, train_etiquetas, test_etiquetas = train_test_split(imagenes, etiquetas,
                                                                 test_size = 0.3, random_state = semilla_aleatoria)

# %%
'''Se imprime las dimensiones para cada división realizada'''
print("Dimensión train_fotos = ",train_fotos.shape)
print("Dimensión train_etiquetas= ",train_etiquetas.shape)
print("\nDimensión test_fotos = ",test_fotos.shape)
print("Dimensión test_etiquetas = ",test_etiquetas.shape)
# Out:
# Dimensión train_fotos =  (1711, 100, 100, 3)
# Dimensión train_etiquetas=  (1711,)
#
# Dimensión test_fotos =  (734, 100, 100, 3)
# Dimensión test_etiquetas =  (734,)

# %%
'''Se llama al método que imprime imágenes aleatorias'''
mostrar_imagenes_aleatorias(train_fotos, train_etiquetas)

# %% [markdown]
# # Arquitectura de AlexNet

# %% [markdown]
# ## Cuarto experimento

# %%
#Código que responde a la descripción anterior
#Instanciamos el modelo
modelo=Sequential()
modelo.add(Conv2D(filters=96,kernel_size=(10,10),strides=(4,4),padding="valid",activation="relu",input_shape=(100,100,3)))
# Primera capa max pool 
modelo.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
#Normalizacion batch
modelo.add(BatchNormalization())
#2 Segunda capa convolucional
modelo.add(Conv2D(filters=256,kernel_size=(5,5),strides=(1,1),padding="valid",activation="relu"))
#2 Segunda  capa max pool 
modelo.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))
#Normalizacion batch
modelo.add(BatchNormalization())
# Tercera capa convolucional
modelo.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))
#Normalizacion batch
modelo.add(BatchNormalization())
#Redimensionar el modelo AlexNet
modelo.add(Flatten())
#Primera capa de densidad
modelo.add(Dense(4096,input_shape=(100,100,3),activation="relu"))
#regularizar neuronas
modelo.add(Dropout(0.4))
#normalizacion por lote
modelo.add(BatchNormalization())
#Segunda capa de densidad
modelo.add(Dense(4096,activation="relu"))
#Regularizar neuronas
modelo.add(Dropout(0.4))
#normalizacion por lotes
modelo.add(BatchNormalization())
#Tercera capa de densidad
modelo.add(Dense(1000,activation="relu"))
#regularizar neuronas
modelo.add(Dropout(0.4))
#normalizacion por lote
modelo.add(BatchNormalization())
#capa de salida
modelo.add(Dense(len(nombre_clases),activation="softmax"))
#resumen
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 23, 23, 96)        9696
#
#  max_pooling2d_2 (MaxPooling  (None, 11, 11, 96)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 11, 11, 96)       384
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 256)         614656
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 384)         885120
#
#  batch_normalization_2 (Batc  (None, 1, 1, 384)        1536
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 384)               0
#
#  dense_3 (Dense)             (None, 4096)              1576960
#
#  dropout_6 (Dropout)         (None, 4096)              0
#
#  batch_normalization_3 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_7 (Dropout)         (None, 4096)              0
#
#  batch_normalization_4 (Batc  (None, 4096)             16384
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1000)              4097000
#
#  dropout_8 (Dropout)         (None, 1000)              0
#
#  batch_normalization_5 (Batc  (None, 1000)             4000
#  hNormalization)
#
#  dense_6 (Dense)             (None, 26)                26026
#
# =================================================================
# Total params: 24,030,482
# Trainable params: 24,010,626
# Non-trainable params: 19,856
# _________________________________________________________________

# %%
'''Se compila el modelo'''
modelo.compile(loss='sparse_categorical_crossentropy',
              optimizer="Adam",
              metrics=['accuracy'])

# %%
from  tensorflow.keras.callbacks import TensorBoard

# %%
tensorboardDenso = TensorBoard(log_dir='logs/cnn')

# %%
'''Se entra al modelo'''
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=200, verbose=1)
history = modelo.fit(train_fotos, train_etiquetas, validation_data=(test_fotos, test_etiquetas),
           batch_size=32, epochs=100, callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 11s 459ms/step - loss: 3.7066 - accuracy: 0.1307 - val_loss: 3.2517 - val_accuracy: 0.0976
# Epoch 2/100
# 18/18 [==============================] - 8s 437ms/step - loss: 2.8205 - accuracy: 0.2195 - val_loss: 5.7836 - val_accuracy: 0.0407
# Epoch 3/100
# 18/18 [==============================] - 8s 439ms/step - loss: 2.2568 - accuracy: 0.3240 - val_loss: 6.1010 - val_accuracy: 0.0691
# Epoch 4/100
# 18/18 [==============================] - 7s 415ms/step - loss: 2.0404 - accuracy: 0.4077 - val_loss: 5.8812 - val_accuracy: 0.0610
# Epoch 5/100
# 18/18 [==============================] - 7s 411ms/step - loss: 1.7427 - accuracy: 0.4129 - val_loss: 5.5963 - val_accuracy: 0.0366
# Epoch 6/100
# 18/18 [==============================] - 7s 411ms/step - loss: 1.4137 - accuracy: 0.5505 - val_loss: 6.0826 - val_accuracy: 0.0610
# Epoch 7/100
# 18/18 [==============================] - 7s 417ms/step - loss: 1.2888 - accuracy: 0.5889 - val_loss: 5.7271 - val_accuracy: 0.0935
# Epoch 8/100
# 18/18 [==============================] - 8s 424ms/step - loss: 1.0769 - accuracy: 0.6307 - val_loss: 5.2012 - val_accuracy: 0.0691
# Epoch 9/100
# 18/18 [==============================] - 8s 451ms/step - loss: 0.9019 - accuracy: 0.7160 - val_loss: 6.0480 - val_accuracy: 0.0610
# Epoch 10/100
# 18/18 [==============================] - 8s 451ms/step - loss: 0.7914 - accuracy: 0.7596 - val_loss: 5.1160 - val_accuracy: 0.1057
# Epoch 11/100
# 18/18 [==============================] - 9s 509ms/step - loss: 0.7328 - accuracy: 0.7683 - val_loss: 5.6709 - val_accuracy: 0.0894
# Epoch 12/100
# 18/18 [==============================] - 9s 471ms/step - loss: 0.6127 - accuracy: 0.8014 - val_loss: 5.8843 - val_accuracy: 0.1301
# Epoch 13/100
# 18/18 [==============================] - 8s 462ms/step - loss: 0.5237 - accuracy: 0.8223 - val_loss: 5.8868 - val_accuracy: 0.1301
# Epoch 14/100
# 18/18 [==============================] - 8s 449ms/step - loss: 0.4672 - accuracy: 0.8449 - val_loss: 6.7144 - val_accuracy: 0.0854
# Epoch 15/100
# 18/18 [==============================] - 8s 451ms/step - loss: 0.4610 - accuracy: 0.8537 - val_loss: 5.5129 - val_accuracy: 0.2195
# Epoch 16/100
# 18/18 [==============================] - 8s 450ms/step - loss: 0.4660 - accuracy: 0.8397 - val_loss: 5.8272 - val_accuracy: 0.1951
# Epoch 17/100
# 18/18 [==============================] - 8s 451ms/step - loss: 0.3061 - accuracy: 0.9024 - val_loss: 5.3321 - val_accuracy: 0.2236
# Epoch 18/100
# 18/18 [==============================] - 8s 444ms/step - loss: 0.2786 - accuracy: 0.9181 - val_loss: 5.9571 - val_accuracy: 0.2317
# Epoch 19/100
# 18/18 [==============================] - 8s 455ms/step - loss: 0.2397 - accuracy: 0.9268 - val_loss: 4.0945 - val_accuracy: 0.2886
# Epoch 20/100
# 18/18 [==============================] - 8s 450ms/step - loss: 0.2030 - accuracy: 0.9233 - val_loss: 3.8578 - val_accuracy: 0.3537
# Epoch 21/100
# 18/18 [==============================] - 8s 445ms/step - loss: 0.1988 - accuracy: 0.9338 - val_loss: 3.6761 - val_accuracy: 0.3740
# Epoch 22/100
# 18/18 [==============================] - 8s 443ms/step - loss: 0.1964 - accuracy: 0.9355 - val_loss: 3.6488 - val_accuracy: 0.4146
# Epoch 23/100
# 18/18 [==============================] - 7s 416ms/step - loss: 0.2253 - accuracy: 0.9303 - val_loss: 3.0358 - val_accuracy: 0.4431
# Epoch 24/100
# 18/18 [==============================] - 8s 419ms/step - loss: 0.1952 - accuracy: 0.9321 - val_loss: 3.9987 - val_accuracy: 0.3577
# Epoch 25/100
# 18/18 [==============================] - 8s 423ms/step - loss: 0.2220 - accuracy: 0.9390 - val_loss: 3.2126 - val_accuracy: 0.4553
# Epoch 26/100
# 18/18 [==============================] - 7s 408ms/step - loss: 0.1641 - accuracy: 0.9530 - val_loss: 2.5912 - val_accuracy: 0.5650
# Epoch 27/100
# 18/18 [==============================] - 7s 411ms/step - loss: 0.2446 - accuracy: 0.9303 - val_loss: 2.4986 - val_accuracy: 0.5366
# Epoch 28/100
# 18/18 [==============================] - 8s 432ms/step - loss: 0.2725 - accuracy: 0.9077 - val_loss: 3.1477 - val_accuracy: 0.5081
# Epoch 29/100
# 18/18 [==============================] - 8s 433ms/step - loss: 0.1222 - accuracy: 0.9582 - val_loss: 2.9979 - val_accuracy: 0.4756
# Epoch 30/100
# 18/18 [==============================] - 7s 414ms/step - loss: 0.1026 - accuracy: 0.9617 - val_loss: 3.1786 - val_accuracy: 0.4553
# Epoch 31/100
# 18/18 [==============================] - 8s 454ms/step - loss: 0.0943 - accuracy: 0.9686 - val_loss: 2.5343 - val_accuracy: 0.5325
# Epoch 32/100
# 18/18 [==============================] - 9s 476ms/step - loss: 0.1093 - accuracy: 0.9686 - val_loss: 2.1136 - val_accuracy: 0.5894
# Epoch 33/100
# 18/18 [==============================] - 9s 495ms/step - loss: 0.1241 - accuracy: 0.9512 - val_loss: 4.2571 - val_accuracy: 0.4756
# Epoch 34/100
# 18/18 [==============================] - 8s 473ms/step - loss: 0.1591 - accuracy: 0.9390 - val_loss: 3.2056 - val_accuracy: 0.5081
# Epoch 35/100
# 18/18 [==============================] - 8s 421ms/step - loss: 0.1722 - accuracy: 0.9425 - val_loss: 3.3401 - val_accuracy: 0.5244
# Epoch 36/100
# 18/18 [==============================] - 8s 433ms/step - loss: 0.2116 - accuracy: 0.9303 - val_loss: 3.1107 - val_accuracy: 0.5732
# Epoch 37/100
# 18/18 [==============================] - 8s 434ms/step - loss: 0.1508 - accuracy: 0.9495 - val_loss: 4.5665 - val_accuracy: 0.4472
# Epoch 38/100
# 18/18 [==============================] - 7s 416ms/step - loss: 0.1590 - accuracy: 0.9425 - val_loss: 3.8953 - val_accuracy: 0.5203
# Epoch 39/100
# 18/18 [==============================] - 8s 440ms/step - loss: 0.1421 - accuracy: 0.9495 - val_loss: 2.2073 - val_accuracy: 0.6341
# Epoch 40/100
# 18/18 [==============================] - 8s 417ms/step - loss: 0.1509 - accuracy: 0.9599 - val_loss: 1.9576 - val_accuracy: 0.6545
# Epoch 41/100
# 18/18 [==============================] - 8s 424ms/step - loss: 0.0811 - accuracy: 0.9686 - val_loss: 2.2143 - val_accuracy: 0.6463
# Epoch 42/100
# 18/18 [==============================] - 7s 413ms/step - loss: 0.1099 - accuracy: 0.9652 - val_loss: 2.3180 - val_accuracy: 0.6382
# Epoch 43/100
# 18/18 [==============================] - 7s 408ms/step - loss: 0.0864 - accuracy: 0.9704 - val_loss: 2.5158 - val_accuracy: 0.6057
# Epoch 44/100
# 18/18 [==============================] - 7s 412ms/step - loss: 0.0675 - accuracy: 0.9808 - val_loss: 2.5722 - val_accuracy: 0.5976
# Epoch 45/100
# 18/18 [==============================] - 8s 427ms/step - loss: 0.0883 - accuracy: 0.9791 - val_loss: 2.2166 - val_accuracy: 0.6382
# Epoch 46/100
# 18/18 [==============================] - 7s 411ms/step - loss: 0.0488 - accuracy: 0.9843 - val_loss: 3.4296 - val_accuracy: 0.5122
# Epoch 47/100
# 18/18 [==============================] - 7s 414ms/step - loss: 0.0495 - accuracy: 0.9808 - val_loss: 1.8395 - val_accuracy: 0.6667
# Epoch 48/100
# 18/18 [==============================] - 8s 422ms/step - loss: 0.0401 - accuracy: 0.9861 - val_loss: 1.8695 - val_accuracy: 0.6789
# Epoch 49/100
# 18/18 [==============================] - 8s 428ms/step - loss: 0.0419 - accuracy: 0.9861 - val_loss: 1.8046 - val_accuracy: 0.7073
# Epoch 50/100
# 18/18 [==============================] - 7s 417ms/step - loss: 0.0450 - accuracy: 0.9843 - val_loss: 2.0131 - val_accuracy: 0.6423
# Epoch 51/100
# 18/18 [==============================] - 7s 418ms/step - loss: 0.0403 - accuracy: 0.9843 - val_loss: 2.2808 - val_accuracy: 0.6382
# Epoch 52/100
# 18/18 [==============================] - 8s 422ms/step - loss: 0.0211 - accuracy: 0.9913 - val_loss: 1.7116 - val_accuracy: 0.6870
# Epoch 53/100
# 18/18 [==============================] - 8s 421ms/step - loss: 0.0219 - accuracy: 0.9930 - val_loss: 1.4429 - val_accuracy: 0.7480
# Epoch 54/100
# 18/18 [==============================] - 8s 424ms/step - loss: 0.0130 - accuracy: 0.9948 - val_loss: 1.6861 - val_accuracy: 0.6870
# Epoch 55/100
# 18/18 [==============================] - 8s 419ms/step - loss: 0.0127 - accuracy: 0.9983 - val_loss: 1.5896 - val_accuracy: 0.7398
# Epoch 56/100
# 18/18 [==============================] - 8s 420ms/step - loss: 0.0096 - accuracy: 0.9983 - val_loss: 1.8143 - val_accuracy: 0.7114
# Epoch 57/100
# 18/18 [==============================] - 8s 429ms/step - loss: 0.0217 - accuracy: 0.9983 - val_loss: 1.7367 - val_accuracy: 0.7033
# Epoch 58/100
# 18/18 [==============================] - 7s 408ms/step - loss: 0.0297 - accuracy: 0.9930 - val_loss: 1.7980 - val_accuracy: 0.7114
# Epoch 59/100
# 18/18 [==============================] - 8s 446ms/step - loss: 0.0339 - accuracy: 0.9895 - val_loss: 2.0812 - val_accuracy: 0.6545
# Epoch 60/100
# 18/18 [==============================] - 8s 441ms/step - loss: 0.0368 - accuracy: 0.9895 - val_loss: 2.8424 - val_accuracy: 0.5041
# Epoch 61/100
# 18/18 [==============================] - 8s 438ms/step - loss: 0.0326 - accuracy: 0.9895 - val_loss: 1.9812 - val_accuracy: 0.6667
# Epoch 62/100
# 18/18 [==============================] - 8s 460ms/step - loss: 0.0353 - accuracy: 0.9895 - val_loss: 2.5733 - val_accuracy: 0.6016
# Epoch 63/100
# 18/18 [==============================] - 7s 411ms/step - loss: 0.0898 - accuracy: 0.9774 - val_loss: 2.3404 - val_accuracy: 0.6382
# Epoch 64/100
# 18/18 [==============================] - 8s 425ms/step - loss: 0.0560 - accuracy: 0.9843 - val_loss: 2.8698 - val_accuracy: 0.5610
# Epoch 65/100
# 18/18 [==============================] - 7s 414ms/step - loss: 0.1235 - accuracy: 0.9617 - val_loss: 2.2692 - val_accuracy: 0.6545
# Epoch 66/100
# 18/18 [==============================] - 7s 416ms/step - loss: 0.1324 - accuracy: 0.9669 - val_loss: 2.8617 - val_accuracy: 0.5691
# Epoch 67/100
# 18/18 [==============================] - 7s 411ms/step - loss: 0.0872 - accuracy: 0.9704 - val_loss: 3.1795 - val_accuracy: 0.5366
# Epoch 68/100
# 18/18 [==============================] - 7s 412ms/step - loss: 0.1219 - accuracy: 0.9669 - val_loss: 3.4137 - val_accuracy: 0.5528
# Epoch 69/100
# 18/18 [==============================] - 7s 410ms/step - loss: 0.1571 - accuracy: 0.9460 - val_loss: 3.0664 - val_accuracy: 0.5528
# Epoch 70/100
# 18/18 [==============================] - 7s 409ms/step - loss: 0.1325 - accuracy: 0.9564 - val_loss: 2.9879 - val_accuracy: 0.5528
# Epoch 71/100
# 18/18 [==============================] - 8s 425ms/step - loss: 0.2071 - accuracy: 0.9286 - val_loss: 4.4963 - val_accuracy: 0.4553
# Epoch 72/100
# 18/18 [==============================] - 8s 425ms/step - loss: 0.1514 - accuracy: 0.9564 - val_loss: 4.2534 - val_accuracy: 0.4431
# Epoch 73/100
# 18/18 [==============================] - 7s 409ms/step - loss: 0.1331 - accuracy: 0.9634 - val_loss: 9.1475 - val_accuracy: 0.3293
# Epoch 74/100
# 18/18 [==============================] - 8s 418ms/step - loss: 0.0888 - accuracy: 0.9704 - val_loss: 3.0108 - val_accuracy: 0.5854
# Epoch 75/100
# 18/18 [==============================] - 7s 416ms/step - loss: 0.0921 - accuracy: 0.9739 - val_loss: 3.8126 - val_accuracy: 0.5163
# Epoch 76/100
# 18/18 [==============================] - 7s 417ms/step - loss: 0.1131 - accuracy: 0.9652 - val_loss: 2.9158 - val_accuracy: 0.5691
# Epoch 77/100
# 18/18 [==============================] - 8s 422ms/step - loss: 0.0586 - accuracy: 0.9843 - val_loss: 2.3505 - val_accuracy: 0.6260
# Epoch 78/100
# 18/18 [==============================] - 8s 423ms/step - loss: 0.0605 - accuracy: 0.9791 - val_loss: 2.5620 - val_accuracy: 0.6341
# Epoch 79/100
# 18/18 [==============================] - 8s 429ms/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 2.3202 - val_accuracy: 0.6504
# Epoch 80/100
# 18/18 [==============================] - 8s 444ms/step - loss: 0.0631 - accuracy: 0.9808 - val_loss: 2.1591 - val_accuracy: 0.6829
# Epoch 81/100
# 18/18 [==============================] - 8s 435ms/step - loss: 0.0731 - accuracy: 0.9721 - val_loss: 2.0791 - val_accuracy: 0.7154
# Epoch 82/100
# 18/18 [==============================] - 8s 435ms/step - loss: 0.0359 - accuracy: 0.9895 - val_loss: 1.9921 - val_accuracy: 0.7033
# Epoch 83/100
# 18/18 [==============================] - 8s 422ms/step - loss: 0.0536 - accuracy: 0.9808 - val_loss: 5.3237 - val_accuracy: 0.4390
# Epoch 84/100
# 18/18 [==============================] - 7s 415ms/step - loss: 0.0580 - accuracy: 0.9808 - val_loss: 2.6884 - val_accuracy: 0.5976
# Epoch 85/100
# 18/18 [==============================] - 7s 418ms/step - loss: 0.0324 - accuracy: 0.9861 - val_loss: 2.8338 - val_accuracy: 0.6260
# Epoch 86/100
# 18/18 [==============================] - 7s 417ms/step - loss: 0.0412 - accuracy: 0.9878 - val_loss: 2.5917 - val_accuracy: 0.6545
# Epoch 87/100
# 18/18 [==============================] - 8s 419ms/step - loss: 0.0419 - accuracy: 0.9861 - val_loss: 2.4383 - val_accuracy: 0.6423
# Epoch 88/100
# 18/18 [==============================] - 8s 438ms/step - loss: 0.0416 - accuracy: 0.9843 - val_loss: 3.5234 - val_accuracy: 0.5488
# Epoch 89/100
# 18/18 [==============================] - 7s 409ms/step - loss: 0.0494 - accuracy: 0.9861 - val_loss: 2.1856 - val_accuracy: 0.6829
# Epoch 90/100
# 18/18 [==============================] - 7s 412ms/step - loss: 0.0391 - accuracy: 0.9913 - val_loss: 2.0589 - val_accuracy: 0.6626
# Epoch 91/100
# 18/18 [==============================] - 7s 414ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 2.4577 - val_accuracy: 0.6382
# Epoch 92/100
# 18/18 [==============================] - 7s 415ms/step - loss: 0.0374 - accuracy: 0.9895 - val_loss: 2.3003 - val_accuracy: 0.6545
# Epoch 93/100
# 18/18 [==============================] - 7s 415ms/step - loss: 0.0286 - accuracy: 0.9930 - val_loss: 3.3661 - val_accuracy: 0.4837
# Epoch 94/100
# 18/18 [==============================] - 7s 414ms/step - loss: 0.0627 - accuracy: 0.9878 - val_loss: 2.1866 - val_accuracy: 0.6463
# Epoch 95/100
# 18/18 [==============================] - 8s 436ms/step - loss: 0.0565 - accuracy: 0.9756 - val_loss: 2.8388 - val_accuracy: 0.5935
# Epoch 96/100
# 18/18 [==============================] - 8s 424ms/step - loss: 0.0747 - accuracy: 0.9861 - val_loss: 2.4968 - val_accuracy: 0.6382
# Epoch 97/100
# 18/18 [==============================] - 8s 428ms/step - loss: 0.0513 - accuracy: 0.9826 - val_loss: 2.4817 - val_accuracy: 0.5976
# Epoch 98/100
# 18/18 [==============================] - 7s 416ms/step - loss: 0.0643 - accuracy: 0.9826 - val_loss: 2.2178 - val_accuracy: 0.6382
# Epoch 99/100
# 18/18 [==============================] - 7s 412ms/step - loss: 0.0233 - accuracy: 0.9895 - val_loss: 2.2023 - val_accuracy: 0.6504
# Epoch 100/100
# 18/18 [==============================] - 7s 417ms/step - loss: 0.0122 - accuracy: 0.9965 - val_loss: 2.6657 - val_accuracy: 0.6301

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('acc')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
'''Se evalúa la exactitud del  modelo'''
perdida, exactitud = modelo.evaluate(test_fotos, test_etiquetas)
# Out:
# 8/8 [==============================] - 1s 60ms/step - loss: 2.6657 - accuracy: 0.6301

# %% [markdown]
# ### Predecir valores con el modelo entrenado

# %%
'''Se establece la predicción del modelo'''
pred = modelo.predict(test_fotos).argmax(axis=1)
pred.shape
# Out:
# 8/8 [==============================] - 1s 60ms/step
# (246,)

# %%
for i in range(50):
    print("Actual:", nombre_clases[test_etiquetas[i]])
    print("Prediction:", nombre_clases[np.array(pred[i])])
    print("-----")
    print()
# Out:
# Actual: Hector Cedenio
# Prediction: Hector Cedenio
# -----
#
# Actual: Kevin Paute
# Prediction: Kevin Paute
# -----
#
# Actual: SalazarJohana
# Prediction: SalazarJohana
# -----
#
# Actual: Joan Cevallos
# Prediction: Joan Cevallos
# -----
#
# Actual: Bryan Solorzano
# Prediction: Bryan Solorzano
# -----
#
# Actual: Selena Rivas
# Prediction: Joan Cevallos
# -----
#
# Actual: Joan Cevallos
# Prediction: Lucy Mosquera
# -----
#
# Actual: Melany Lopez
# Prediction: SalazarJohana
# -----
#
# Actual: Genesis Heredia
# Prediction: Mercy Arrobo
# -----
#
# Actual: Selena Enriquez
# Prediction: Selena Enriquez
# -----
#
# Actual: Leonardo Borja
# Prediction: Leonardo Borja
# -----
#
# Actual: Mercy Arrobo
# Prediction: RuizJose
# -----
#
# Actual: Luis Olalla
# Prediction: Luis Olalla
# -----
#
# Actual: Hector Cedenio
# Prediction: Hector Cedenio
# -----
#
# Actual: Melany Lopez
# Prediction: Melany Lopez
# -----
#
# Actual: Davila Raymond
# Prediction: Selena Enriquez
# -----
#
# Actual: Mercy Arrobo
# Prediction: Ariel Chabla
# -----
#
# Actual: Jordan Espinosa
# Prediction: Jordan Espinosa
# -----
#
# Actual: Nataly Acosta
# Prediction: Nataly Acosta
# -----
#
# Actual: Steven Barragan
# Prediction: Steven Barragan
# -----
#
# Actual: Solano Wilmer
# Prediction: Solano Wilmer
# -----
#
# Actual: Maria Jose Parraga
# Prediction: Maria Jose Parraga
# -----
#
# Actual: Nataly Acosta
# Prediction: SalazarJohana
# -----
#
# Actual: Steven Barragan
# Prediction: Steven Barragan
# -----
#
# Actual: Davila Raymond
# Prediction: Mercy Arrobo
# -----
#
# Actual: LucioCarlos
# Prediction: LucioCarlos
# -----
#
# Actual: Jhon Zambrano
# Prediction: Jhon Zambrano
# -----
#
# Actual: Lucy Mosquera
# Prediction: Lucy Mosquera
# -----
#
# Actual: Luis Olalla
# Prediction: Luis Olalla
# -----
#
# Actual: Melany Lopez
# Prediction: Melany Lopez
# -----
#
# Actual: Ariel Chabla
# Prediction: Davila Raymond
# -----
#
# Actual: Selena Rivas
# Prediction: Selena Rivas
# -----
#
# Actual: Mercy Arrobo
# Prediction: Mercy Arrobo
# -----
#
# Actual: Solano Wilmer
# Prediction: Solano Wilmer
# -----
#
# Actual: Jordan Espinosa
# Prediction: Jordan Espinosa
# -----
#
# Actual: Solano Wilmer
# Prediction: Solano Wilmer
# -----
#
# Actual: Jhon Zambrano
# Prediction: Selena Rivas
# -----
#
# Actual: Steven Barragan
# Prediction: Steven Barragan
# -----
#
# Actual: Nataly Acosta
# Prediction: Nataly Acosta
# -----
#
# Actual: Nataly Acosta
# Prediction: Nataly Acosta
# -----
#
# Actual: Jorge Borrero
# Prediction: Jorge Borrero
# -----
#
# Actual: Maria Jose Parraga
# Prediction: Steven Barragan
# -----
#
# Actual: Ariel Chabla
# Prediction: Ariel Chabla
# -----
#
# Actual: Selena Enriquez
# Prediction: Steven Barragan
# -----
#
# Actual: Fernando Masache
# Prediction: Fernando Masache
# -----
#
# Actual: Nataly Acosta
# Prediction: Nataly Acosta
# -----
#
# Actual: Melany Lopez
# Prediction: Melany Lopez
# -----
#
# Actual: Lucy Mosquera
# Prediction: Lucy Mosquera
# -----
#
# Actual: Davila Raymond
# Prediction: Davila Raymond
# -----
#
# Actual: Steven Barragan
# Prediction: Steven Barragan
# -----

# %%
from sklearn.metrics import classification_report,confusion_matrix
import seaborn as sns
matrix = confusion_matrix(test_etiquetas, pred)
sns.heatmap(matrix, annot=True)
sns.set(rc = {'figure.figsize':(20,20)})
plt.title('Matriz de Confusión')
plt.xlabel('Clases predecidas')
plt.ylabel('Clases reales')
# Out:
# Text(33.0, 0.5, 'Clases reales')

# %%
L = 10
W = 5

fig, axes = plt.subplots(L, W, figsize = (15, 24))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(test_fotos[i], cmap='gray')
    axes[i].set_title('Prediction = {} ({})\n Verdadero = {} ({})'.format(nombre_clases[test_etiquetas[i]],
                    pred[i], nombre_clases[pred[i]],test_etiquetas[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %%
modelo.save('./cnnPrueba.h5')

# %%
# !mkdir API

# %%
# !tensorflowjs_converter --input_format keras cnn.h5 API

# %%
from keras.models import load_model
modelo = load_model('cnnPrueba.h5', compile = True)

# %%
ruta_ejemplo = './Estudiantes_datos_aumentados/Leonardo Borja/L00393007_3.jpg'
imagen = cv2.imread(ruta_ejemplo)
imagen = np.sum(imagen/3, axis = 2, keepdims = True)
imagen = np.array(imagen)
imagen = imagen.astype(np.float32)
imagen = (imagen -  128)/128

# %%
prediction = modelo.predict(imagen.reshape(1,100,100,1))

d = prediction.flatten()
j = d.max()
for index,item in enumerate(d):
    if item == j:
        class_name = nombre_clases[index]

#ploting image with predicted class name        
plt.figure(figsize = (4,4))
plt.imshow(imagen, cmap='gray')
plt.axis('off')
plt.title(class_name + ' ' + str(round(j*100,2)) + '%')
plt.show()
# Out:
# 1/1 [==============================] - 0s 32ms/step
