# %% [markdown]
# <center><h1>Inteligencia Artificial</header1></center>

# %% [markdown]
# Presentado por: <br>
# - Anthony Mauricio Goyes Díaz  <br>
# - Bryan Alfredo Solórzano Montero <br>
#
# Fecha: 13/08/2022

# %% [markdown]
# # Importación de librerias necesarias

# %%
'''Se importa la libreria cv2'''
import cv2
'''Se importa la libreria numpy'''
import numpy as np
'''Se importa la libreria os'''
import os
'''Se establece el nivel de codificación'''
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
'''Se importa la libreria pandas'''
import pandas as pd
'''Se importa la libreria pyplot'''
import matplotlib.pyplot as plt
'''Se importan el módulo ImageDataGenerator'''
from keras.preprocessing.image import ImageDataGenerator
'''Se importan los módulos array_to_img, img_to_array, load_img'''
from tensorflow.keras.utils import img_to_array, array_to_img, img_to_array, load_img
'''Se importa el módulo Image'''
from  PIL  import Image
'''Se importa la libreria h5py'''
import h5py
'''Se importa el módulo remove'''
from rembg import remove
'''Se importa el método io del módulo skimage'''
from skimage import io
'''Se importa el módulo random'''
import random
'''Se importa el módulo glob'''
import glob
'''Se importa el módulo tqdm'''
from tqdm import tqdm
# Out:
# C:\Users\Personal\AppData\Roaming\Python\Python39\site-packages\skimage\io\manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
class colorear:
    '''Generación de código ascii para colorear texto'''
    OK = '\033[1;92m' #Verde-negrita
    ADVERTENCIA = '\033[1;93m' #Amarillo-negrita
    ERROR = '\033[1;91m' #Rojo-negrita
    REINICIAR = '\033[1;0m' #Resetar color-negrita

# %% [markdown]
# ## Cargar el Dataset

# %%
'''Se establece la ruta general de espacio de trabajo'''
os.chdir('C:/Users/Personal/IA/ProyectoU3/')

# %%
'''Se establece la ruta de las imágenes'''
ruta_imagenes = "./recursos/clases"
'''Se muestra los directorios (clases) del dataset'''
nombre_clases = os.listdir(ruta_imagenes)
'''Se ordenan en orden alfabético (AZ - az)'''
nombre_clases.sort()
'''Se muestran las clases del dataset'''
print('Las clases del dataset son: \n' + str(nombre_clases))
# Out:
# Las clases del dataset son:
# ['Anthony Goyes', 'Ariel Chabla', 'Bryan Solorzano', 'Davila Raymond', 'Fernando Masache', 'Genesis Heredia', 'Hector Cedenio', 'Jhon Zambrano', 'Joan Cevallos', 'Johana Salazar', 'Jordan Espinosa', 'Jorge Borrero', 'Jose Ruiz', 'Kevin Paute', 'Leonardo Borja', 'LucioCarlos', 'Lucy Mosquera', 'Luis Olalla', 'Maria Jose Parraga', 'Melany Lopez', 'Mercy Arrobo', 'Nataly Acosta', 'Selena Enriquez', 'Selena Rivas', 'Solano Wilmer', 'Steven Barragan']

# %% [markdown]
# ## Descripción de la fuente del Dataset

# %% [markdown]
# La colección de datos está conformada por cinco clases que representan a cada estudiante perteneciente a la Universidad de las Fuerzas Armadas ESPE sede Santo Domingo de la materia de Inteligencia Artificial. Cada clase tiene un total de tres imágenes del rostro del estudiante, siendo cada una para la perspectiva de frente, perfil izquierdo y derecho. Por lo tanto, se tiene un total de 15 imágenes en total. Sin embargo estas imágenes tienen dimensiones y extensiones variadas por lo que será necesario realizar una limpieza a los datos y preprocesarlos.

# %% [markdown]
# ## Explique el problema a resolver.
# Se pretende reconocer si una persona pertenece a la clase de Inteligencia artificial de las Fuerzas Armadas ESPE sede Santo Domingo para lo cuál se debe recolectar imágenes del rostro de cada estudiante desde diferentes perspectivas y generar un modelo predictivo. Debido a que la clase de Inteligencia Artificial tiene varios estudiantes (26 estudiates/clases) el modelo a generar es clasificatorio multi-clase y será el modelo predictivo de Redes Neuronales Convoolucionales, es decir, no etiquetado. Lo que se espera predecir es el nombre del estudiante (etiqueta) a la que pertecena la imagen de entrada. El modelo podría tener una aplicación en la universidad de las Fuerzas Armadas ESPE como sistema automático para la asistencia en la clase.

# %% [markdown]
# Realice una descripción de los datos con:
#
# >- Número de instancias en total.

# %%
instancias = 0
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se contabiliza el total de instancias'''
        instancias+=1
print(f'Existen un total de {colorear.OK} ' + str(len(nombre_clases)) + f' clases {colorear.REINICIAR}')
print(f'Y un total de {colorear.OK}' + str(instancias) + f' fotos {colorear.REINICIAR}')
# Out:
# Existen un total de  26 clases
# Y un total de 268 fotos

# %%
# fotos por clases
cantidad = 0
for clases in os.listdir('./recursos/clases/'):
    for contador in os.listdir('./recursos/clases/' + clases):
        cantidad+=1
    print('Para la clase ',colorear.OK + clases + colorear.REINICIAR,
          ' se tiene un total de ',colorear.OK + str(cantidad) + colorear.REINICIAR,' fotos')     
    cantidad = 0
# Out:
# Para la clase  Anthony Goyes  se tiene un total de  10  fotos
# Para la clase  Ariel Chabla  se tiene un total de  8  fotos
# Para la clase  Bryan Solorzano  se tiene un total de  12  fotos
# Para la clase  Davila Raymond  se tiene un total de  9  fotos
# Para la clase  Fernando Masache  se tiene un total de  10  fotos
# Para la clase  Genesis Heredia  se tiene un total de  13  fotos
# Para la clase  Hector Cedenio  se tiene un total de  10  fotos
# Para la clase  Jhon Zambrano  se tiene un total de  16  fotos
# Para la clase  Joan Cevallos  se tiene un total de  9  fotos
# Para la clase  Johana Salazar  se tiene un total de  8  fotos
# Para la clase  Jordan Espinosa  se tiene un total de  8  fotos
# Para la clase  Jorge Borrero  se tiene un total de  3  fotos
# Para la clase  Jose Ruiz  se tiene un total de  10  fotos
# Para la clase  Kevin Paute  se tiene un total de  10  fotos
# Para la clase  Leonardo Borja  se tiene un total de  13  fotos
# Para la clase  LucioCarlos  se tiene un total de  13  fotos
# Para la clase  Lucy Mosquera  se tiene un total de  9  fotos
# Para la clase  Luis Olalla  se tiene un total de  13  fotos
# Para la clase  Maria Jose Parraga  se tiene un total de  13  fotos
# Para la clase  Melany Lopez  se tiene un total de  11  fotos
# Para la clase  Mercy Arrobo  se tiene un total de  8  fotos
# Para la clase  Nataly Acosta  se tiene un total de  8  fotos
# Para la clase  Selena Enriquez  se tiene un total de  8  fotos
# Para la clase  Selena Rivas  se tiene un total de  11  fotos
# Para la clase  Solano Wilmer  se tiene un total de  8  fotos
# Para la clase  Steven Barragan  se tiene un total de  17  fotos

# %%
def cargarImagenes(ruta_imagenes):
    """Permite imprimir randómicamente una imagen por cada clase con título y sus dimensiones.

    Argumentos:
        ruta_imagenes (str): Una cadena de texto que identifica el.

    Returna:
                    No retorna nada
    """
    '''Arreglo vacío que almacenará las fotos'''
    imagen = []
    '''Se genera un bucle para recorrer cada etiqueta de las clases'''
    for nombre_clase in nombre_clases:
        '''Se almacena la ruta actual de cada clase por ciclo'''
        ruta_actual = ruta_imagenes + "/" + nombre_clase
        '''Se obtiene una lista de los elementos por clase'''
        elementos = os.listdir(ruta_actual) 
        '''Se generar un número aleatorio encargado de imprimir una imagen por clase'''
        ran = random.randint(0, len(elementos) - 1)
        '''Se agrega al arreglo vacío un elemento aleatorio represtado como imagen'''
        imagen.append(io.imread(ruta_imagenes + "/" + nombre_clase +'/'+ elementos[ran])/255.0) 

    '''Se establece las dimensiones de contendor del gráfico'''  
    plt.figure(figsize=(19,15))
    '''Se genera un ciclo que recorrerá cada elemento del arreglo de fotos'''
    for iterador in range(len(nombre_clases)):
        '''Se establece la distribución de cada elemento en el contenedor gráfico
        donde se genera de manera dinámica en relación al número de elementos'''
        ax = plt.subplot(round(len(nombre_clases)/5)+1,5, iterador+1)
        '''Se muestra la imagen actual del ciclo'''
        plt.imshow(imagen[iterador])
        '''Se establece un título representativo de la imaegen y se menciona su dimensión'''
        plt.title(nombre_clases[iterador] + ' ' + str(imagen[iterador].shape))
        plt.axis('off')

# %%
cargarImagenes(ruta_imagenes)

# %% [markdown]
# ## Preprocesamiento del dataset. Transformaciones previas necesarias para la modelación

# %%
def crearDirecotrio(ruta):
    """Permite crear los directorios que se usarán para almacenar los datos transformados para cada etapa.

    Argumentos:
        ruta (str): Una cadena de texto que recibe la ruta padre donde se crearán los directorios.
    Retorna:
        No retorna nada
    """
    '''Pasos para almacenar los nuevos datos después de usar la técnica de
    aumentos de datos'''
    '''Se crea un nuevo directorio con la ruta anterior'''
    os.mkdir(ruta)
    '''Se establece un ciclo que creará el nombre y directorio de las carpetas
    que contendrá las imágenes de cada una de las clases'''
    for clase in nombre_clases:
        '''Se asigna la ruta de la clase a una variable'''
        subdirectorio = ruta+"/"+clase
        '''Se crea un nuevo directorio con la ruta anterior'''
        os.mkdir(subdirectorio)

# %%
ruta = './Estudiantes_datos'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_ruidoEliminado'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_fondoEliminado'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_aumentados'
crearDirecotrio(ruta)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se almacena la ruta de la imagen en una variable'''
        imagen = ruta_actual+'/'+elemento
        '''Se lee la ruta y se almacena la imagen leída en una variable'''
        imagen = cv2.imread(imagen)
        '''Se ajustan las dimensiones de la imagen'''
        imagen = cv2.resize(imagen, (100,100))
        '''Se almacena el prefijo del nombre de la imagen'''
        elemento = elemento[:elemento.find(".")]
        '''Se imprime un mensaje del proceso'''
        print("Copiando imagen - {} en Estudiantes_datos/{}".format(elemento+'.jpg', nombre_clase))
        '''Se establece la ruta destino de ese elemento'''
        ruta_destino = ("C:/Users/Personal/IA/ProyectoU3/Estudiantes_datos/" + nombre_clase + '/') 
        '''Se copia el elemento del origen al destino cambiando el formato a jpg'''
        cv2.imwrite(os.path.join(ruta_destino, elemento+'.jpg')    , imagen)
# Out:
# Copiando imagen - L00393010_1.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_10.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_2.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_3.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_4.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_5.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_6.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_7.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_8.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00393010_9.jpg en Estudiantes_datos/Anthony Goyes
# Copiando imagen - L00376418_1.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_2.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_3.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_4.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_5.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_6.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_7.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00376418_8.jpg en Estudiantes_datos/Ariel Chabla
# Copiando imagen - L00080131_1.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_1.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_2.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_2.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_3.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_3.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_4.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_5.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_6.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_7.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_8.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080131_9.jpg en Estudiantes_datos/Bryan Solorzano
# Copiando imagen - L00080957_1.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_2.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_3.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_4.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_5.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_6.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_7.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_8.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - L00080957_9.jpg en Estudiantes_datos/Davila Raymond
# Copiando imagen - 20220803_110911.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - 20220803_110958(1).jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - 20220803_110958(2).jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - 20220803_110958(3).jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - 20220803_110958.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - 20220803_111006.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - IDPhoto_20220817_132123.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - IDPhoto_20220817_132216.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - IDPhoto_20220817_132420.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - IDPhoto_20220817_132542.jpg en Estudiantes_datos/Fernando Masache
# Copiando imagen - L00392991_1.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_1.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_10.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_2.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_2.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_3.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_3.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_4.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_5.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_6.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_7.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_8.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L00392991_9.jpg en Estudiantes_datos/Genesis Heredia
# Copiando imagen - L003392989_4.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L003392989_5.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L003392989_6.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L003392989_7.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L003392989_8.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392989_1.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392989_10.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392989_2.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392989_3.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392989_9.jpg en Estudiantes_datos/Hector Cedenio
# Copiando imagen - L00392993_10.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_11.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_12.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_13.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_4.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_5.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_6.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_7.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_8.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_9.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_Centro.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_Centro.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_LD.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_LD.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_LI.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00392993_LI.jpg en Estudiantes_datos/Jhon Zambrano
# Copiando imagen - L00376416_1.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_2.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_3.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_4.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_5.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_6.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_7.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_8.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00376416_9.jpg en Estudiantes_datos/Joan Cevallos
# Copiando imagen - L00380416_01.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_02.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_03.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_1.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_2.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_3.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_4.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00380416_5.jpg en Estudiantes_datos/Johana Salazar
# Copiando imagen - L00080128_1 Frente.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_2 Derecho.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_3 Izquierda.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_4.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_5.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_6.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_7.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00080128_8.jpg en Estudiantes_datos/Jordan Espinosa
# Copiando imagen - L00379412_1.jpg en Estudiantes_datos/Jorge Borrero
# Copiando imagen - L00379412_2.jpg en Estudiantes_datos/Jorge Borrero
# Copiando imagen - L00379412_3.jpg en Estudiantes_datos/Jorge Borrero
# Copiando imagen - L00380361_1.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_10.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_2.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_3.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_4.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_5.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_6.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_7.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_8.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00380361_9.jpg en Estudiantes_datos/Jose Ruiz
# Copiando imagen - L00080134_1.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_10.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_2.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_3.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_4.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_5.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_6.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_7.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_8.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00080134_9.jpg en Estudiantes_datos/Kevin Paute
# Copiando imagen - L00393007_1.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_1.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_10.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_2.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_2.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_3.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_3.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_4.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_5.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_6.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_7.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_8.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393007_9.jpg en Estudiantes_datos/Leonardo Borja
# Copiando imagen - L00393009_1.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_1.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_10.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_2.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_2.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_3.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_3.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_4.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_5.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_6.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_7.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_8.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00393009_9.jpg en Estudiantes_datos/LucioCarlos
# Copiando imagen - L00073392_1.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_2.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_3.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_4.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_5.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_6.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_7.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_8.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00073392_9.jpg en Estudiantes_datos/Lucy Mosquera
# Copiando imagen - L00393001_1.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_10.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_11.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_12.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_13.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_2.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_3.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_4.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_5.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_6.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_7.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_8.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00393001_9.jpg en Estudiantes_datos/Luis Olalla
# Copiando imagen - L00392984_1.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_1.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_10.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_2.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_2.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_3.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_3.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_4.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_5.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_6.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_7.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_8.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392984_9.jpg en Estudiantes_datos/Maria Jose Parraga
# Copiando imagen - L00392999_1.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_10.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_11.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_2.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_3.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_4.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_5.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_6.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_7.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_8.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00392999_9.jpg en Estudiantes_datos/Melany Lopez
# Copiando imagen - L00385770_1.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_2.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_3.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_4.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_5.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_6.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_7.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00385770_8.jpg en Estudiantes_datos/Mercy Arrobo
# Copiando imagen - L00380424_1.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_2.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_3.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_4.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_5.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_6.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_7.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L00380424_8.jpg en Estudiantes_datos/Nataly Acosta
# Copiando imagen - L000376481_1.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L000376481_2.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L000376481_3.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L000376481_4.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L000376481_5.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L00376481_1.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L00376481_2.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L00376481_3.jpg en Estudiantes_datos/Selena Enriquez
# Copiando imagen - L00376689_1.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_10.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_11.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_2.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_3.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_4.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_5.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_6.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_7.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_8.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00376689_9.jpg en Estudiantes_datos/Selena Rivas
# Copiando imagen - L00392980_1.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_1.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_2.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_2.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_3.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_3.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_4.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392980_5.jpg en Estudiantes_datos/Solano Wilmer
# Copiando imagen - L00392978_1.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_1.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_10.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_11.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_12.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_13.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_14.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_2.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_2.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_3.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_3.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_4.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_5.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_6.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_7.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_8.jpg en Estudiantes_datos/Steven Barragan
# Copiando imagen - L00392978_9.jpg en Estudiantes_datos/Steven Barragan

# %% [markdown]
# ## Filtro NLM para la eliminación de ruido de las imágenes

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:     
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se almacenan las etiquetas de las clases'''
    etiqueta_actual = nombre_clase
    '''Se genera un iterador'''
    iterador = 1
    '''Se recorre cada imagen por clase sin importar su nombre o extensión'''
    for file in glob.glob(ruta_actual + "/*"):
        '''Se imprime el proceso'''
        print("Procesando imagen - {} en {}".format(iterador, etiqueta_actual))
        '''Se leen las rutas de las imágenes'''
        imagen = cv2.imread(file)
        '''Se establece la denotación de imágenes'''
        dst = cv2.fastNlMeansDenoisingColored(imagen,None,10,10,7,21)
        '''Se divide por capa de color'''
        b,g,r = cv2.split(dst)
        '''Se unen las capas seperadas en orden (r,g,b)'''
        rgb_dst = cv2.merge([r,g,b])
        '''Se guardan las imagenes'''
        ruta_guardado = './Estudiantes_datos_ruidoEliminado/'+ etiqueta_actual
        '''Se genera cada imagen según la ruta de guardado'''
        cv2.imwrite(os.path.join(ruta_guardado , etiqueta_actual + '_' + str(iterador) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        
        '''Se muestra la actualización del bucle'''
        iterador += 1
# Out:
# Procesando imagen - 1 en Anthony Goyes
# Procesando imagen - 2 en Anthony Goyes
# Procesando imagen - 3 en Anthony Goyes
# Procesando imagen - 4 en Anthony Goyes
# Procesando imagen - 5 en Anthony Goyes
# Procesando imagen - 6 en Anthony Goyes
# Procesando imagen - 7 en Anthony Goyes
# Procesando imagen - 8 en Anthony Goyes
# Procesando imagen - 9 en Anthony Goyes
# Procesando imagen - 10 en Anthony Goyes
# Procesando imagen - 1 en Ariel Chabla
# Procesando imagen - 2 en Ariel Chabla
# Procesando imagen - 3 en Ariel Chabla
# Procesando imagen - 4 en Ariel Chabla
# Procesando imagen - 5 en Ariel Chabla
# Procesando imagen - 6 en Ariel Chabla
# Procesando imagen - 7 en Ariel Chabla
# Procesando imagen - 8 en Ariel Chabla
# Procesando imagen - 1 en Bryan Solorzano
# Procesando imagen - 2 en Bryan Solorzano
# Procesando imagen - 3 en Bryan Solorzano
# Procesando imagen - 4 en Bryan Solorzano
# Procesando imagen - 5 en Bryan Solorzano
# Procesando imagen - 6 en Bryan Solorzano
# Procesando imagen - 7 en Bryan Solorzano
# Procesando imagen - 8 en Bryan Solorzano
# Procesando imagen - 9 en Bryan Solorzano
# Procesando imagen - 1 en Davila Raymond
# Procesando imagen - 2 en Davila Raymond
# Procesando imagen - 3 en Davila Raymond
# Procesando imagen - 4 en Davila Raymond
# Procesando imagen - 5 en Davila Raymond
# Procesando imagen - 6 en Davila Raymond
# Procesando imagen - 7 en Davila Raymond
# Procesando imagen - 8 en Davila Raymond
# Procesando imagen - 9 en Davila Raymond
# Procesando imagen - 1 en Fernando Masache
# Procesando imagen - 2 en Fernando Masache
# Procesando imagen - 3 en Fernando Masache
# Procesando imagen - 4 en Fernando Masache
# Procesando imagen - 5 en Fernando Masache
# Procesando imagen - 6 en Fernando Masache
# Procesando imagen - 7 en Fernando Masache
# Procesando imagen - 8 en Fernando Masache
# Procesando imagen - 9 en Fernando Masache
# Procesando imagen - 10 en Fernando Masache
# Procesando imagen - 1 en Genesis Heredia
# Procesando imagen - 2 en Genesis Heredia
# Procesando imagen - 3 en Genesis Heredia
# Procesando imagen - 4 en Genesis Heredia
# Procesando imagen - 5 en Genesis Heredia
# Procesando imagen - 6 en Genesis Heredia
# Procesando imagen - 7 en Genesis Heredia
# Procesando imagen - 8 en Genesis Heredia
# Procesando imagen - 9 en Genesis Heredia
# Procesando imagen - 10 en Genesis Heredia
# Procesando imagen - 1 en Hector Cedenio
# Procesando imagen - 2 en Hector Cedenio
# Procesando imagen - 3 en Hector Cedenio
# Procesando imagen - 4 en Hector Cedenio
# Procesando imagen - 5 en Hector Cedenio
# Procesando imagen - 6 en Hector Cedenio
# Procesando imagen - 7 en Hector Cedenio
# Procesando imagen - 8 en Hector Cedenio
# Procesando imagen - 9 en Hector Cedenio
# Procesando imagen - 10 en Hector Cedenio
# Procesando imagen - 1 en Jhon Zambrano
# Procesando imagen - 2 en Jhon Zambrano
# Procesando imagen - 3 en Jhon Zambrano
# Procesando imagen - 4 en Jhon Zambrano
# Procesando imagen - 5 en Jhon Zambrano
# Procesando imagen - 6 en Jhon Zambrano
# Procesando imagen - 7 en Jhon Zambrano
# Procesando imagen - 8 en Jhon Zambrano
# Procesando imagen - 9 en Jhon Zambrano
# Procesando imagen - 10 en Jhon Zambrano
# Procesando imagen - 11 en Jhon Zambrano
# Procesando imagen - 12 en Jhon Zambrano
# Procesando imagen - 13 en Jhon Zambrano
# Procesando imagen - 1 en Joan Cevallos
# Procesando imagen - 2 en Joan Cevallos
# Procesando imagen - 3 en Joan Cevallos
# Procesando imagen - 4 en Joan Cevallos
# Procesando imagen - 5 en Joan Cevallos
# Procesando imagen - 6 en Joan Cevallos
# Procesando imagen - 7 en Joan Cevallos
# Procesando imagen - 8 en Joan Cevallos
# Procesando imagen - 9 en Joan Cevallos
# Procesando imagen - 1 en Johana Salazar
# Procesando imagen - 2 en Johana Salazar
# Procesando imagen - 3 en Johana Salazar
# Procesando imagen - 4 en Johana Salazar
# Procesando imagen - 5 en Johana Salazar
# Procesando imagen - 6 en Johana Salazar
# Procesando imagen - 7 en Johana Salazar
# Procesando imagen - 8 en Johana Salazar
# Procesando imagen - 1 en Jordan Espinosa
# Procesando imagen - 2 en Jordan Espinosa
# Procesando imagen - 3 en Jordan Espinosa
# Procesando imagen - 4 en Jordan Espinosa
# Procesando imagen - 5 en Jordan Espinosa
# Procesando imagen - 6 en Jordan Espinosa
# Procesando imagen - 7 en Jordan Espinosa
# Procesando imagen - 8 en Jordan Espinosa
# Procesando imagen - 1 en Jorge Borrero
# Procesando imagen - 2 en Jorge Borrero
# Procesando imagen - 3 en Jorge Borrero
# Procesando imagen - 1 en Jose Ruiz
# Procesando imagen - 2 en Jose Ruiz
# Procesando imagen - 3 en Jose Ruiz
# Procesando imagen - 4 en Jose Ruiz
# Procesando imagen - 5 en Jose Ruiz
# Procesando imagen - 6 en Jose Ruiz
# Procesando imagen - 7 en Jose Ruiz
# Procesando imagen - 8 en Jose Ruiz
# Procesando imagen - 9 en Jose Ruiz
# Procesando imagen - 10 en Jose Ruiz
# Procesando imagen - 1 en Kevin Paute
# Procesando imagen - 2 en Kevin Paute
# Procesando imagen - 3 en Kevin Paute
# Procesando imagen - 4 en Kevin Paute
# Procesando imagen - 5 en Kevin Paute
# Procesando imagen - 6 en Kevin Paute
# Procesando imagen - 7 en Kevin Paute
# Procesando imagen - 8 en Kevin Paute
# Procesando imagen - 9 en Kevin Paute
# Procesando imagen - 10 en Kevin Paute
# Procesando imagen - 1 en Leonardo Borja
# Procesando imagen - 2 en Leonardo Borja
# Procesando imagen - 3 en Leonardo Borja
# Procesando imagen - 4 en Leonardo Borja
# Procesando imagen - 5 en Leonardo Borja
# Procesando imagen - 6 en Leonardo Borja
# Procesando imagen - 7 en Leonardo Borja
# Procesando imagen - 8 en Leonardo Borja
# Procesando imagen - 9 en Leonardo Borja
# Procesando imagen - 10 en Leonardo Borja
# Procesando imagen - 1 en LucioCarlos
# Procesando imagen - 2 en LucioCarlos
# Procesando imagen - 3 en LucioCarlos
# Procesando imagen - 4 en LucioCarlos
# Procesando imagen - 5 en LucioCarlos
# Procesando imagen - 6 en LucioCarlos
# Procesando imagen - 7 en LucioCarlos
# Procesando imagen - 8 en LucioCarlos
# Procesando imagen - 9 en LucioCarlos
# Procesando imagen - 10 en LucioCarlos
# Procesando imagen - 1 en Lucy Mosquera
# Procesando imagen - 2 en Lucy Mosquera
# Procesando imagen - 3 en Lucy Mosquera
# Procesando imagen - 4 en Lucy Mosquera
# Procesando imagen - 5 en Lucy Mosquera
# Procesando imagen - 6 en Lucy Mosquera
# Procesando imagen - 7 en Lucy Mosquera
# Procesando imagen - 8 en Lucy Mosquera
# Procesando imagen - 9 en Lucy Mosquera
# Procesando imagen - 1 en Luis Olalla
# Procesando imagen - 2 en Luis Olalla
# Procesando imagen - 3 en Luis Olalla
# Procesando imagen - 4 en Luis Olalla
# Procesando imagen - 5 en Luis Olalla
# Procesando imagen - 6 en Luis Olalla
# Procesando imagen - 7 en Luis Olalla
# Procesando imagen - 8 en Luis Olalla
# Procesando imagen - 9 en Luis Olalla
# Procesando imagen - 10 en Luis Olalla
# Procesando imagen - 11 en Luis Olalla
# Procesando imagen - 12 en Luis Olalla
# Procesando imagen - 13 en Luis Olalla
# Procesando imagen - 1 en Maria Jose Parraga
# Procesando imagen - 2 en Maria Jose Parraga
# Procesando imagen - 3 en Maria Jose Parraga
# Procesando imagen - 4 en Maria Jose Parraga
# Procesando imagen - 5 en Maria Jose Parraga
# Procesando imagen - 6 en Maria Jose Parraga
# Procesando imagen - 7 en Maria Jose Parraga
# Procesando imagen - 8 en Maria Jose Parraga
# Procesando imagen - 9 en Maria Jose Parraga
# Procesando imagen - 10 en Maria Jose Parraga
# Procesando imagen - 1 en Melany Lopez
# Procesando imagen - 2 en Melany Lopez
# Procesando imagen - 3 en Melany Lopez
# Procesando imagen - 4 en Melany Lopez
# Procesando imagen - 5 en Melany Lopez
# Procesando imagen - 6 en Melany Lopez
# Procesando imagen - 7 en Melany Lopez
# Procesando imagen - 8 en Melany Lopez
# Procesando imagen - 9 en Melany Lopez
# Procesando imagen - 10 en Melany Lopez
# Procesando imagen - 11 en Melany Lopez
# Procesando imagen - 1 en Mercy Arrobo
# Procesando imagen - 2 en Mercy Arrobo
# Procesando imagen - 3 en Mercy Arrobo
# Procesando imagen - 4 en Mercy Arrobo
# Procesando imagen - 5 en Mercy Arrobo
# Procesando imagen - 6 en Mercy Arrobo
# Procesando imagen - 7 en Mercy Arrobo
# Procesando imagen - 8 en Mercy Arrobo
# Procesando imagen - 1 en Nataly Acosta
# Procesando imagen - 2 en Nataly Acosta
# Procesando imagen - 3 en Nataly Acosta
# Procesando imagen - 4 en Nataly Acosta
# Procesando imagen - 5 en Nataly Acosta
# Procesando imagen - 6 en Nataly Acosta
# Procesando imagen - 7 en Nataly Acosta
# Procesando imagen - 8 en Nataly Acosta
# Procesando imagen - 1 en Selena Enriquez
# Procesando imagen - 2 en Selena Enriquez
# Procesando imagen - 3 en Selena Enriquez
# Procesando imagen - 4 en Selena Enriquez
# Procesando imagen - 5 en Selena Enriquez
# Procesando imagen - 6 en Selena Enriquez
# Procesando imagen - 7 en Selena Enriquez
# Procesando imagen - 8 en Selena Enriquez
# Procesando imagen - 1 en Selena Rivas
# Procesando imagen - 2 en Selena Rivas
# Procesando imagen - 3 en Selena Rivas
# Procesando imagen - 4 en Selena Rivas
# Procesando imagen - 5 en Selena Rivas
# Procesando imagen - 6 en Selena Rivas
# Procesando imagen - 7 en Selena Rivas
# Procesando imagen - 8 en Selena Rivas
# Procesando imagen - 9 en Selena Rivas
# Procesando imagen - 10 en Selena Rivas
# Procesando imagen - 11 en Selena Rivas
# Procesando imagen - 1 en Solano Wilmer
# Procesando imagen - 2 en Solano Wilmer
# Procesando imagen - 3 en Solano Wilmer
# Procesando imagen - 4 en Solano Wilmer
# Procesando imagen - 5 en Solano Wilmer
# Procesando imagen - 1 en Steven Barragan
# Procesando imagen - 2 en Steven Barragan
# Procesando imagen - 3 en Steven Barragan
# Procesando imagen - 4 en Steven Barragan
# Procesando imagen - 5 en Steven Barragan
# Procesando imagen - 6 en Steven Barragan
# Procesando imagen - 7 en Steven Barragan
# Procesando imagen - 8 en Steven Barragan
# Procesando imagen - 9 en Steven Barragan
# Procesando imagen - 10 en Steven Barragan
# Procesando imagen - 11 en Steven Barragan
# Procesando imagen - 12 en Steven Barragan
# Procesando imagen - 13 en Steven Barragan
# Procesando imagen - 14 en Steven Barragan

# %% [markdown]
# ## Eliminando el fondo con aplicar filtro NLM

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_ruidoEliminado"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se almacenan las etiquetas de las clases'''
    etiqueta_actual = nombre_clase
    '''Se genera un iterador'''
    iterador = 1
    '''Se recorre cada imagen por clase sin importar su nombre o extensión'''
    for file in glob.glob(ruta_actual + "/*"):
        '''Se imprime el proceso'''
        print("Procesando imaegen - {} en {}".format(iterador, etiqueta_actual))
        '''Se leen las rutas de las imágenes'''
        imagen = cv2.imread(file)
        '''Se remueve el fondo'''
        salida = remove(imagen)
        '''Se guardan las imagenes'''
        ruta_guardado = './Estudiantes_datos_fondoEliminado/'+ etiqueta_actual
        '''Se genera cada imagen según la ruta de guardado'''
        cv2.imwrite(os.path.join(ruta_guardado , etiqueta_actual + '_' + str(iterador) + '.jpg'), salida)       
        '''Se aumenta el iterador'''
        iterador += 1
# Out:
# Procesando imaegen - 1 en Anthony Goyes
# Procesando imaegen - 2 en Anthony Goyes
# Procesando imaegen - 3 en Anthony Goyes
# Procesando imaegen - 4 en Anthony Goyes
# Procesando imaegen - 5 en Anthony Goyes
# Procesando imaegen - 6 en Anthony Goyes
# Procesando imaegen - 7 en Anthony Goyes
# Procesando imaegen - 8 en Anthony Goyes
# Procesando imaegen - 9 en Anthony Goyes
# Procesando imaegen - 10 en Anthony Goyes
# Procesando imaegen - 1 en Ariel Chabla
# Procesando imaegen - 2 en Ariel Chabla
# Procesando imaegen - 3 en Ariel Chabla
# Procesando imaegen - 4 en Ariel Chabla
# Procesando imaegen - 5 en Ariel Chabla
# Procesando imaegen - 6 en Ariel Chabla
# Procesando imaegen - 7 en Ariel Chabla
# Procesando imaegen - 8 en Ariel Chabla
# Procesando imaegen - 1 en Bryan Solorzano
# Procesando imaegen - 2 en Bryan Solorzano
# Procesando imaegen - 3 en Bryan Solorzano
# Procesando imaegen - 4 en Bryan Solorzano
# Procesando imaegen - 5 en Bryan Solorzano
# Procesando imaegen - 6 en Bryan Solorzano
# Procesando imaegen - 7 en Bryan Solorzano
# Procesando imaegen - 8 en Bryan Solorzano
# Procesando imaegen - 9 en Bryan Solorzano
# Procesando imaegen - 1 en Davila Raymond
# Procesando imaegen - 2 en Davila Raymond
# Procesando imaegen - 3 en Davila Raymond
# Procesando imaegen - 4 en Davila Raymond
# Procesando imaegen - 5 en Davila Raymond
# Procesando imaegen - 6 en Davila Raymond
# Procesando imaegen - 7 en Davila Raymond
# Procesando imaegen - 8 en Davila Raymond
# Procesando imaegen - 9 en Davila Raymond
# Procesando imaegen - 1 en Fernando Masache
# Procesando imaegen - 2 en Fernando Masache
# Procesando imaegen - 3 en Fernando Masache
# Procesando imaegen - 4 en Fernando Masache
# Procesando imaegen - 5 en Fernando Masache
# Procesando imaegen - 6 en Fernando Masache
# Procesando imaegen - 7 en Fernando Masache
# Procesando imaegen - 8 en Fernando Masache
# Procesando imaegen - 9 en Fernando Masache
# Procesando imaegen - 10 en Fernando Masache
# Procesando imaegen - 1 en Genesis Heredia
# Procesando imaegen - 2 en Genesis Heredia
# Procesando imaegen - 3 en Genesis Heredia
# Procesando imaegen - 4 en Genesis Heredia
# Procesando imaegen - 5 en Genesis Heredia
# Procesando imaegen - 6 en Genesis Heredia
# Procesando imaegen - 7 en Genesis Heredia
# Procesando imaegen - 8 en Genesis Heredia
# Procesando imaegen - 9 en Genesis Heredia
# Procesando imaegen - 10 en Genesis Heredia
# Procesando imaegen - 1 en Hector Cedenio
# Procesando imaegen - 2 en Hector Cedenio
# Procesando imaegen - 3 en Hector Cedenio
# Procesando imaegen - 4 en Hector Cedenio
# Procesando imaegen - 5 en Hector Cedenio
# Procesando imaegen - 6 en Hector Cedenio
# Procesando imaegen - 7 en Hector Cedenio
# Procesando imaegen - 8 en Hector Cedenio
# Procesando imaegen - 9 en Hector Cedenio
# Procesando imaegen - 10 en Hector Cedenio
# Procesando imaegen - 1 en Jhon Zambrano
# Procesando imaegen - 2 en Jhon Zambrano
# Procesando imaegen - 3 en Jhon Zambrano
# Procesando imaegen - 4 en Jhon Zambrano
# Procesando imaegen - 5 en Jhon Zambrano
# Procesando imaegen - 6 en Jhon Zambrano
# Procesando imaegen - 7 en Jhon Zambrano
# Procesando imaegen - 8 en Jhon Zambrano
# Procesando imaegen - 9 en Jhon Zambrano
# Procesando imaegen - 10 en Jhon Zambrano
# Procesando imaegen - 11 en Jhon Zambrano
# Procesando imaegen - 12 en Jhon Zambrano
# Procesando imaegen - 13 en Jhon Zambrano
# Procesando imaegen - 1 en Joan Cevallos
# Procesando imaegen - 2 en Joan Cevallos
# Procesando imaegen - 3 en Joan Cevallos
# Procesando imaegen - 4 en Joan Cevallos
# Procesando imaegen - 5 en Joan Cevallos
# Procesando imaegen - 6 en Joan Cevallos
# Procesando imaegen - 7 en Joan Cevallos
# Procesando imaegen - 8 en Joan Cevallos
# Procesando imaegen - 9 en Joan Cevallos
# Procesando imaegen - 1 en Johana Salazar
# Procesando imaegen - 2 en Johana Salazar
# Procesando imaegen - 3 en Johana Salazar
# Procesando imaegen - 4 en Johana Salazar
# Procesando imaegen - 5 en Johana Salazar
# Procesando imaegen - 6 en Johana Salazar
# Procesando imaegen - 7 en Johana Salazar
# Procesando imaegen - 8 en Johana Salazar
# Procesando imaegen - 1 en Jordan Espinosa
# Procesando imaegen - 2 en Jordan Espinosa
# Procesando imaegen - 3 en Jordan Espinosa
# Procesando imaegen - 4 en Jordan Espinosa
# Procesando imaegen - 5 en Jordan Espinosa
# Procesando imaegen - 6 en Jordan Espinosa
# Procesando imaegen - 7 en Jordan Espinosa
# Procesando imaegen - 8 en Jordan Espinosa
# Procesando imaegen - 1 en Jorge Borrero
# Procesando imaegen - 2 en Jorge Borrero
# Procesando imaegen - 3 en Jorge Borrero
# Procesando imaegen - 1 en Jose Ruiz
# Procesando imaegen - 2 en Jose Ruiz
# Procesando imaegen - 3 en Jose Ruiz
# Procesando imaegen - 4 en Jose Ruiz
# Procesando imaegen - 5 en Jose Ruiz
# Procesando imaegen - 6 en Jose Ruiz
# Procesando imaegen - 7 en Jose Ruiz
# Procesando imaegen - 8 en Jose Ruiz
# Procesando imaegen - 9 en Jose Ruiz
# Procesando imaegen - 10 en Jose Ruiz
# Procesando imaegen - 1 en Kevin Paute
# Procesando imaegen - 2 en Kevin Paute
# Procesando imaegen - 3 en Kevin Paute
# Procesando imaegen - 4 en Kevin Paute
# Procesando imaegen - 5 en Kevin Paute
# Procesando imaegen - 6 en Kevin Paute
# Procesando imaegen - 7 en Kevin Paute
# Procesando imaegen - 8 en Kevin Paute
# Procesando imaegen - 9 en Kevin Paute
# Procesando imaegen - 10 en Kevin Paute
# Procesando imaegen - 1 en Leonardo Borja
# Procesando imaegen - 2 en Leonardo Borja
# Procesando imaegen - 3 en Leonardo Borja
# Procesando imaegen - 4 en Leonardo Borja
# Procesando imaegen - 5 en Leonardo Borja
# Procesando imaegen - 6 en Leonardo Borja
# Procesando imaegen - 7 en Leonardo Borja
# Procesando imaegen - 8 en Leonardo Borja
# Procesando imaegen - 9 en Leonardo Borja
# Procesando imaegen - 10 en Leonardo Borja
# Procesando imaegen - 1 en LucioCarlos
# Procesando imaegen - 2 en LucioCarlos
# Procesando imaegen - 3 en LucioCarlos
# Procesando imaegen - 4 en LucioCarlos
# Procesando imaegen - 5 en LucioCarlos
# Procesando imaegen - 6 en LucioCarlos
# Procesando imaegen - 7 en LucioCarlos
# Procesando imaegen - 8 en LucioCarlos
# Procesando imaegen - 9 en LucioCarlos
# Procesando imaegen - 10 en LucioCarlos
# Procesando imaegen - 1 en Lucy Mosquera
# Procesando imaegen - 2 en Lucy Mosquera
# Procesando imaegen - 3 en Lucy Mosquera
# Procesando imaegen - 4 en Lucy Mosquera
# Procesando imaegen - 5 en Lucy Mosquera
# Procesando imaegen - 6 en Lucy Mosquera
# Procesando imaegen - 7 en Lucy Mosquera
# Procesando imaegen - 8 en Lucy Mosquera
# Procesando imaegen - 9 en Lucy Mosquera
# Procesando imaegen - 1 en Luis Olalla
# Procesando imaegen - 2 en Luis Olalla
# Procesando imaegen - 3 en Luis Olalla
# Procesando imaegen - 4 en Luis Olalla
# Procesando imaegen - 5 en Luis Olalla
# Procesando imaegen - 6 en Luis Olalla
# Procesando imaegen - 7 en Luis Olalla
# Procesando imaegen - 8 en Luis Olalla
# Procesando imaegen - 9 en Luis Olalla
# Procesando imaegen - 10 en Luis Olalla
# Procesando imaegen - 11 en Luis Olalla
# Procesando imaegen - 12 en Luis Olalla
# Procesando imaegen - 13 en Luis Olalla
# Procesando imaegen - 1 en Maria Jose Parraga
# Procesando imaegen - 2 en Maria Jose Parraga
# Procesando imaegen - 3 en Maria Jose Parraga
# Procesando imaegen - 4 en Maria Jose Parraga
# Procesando imaegen - 5 en Maria Jose Parraga
# Procesando imaegen - 6 en Maria Jose Parraga
# Procesando imaegen - 7 en Maria Jose Parraga
# Procesando imaegen - 8 en Maria Jose Parraga
# Procesando imaegen - 9 en Maria Jose Parraga
# Procesando imaegen - 10 en Maria Jose Parraga
# Procesando imaegen - 1 en Melany Lopez
# Procesando imaegen - 2 en Melany Lopez
# Procesando imaegen - 3 en Melany Lopez
# Procesando imaegen - 4 en Melany Lopez
# Procesando imaegen - 5 en Melany Lopez
# Procesando imaegen - 6 en Melany Lopez
# Procesando imaegen - 7 en Melany Lopez
# Procesando imaegen - 8 en Melany Lopez
# Procesando imaegen - 9 en Melany Lopez
# Procesando imaegen - 10 en Melany Lopez
# Procesando imaegen - 11 en Melany Lopez
# Procesando imaegen - 1 en Mercy Arrobo
# Procesando imaegen - 2 en Mercy Arrobo
# Procesando imaegen - 3 en Mercy Arrobo
# Procesando imaegen - 4 en Mercy Arrobo
# Procesando imaegen - 5 en Mercy Arrobo
# Procesando imaegen - 6 en Mercy Arrobo
# Procesando imaegen - 7 en Mercy Arrobo
# Procesando imaegen - 8 en Mercy Arrobo
# Procesando imaegen - 1 en Nataly Acosta
# Procesando imaegen - 2 en Nataly Acosta
# Procesando imaegen - 3 en Nataly Acosta
# Procesando imaegen - 4 en Nataly Acosta
# Procesando imaegen - 5 en Nataly Acosta
# Procesando imaegen - 6 en Nataly Acosta
# Procesando imaegen - 7 en Nataly Acosta
# Procesando imaegen - 8 en Nataly Acosta
# Procesando imaegen - 1 en Selena Enriquez
# Procesando imaegen - 2 en Selena Enriquez
# Procesando imaegen - 3 en Selena Enriquez
# Procesando imaegen - 4 en Selena Enriquez
# Procesando imaegen - 5 en Selena Enriquez
# Procesando imaegen - 6 en Selena Enriquez
# Procesando imaegen - 7 en Selena Enriquez
# Procesando imaegen - 8 en Selena Enriquez
# Procesando imaegen - 1 en Selena Rivas
# Procesando imaegen - 2 en Selena Rivas
# Procesando imaegen - 3 en Selena Rivas
# Procesando imaegen - 4 en Selena Rivas
# Procesando imaegen - 5 en Selena Rivas
# Procesando imaegen - 6 en Selena Rivas
# Procesando imaegen - 7 en Selena Rivas
# Procesando imaegen - 8 en Selena Rivas
# Procesando imaegen - 9 en Selena Rivas
# Procesando imaegen - 10 en Selena Rivas
# Procesando imaegen - 11 en Selena Rivas
# Procesando imaegen - 1 en Solano Wilmer
# Procesando imaegen - 2 en Solano Wilmer
# Procesando imaegen - 3 en Solano Wilmer
# Procesando imaegen - 4 en Solano Wilmer
# Procesando imaegen - 5 en Solano Wilmer
# Procesando imaegen - 1 en Steven Barragan
# Procesando imaegen - 2 en Steven Barragan
# Procesando imaegen - 3 en Steven Barragan
# Procesando imaegen - 4 en Steven Barragan
# Procesando imaegen - 5 en Steven Barragan
# Procesando imaegen - 6 en Steven Barragan
# Procesando imaegen - 7 en Steven Barragan
# Procesando imaegen - 8 en Steven Barragan
# Procesando imaegen - 9 en Steven Barragan
# Procesando imaegen - 10 en Steven Barragan
# Procesando imaegen - 11 en Steven Barragan
# Procesando imaegen - 12 en Steven Barragan
# Procesando imaegen - 13 en Steven Barragan
# Procesando imaegen - 14 en Steven Barragan

# %% [markdown]
# # Aumento de datos (Data augmentation)

# %%
'''Se crea un elemento para generar imagenes según sus hiperparámetros'''
generacionDatos = ImageDataGenerator(
    rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest"
)

# %% [markdown]
# ## Aumento de datos para todas la clases

# %%
'''Se redirecciona con una ruta dinámica para el sistema'''
os.chdir(r'C:/Users/Personal/IA/ProyectoU3/Estudiantes_datos_fondoEliminado')
for clases in os.listdir():
    '''Se genera una ciclo que recorre cada elemento de la clase "GoyesAnthony"'''      
    for elemento in tqdm(os.listdir(clases), desc="Aumentando la cantidad de imágenes para la clase "
                         + clases + "..."):
        '''Se almacena la imagen de la ruta'''
        imagen = load_img(f"{os.getcwd()+ '/' + clases + '/' + elemento}")
        '''Se almacena un array Numpy'''
        elemento_iterado = img_to_array(imagen)
        elemento_iterado = cv2.resize(elemento_iterado,(100,100))
        '''Se aumenta una dimensión por ciclo que hará referencia a cada elemento'''  
        elemento_iterado = elemento_iterado.reshape((1,) + elemento_iterado.shape)
        '''Se inicializa un iterador'''
        iterador = 0
        '''Se genera un ciclo que corrererá cada lote de la transformación con sus
        hiperparámetros'''
        for lote in generacionDatos.flow(elemento_iterado, batch_size=1,
                save_to_dir="./"+str(clases), 
                save_prefix= clases, 
                save_format='jpg'):
            '''Se aumenta en una unidad en el iterador'''
            iterador += 1
            '''Se crea 10 imágenes de cada imagen'''
            if iterador == 34: 
                break
# Out:
# Aumentando la cantidad de imágenes para la clase Anthony Goyes...: 100%|███████████████| 10/10 [00:13<00:00,  1.37s/it]
# Aumentando la cantidad de imágenes para la clase Ariel Chabla...: 100%|██████████████████| 8/8 [00:05<00:00,  1.50it/s]
# Aumentando la cantidad de imágenes para la clase Bryan Solorzano...: 100%|███████████████| 9/9 [00:14<00:00,  1.58s/it]
# Aumentando la cantidad de imágenes para la clase Davila Raymond...: 100%|████████████████| 9/9 [00:07<00:00,  1.17it/s]
# Aumentando la cantidad de imágenes para la clase Fernando Masache...: 100%|████████████| 10/10 [00:04<00:00,  2.26it/s]
# Aumentando la cantidad de imágenes para la clase Genesis Heredia...: 100%|█████████████| 10/10 [00:06<00:00,  1.53it/s]
# Aumentando la cantidad de imágenes para la clase Hector Cedenio...: 100%|██████████████| 10/10 [00:04<00:00,  2.47it/s]
# Aumentando la cantidad de imágenes para la clase Jhon Zambrano...: 100%|███████████████| 13/13 [00:04<00:00,  2.75it/s]
# Aumentando la cantidad de imágenes para la clase Joan Cevallos...: 100%|█████████████████| 9/9 [00:06<00:00,  1.39it/s]
# Aumentando la cantidad de imágenes para la clase Johana Salazar...: 100%|████████████████| 8/8 [00:03<00:00,  2.17it/s]
# Aumentando la cantidad de imágenes para la clase Jordan Espinosa...: 100%|███████████████| 8/8 [00:03<00:00,  2.64it/s]
# Aumentando la cantidad de imágenes para la clase Jorge Borrero...: 100%|█████████████████| 3/3 [00:01<00:00,  2.51it/s]
# Aumentando la cantidad de imágenes para la clase Jose Ruiz...: 100%|███████████████████| 10/10 [00:03<00:00,  2.53it/s]
# Aumentando la cantidad de imágenes para la clase Kevin Paute...: 100%|█████████████████| 10/10 [00:03<00:00,  2.69it/s]
# Aumentando la cantidad de imágenes para la clase Leonardo Borja...: 100%|██████████████| 10/10 [00:05<00:00,  1.87it/s]
# Aumentando la cantidad de imágenes para la clase LucioCarlos...: 100%|█████████████████| 10/10 [00:04<00:00,  2.14it/s]
# Aumentando la cantidad de imágenes para la clase Lucy Mosquera...: 100%|█████████████████| 9/9 [00:05<00:00,  1.59it/s]
# Aumentando la cantidad de imágenes para la clase Luis Olalla...: 100%|█████████████████| 13/13 [00:07<00:00,  1.75it/s]
# Aumentando la cantidad de imágenes para la clase Maria Jose Parraga...: 100%|██████████| 10/10 [00:07<00:00,  1.36it/s]
# Aumentando la cantidad de imágenes para la clase Melany Lopez...: 100%|████████████████| 11/11 [00:04<00:00,  2.40it/s]
# Aumentando la cantidad de imágenes para la clase Mercy Arrobo...: 100%|██████████████████| 8/8 [00:03<00:00,  2.09it/s]
# Aumentando la cantidad de imágenes para la clase Nataly Acosta...: 100%|█████████████████| 8/8 [00:04<00:00,  1.73it/s]
# Aumentando la cantidad de imágenes para la clase Selena Enriquez...: 100%|███████████████| 8/8 [00:04<00:00,  1.76it/s]
# Aumentando la cantidad de imágenes para la clase Selena Rivas...: 100%|████████████████| 11/11 [00:06<00:00,  1.83it/s]
# Aumentando la cantidad de imágenes para la clase Solano Wilmer...: 100%|█████████████████| 5/5 [00:03<00:00,  1.66it/s]
# Aumentando la cantidad de imágenes para la clase Steven Barragan...: 100%|█████████████| 14/14 [00:07<00:00,  1.82it/s]

# %%
'''Se redirecciona con una ruta dinámica para el sistema'''
os.chdir(r'C:/Users/Personal/IA/ProyectoU3/')
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_fondoEliminado"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
instancias = 0
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se contabiliza el total de instancias'''
        instancias+=1
print(f'Existen un total de {colorear.OK} ' + str(len(nombre_clases)) + f' clases {colorear.REINICIAR}')
print(f'Y un total de {colorear.OK}' + str(instancias) + f' fotos {colorear.REINICIAR}')
# Out:
# Existen un total de  26 clases
# Y un total de 8396 fotos

# %%
# fotos por clases
cantidad = 0
for clases in os.listdir('./Estudiantes_datos_fondoEliminado/'):
    for contador in os.listdir('./Estudiantes_datos_fondoEliminado/' + clases):
        cantidad+=1
    print('Para la clase ',colorear.OK + clases + colorear.REINICIAR,
          ' se tiene un total de ',colorear.OK + str(cantidad) + colorear.REINICIAR,' fotos')     
    cantidad = 0
# Out:
# Para la clase  Anthony Goyes  se tiene un total de  342  fotos
# Para la clase  Ariel Chabla  se tiene un total de  276  fotos
# Para la clase  Bryan Solorzano  se tiene un total de  315  fotos
# Para la clase  Davila Raymond  se tiene un total de  308  fotos
# Para la clase  Fernando Masache  se tiene un total de  340  fotos
# Para la clase  Genesis Heredia  se tiene un total de  343  fotos
# Para la clase  Hector Cedenio  se tiene un total de  342  fotos
# Para la clase  Jhon Zambrano  se tiene un total de  445  fotos
# Para la clase  Joan Cevallos  se tiene un total de  310  fotos
# Para la clase  Johana Salazar  se tiene un total de  277  fotos
# Para la clase  Jordan Espinosa  se tiene un total de  278  fotos
# Para la clase  Jorge Borrero  se tiene un total de  105  fotos
# Para la clase  Jose Ruiz  se tiene un total de  348  fotos
# Para la clase  Kevin Paute  se tiene un total de  348  fotos
# Para la clase  Leonardo Borja  se tiene un total de  344  fotos
# Para la clase  LucioCarlos  se tiene un total de  344  fotos
# Para la clase  Lucy Mosquera  se tiene un total de  308  fotos
# Para la clase  Luis Olalla  se tiene un total de  445  fotos
# Para la clase  Maria Jose Parraga  se tiene un total de  343  fotos
# Para la clase  Melany Lopez  se tiene un total de  380  fotos
# Para la clase  Mercy Arrobo  se tiene un total de  273  fotos
# Para la clase  Nataly Acosta  se tiene un total de  274  fotos
# Para la clase  Selena Enriquez  se tiene un total de  277  fotos
# Para la clase  Selena Rivas  se tiene un total de  377  fotos
# Para la clase  Solano Wilmer  se tiene un total de  172  fotos
# Para la clase  Steven Barragan  se tiene un total de  482  fotos

# %% [markdown]
# ## Resultado de los datos (antes de eliminar las inconsitencias)

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_fondoEliminado"
'''Se llama al método para cargar las imágenes de la ruta'''
cargarImagenes(ruta_imagenes)

# %% [markdown]
# ### Balancear y limpiar inconsistencias en los samples por clase

# %%
cantidad = 0
for clases in os.listdir('./Estudiantes_datos_fondoEliminado/'):
    for imagen in os.listdir('./Estudiantes_datos_fondoEliminado/' + clases):
        while cantidad < 100:
            '''Se almacena la ruta de la imagen en una variable'''
    #         imagen = ruta_actual+'/'+elemento
            '''Se lee la ruta y se almacena la imagen leída en una variable'''
            imagen = cv2.imread(imagen)
            '''Se ajustan las dimensiones de la imagen'''
    #         imagen = cv2.resize(imagen, (100,100))
            '''Se almacena el prefijo del nombre de la imagen'''
            elemento = elemento[:elemento.find(".")]
            '''Se imprime un mensaje del proceso'''
            print("Copiando imagen - {} en Estudiantes_datos_aumentados/{}".format(elemento+'.jpg', nombre_clase))
            '''Se establece la ruta destino de ese elemento'''
            ruta_destino = ("C:/Users/Personal/IA/ProyectoU3/Estudiantes_datos_aumentados/" + nombre_clase + '/') 
            '''Se copia el elemento del origen al destino con formato jpg'''
            cv2.imwrite(os.path.join(ruta_destino, elemento+'.jpg')    , imagen)
            cantidad+=1     
    cantidad = 0

# %% [markdown]
# ### Resultado de los datos (después de eliminar las inconsistencias)

# %%
cargarImagenes(ruta_imagenes)
