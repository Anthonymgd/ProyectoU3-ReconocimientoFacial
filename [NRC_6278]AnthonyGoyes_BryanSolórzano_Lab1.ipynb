# %% [markdown]
# <center><h1>Inteligencia Artificial</header1></center>

# %% [markdown]
# Presentado por: <br>
# - Anthony Mauricio Goyes Díaz  <br>
# - Bryan Alfredo Solórzano Montero <br>
#
# Fecha: 13/08/2022

# %% [markdown]
# # Importación de librerias necesarias

# %%
'''Se importa la libreria cv2'''
import cv2
'''Se importa la libreria numpy'''
import numpy as np
'''Se importa la libreria os'''
import os
'''Se establece el nivel de codificación'''
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
'''Se importa la libreria pandas'''
import pandas as pd
'''Se importa la libreria pyplot'''
import matplotlib.pyplot as plt
'''Se importan el módulo ImageDataGenerator'''
from keras.preprocessing.image import ImageDataGenerator
'''Se importan los módulos array_to_img, img_to_array, load_img'''
from tensorflow.keras.utils import img_to_array, array_to_img, img_to_array, load_img
'''Se importa el módulo Image'''
from  PIL  import Image
'''Se importa la libreria h5py'''
import h5py
'''Se importa el módulo remove'''
from rembg import remove
'''Se importa el método io del módulo skimage'''
from skimage import io
'''Se importa el módulo random'''
import random
'''Se importa el módulo glob'''
import glob
from tqdm import tqdm

# %%
class colorear:
    '''Generación de código ascii para colorear texto'''
    OK = '\033[1;92m' #Verde-negrita
    ADVERTENCIA = '\033[1;93m' #Amarillo-negrita
    ERROR = '\033[1;91m' #Rojo-negrita
    REINICIAR = '\033[1;0m' #Resetar color-negrita

# %% [markdown]
# ## Cargar el Dataset

# %%
'''Se establece la ruta general de espacio de trabajo'''
os.chdir('C:/Users/Personal/IA/ProyectoU3/')

# %%
'''Se establece la ruta de las imágenes'''
ruta_imagenes = "./recursos/clases"
'''Se muestra los directorios (clases) del dataset'''
nombre_clases = os.listdir(ruta_imagenes)
'''Se ordenan en orden alfabético (AZ - az)'''
nombre_clases.sort()
'''Se muestran las clases del dataset'''
print('Las clases del dataset son: \n' + str(nombre_clases))
# Out:
# Las clases del dataset son:
# ['Anthony Goyes', 'Ariel Chabla', 'Bryan Solorzano', 'Davila Raymond', 'Fernando Masache', 'Genesis Heredia', 'Hector Cedenio', 'Jhon Zambrano', 'Joan Cevallos', 'Johana Salazar', 'Jordan Espinosa', 'Jorge Borrero', 'Jose Ruiz', 'Kevin Paute', 'Leonardo Borja', 'LucioCarlos', 'Lucy Mosquera', 'Luis Olalla', 'Maria Jose Parraga', 'Melany Lopez', 'Mercy Arrobo', 'Nataly Acosta', 'Selena Enriquez', 'Selena Rivas', 'Solano Wilmer', 'Steven Barragan']

# %% [markdown]
# ## Descripción de la fuente del Dataset

# %% [markdown]
# La colección de datos está conformada por cinco clases que representan a cada estudiante perteneciente a la Universidad de las Fuerzas Armadas ESPE sede Santo Domingo de la materia de Inteligencia Artificial. Cada clase tiene un total de tres imágenes del rostro del estudiante, siendo cada una para la perspectiva de frente, perfil izquierdo y derecho. Por lo tanto, se tiene un total de 15 imágenes en total. Sin embargo estas imágenes tienen dimensiones y extensiones variadas por lo que será necesario realizar una limpieza a los datos y preprocesarlos.

# %% [markdown]
# ## Explique el problema a resolver.
# Se pretende reconocer si una persona pertenece a la clase de Inteligencia artificial de las Fuerzas Armadas ESPE sede Santo Domingo para lo cuál se debe recolectar imágenes del rostro de cada estudiante desde diferentes perspectivas y generar un modelo predictivo. Debido a que la clase de Inteligencia Artificial tiene varios estudiantes (26 estudiates/clases) el modelo a generar es clasificatorio multi-clase y será el modelo predictivo de Redes Neuronales Convoolucionales, es decir, no etiquetado. Lo que se espera predecir es el nombre del estudiante (etiqueta) a la que pertecena la imagen de entrada. El modelo podría tener una aplicación en la universidad de las Fuerzas Armadas ESPE como sistema automático para la asistencia en la clase.

# %% [markdown]
# Realice una descripción de los datos con:
#
# >- Número de instancias en total.

# %%
instancias = 0
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se contabiliza el total de instancias'''
        instancias+=1
print(f'Existen un total de {colorear.OK} ' + str(len(nombre_clases)) + f' clases {colorear.REINICIAR}')
print(f'Y un total de {colorear.OK}' + str(instancias) + f' fotos {colorear.REINICIAR}')
# Out:
# Existen un total de  26 clases
# Y un total de 268 fotos

# %%
# fotos por clases
cantidad = 0
for clases in os.listdir('./recursos/clases/'):
    for contador in os.listdir('./recursos/clases/' + clases):
        cantidad+=1
    print('Para la clase ',bcolors.OK + clases + bcolors.RESET,
          ' se tiene un total de ',bcolors.OK + str(cantidad) + bcolors.RESET,' fotos')     
    cantidad = 0
# Out:
# Para la clase  Anthony Goyes  se tiene un total de  10  fotos
# Para la clase  Ariel Chabla  se tiene un total de  8  fotos
# Para la clase  Bryan Solorzano  se tiene un total de  12  fotos
# Para la clase  Davila Raymond  se tiene un total de  9  fotos
# Para la clase  Fernando Masache  se tiene un total de  10  fotos
# Para la clase  Genesis Heredia  se tiene un total de  13  fotos
# Para la clase  Hector Cedenio  se tiene un total de  10  fotos
# Para la clase  Jhon Zambrano  se tiene un total de  16  fotos
# Para la clase  Joan Cevallos  se tiene un total de  9  fotos
# Para la clase  Johana Salazar  se tiene un total de  8  fotos
# Para la clase  Jordan Espinosa  se tiene un total de  8  fotos
# Para la clase  Jorge Borrero  se tiene un total de  3  fotos
# Para la clase  Jose Ruiz  se tiene un total de  10  fotos
# Para la clase  Kevin Paute  se tiene un total de  10  fotos
# Para la clase  Leonardo Borja  se tiene un total de  13  fotos
# Para la clase  LucioCarlos  se tiene un total de  13  fotos
# Para la clase  Lucy Mosquera  se tiene un total de  9  fotos
# Para la clase  Luis Olalla  se tiene un total de  13  fotos
# Para la clase  Maria Jose Parraga  se tiene un total de  13  fotos
# Para la clase  Melany Lopez  se tiene un total de  11  fotos
# Para la clase  Mercy Arrobo  se tiene un total de  8  fotos
# Para la clase  Nataly Acosta  se tiene un total de  8  fotos
# Para la clase  Selena Enriquez  se tiene un total de  8  fotos
# Para la clase  Selena Rivas  se tiene un total de  11  fotos
# Para la clase  Solano Wilmer  se tiene un total de  8  fotos
# Para la clase  Steven Barragan  se tiene un total de  17  fotos

# %%
def cargarImagenes(ruta_imagenes):
    """Permite imprimir randómicamente una imagen por cada clase con título y sus dimensiones.

    Argumentos:
        ruta_imagenes (str): Una cadena de texto que identifica el.

    Returna:
                    No retorna nada
    """
    '''Arreglo vacío que almacenará las fotos'''
    imagen = []
    '''Se genera un bucle para recorrer cada etiqueta de las clases'''
    for nombre_clase in nombre_clases:
        '''Se almacena la ruta actual de cada clase por ciclo'''
        ruta_actual = ruta_imagenes + "/" + nombre_clase
        '''Se obtiene una lista de los elementos por clase'''
        elementos = os.listdir(ruta_actual) 
        '''Se generar un número aleatorio encargado de imprimir una imagen por clase'''
        ran = random.randint(0, len(elementos) - 1)
        '''Se agrega al arreglo vacío un elemento aleatorio represtado como imagen'''
        imagen.append(io.imread(ruta_imagenes + "/" + nombre_clase +'/'+ elementos[ran])/255.0) 

    '''Se establece las dimensiones de contendor del gráfico'''  
    plt.figure(figsize=(19,15))
    '''Se genera un ciclo que recorrerá cada elemento del arreglo de fotos'''
    for iterador in range(len(nombre_clases)):
        '''Se establece la distribución de cada elemento en el contenedor gráfico
        donde se genera de manera dinámica en relación al número de elementos'''
        ax = plt.subplot(round(len(nombre_clases)/5)+1,5, iterador+1)
        '''Se muestra la imagen actual del ciclo'''
        plt.imshow(imagen[iterador])
        '''Se establece un título representativo de la imaegen y se menciona su dimensión'''
        plt.title(nombre_clases[iterador] + ' ' + str(imagen[iterador].shape))
        plt.axis('off')

# %%
cargarImagenes(ruta_imagenes)

# %% [markdown]
# ## Preprocesamiento del dataset. Transformaciones previas necesarias para la modelación

# %%
def crearDirecotrio(ruta):
    """Permite crear los directorios que se usarán para almacenar los datos transformados para cada etapa.

    Argumentos:
        ruta (str): Una cadena de texto que recibe la ruta padre donde se crearán los directorios.
    Retorna:
        No retorna nada
    """
    '''Pasos para almacenar los nuevos datos después de usar la técnica de
    aumentos de datos'''
    '''Se crea un nuevo directorio con la ruta anterior'''
    os.mkdir(ruta)
    '''Se establece un ciclo que creará el nombre y directorio de las carpetas
    que contendrá las imágenes de cada una de las clases'''
    for clase in nombre_clases:
        '''Se asigna la ruta de la clase a una variable'''
        subdirectorio = ruta+"/"+clase
        '''Se crea un nuevo directorio con la ruta anterior'''
        os.mkdir(subdirectorio)

# %%
ruta = './Estudiantes_datos_aumentados'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_ruidoEliminado'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_fondoEliminadoSinNLM'
crearDirecotrio(ruta)
ruta = './Estudiantes_datos_fondoEliminadoNLM'
crearDirecotrio(ruta)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se almacena la ruta de la imagen en una variable'''
        imagen = ruta_actual+'/'+elemento
        '''Se lee la ruta y se almacena la imagen leída en una variable'''
        imagen = cv2.imread(imagen)
        '''Se ajustan las dimensiones de la imagen'''
        imagen = cv2.resize(imagen, (100,100))
        '''Se almacena el prefijo del nombre de la imagen'''
        elemento = elemento[:elemento.find(".")]
        '''Se imprime un mensaje del proceso'''
        print("Copiando imagen - {} en Estudiantes_datos_aumentados/{}".format(elemento+'.jpg', nombre_clase))
        '''Se establece la ruta destino de ese elemento'''
        ruta_destino = ("C:/Users/Personal/IA/ProyectoU3/Estudiantes_datos_Aumentados/" + nombre_clase + '/') 
        '''Se copia el elemento del origen al destino cambiando el formato a jpg'''
        cv2.imwrite(os.path.join(ruta_destino, elemento+'.jpg')    , imagen)
# Out:
# Copiando imagen - L00393010_1.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_10.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_2.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_3.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_4.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_5.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_6.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_7.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_8.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00393010_9.jpg en Estudiantes_datos_aumentados/Anthony Goyes
# Copiando imagen - L00376418_1.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_2.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_3.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_4.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_5.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_6.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_7.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00376418_8.jpg en Estudiantes_datos_aumentados/Ariel Chabla
# Copiando imagen - L00080131_1.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_1.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_2.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_2.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_3.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_3.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00080131_4.jpg en Estudiantes_datos_aumentados/Bryan Solorzano
# Copiando imagen - L00392980_2.jpg en Estudiantes_datos_aumentados/Solano Wilmer
# Copiando imagen - L00392980_3.jpg en Estudiantes_datos_aumentados/Solano Wilmer
# Copiando imagen - L00392980_3.jpg en Estudiantes_datos_aumentados/Solano Wilmer
# Copiando imagen - L00392980_4.jpg en Estudiantes_datos_aumentados/Solano Wilmer
# Copiando imagen - L00392980_5.jpg en Estudiantes_datos_aumentados/Solano Wilmer
# Copiando imagen - L00392978_1.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_1.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_10.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_11.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_12.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_13.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_14.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_2.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_2.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_3.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_3.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_4.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_5.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_6.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_7.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_8.jpg en Estudiantes_datos_aumentados/Steven Barragan
# Copiando imagen - L00392978_9.jpg en Estudiantes_datos_aumentados/Steven Barragan

# %% [markdown]
# # Aumento de datos (Data augmentation)

# %%
'''Se crea un elemento para generar imagenes según sus hiperparámetros'''
generacionDatos = ImageDataGenerator(
    rotation_range=30,
	zoom_range=0.15,
	width_shift_range=0.2,
	height_shift_range=0.2,
	shear_range=0.15,
	horizontal_flip=True,
	fill_mode="nearest"
)

# %% [markdown]
# ## Aumento de datos para todas la clases

# %%
'''Se redirecciona con una ruta dinámica para el sistema'''
os.chdir(r'C:/Users/Personal/IA/ProyectoU3/Estudiantes_datos_aumentados')
for clases in os.listdir():
    '''Se genera una ciclo que recorre cada elemento de la clase "GoyesAnthony"'''      
    for elemento in tqdm(os.listdir(clases), desc="Aumentando la cantidad de imágenes para la clase "
                         + clases + "..."):
        '''Se almacena la imagen de la ruta'''
        imagen = load_img(f"{os.getcwd()+ '/' + clases + '/' + elemento}")
        '''Se almacena un array Numpy'''
        elemento_iterado = img_to_array(imagen)
        elemento_iterado = cv2.resize(elemento_iterado,(100,100))
        '''Se aumenta una dimensión por ciclo que hará referencia a cada elemento'''  
        elemento_iterado = elemento_iterado.reshape((1,) + elemento_iterado.shape)
        '''Se inicializa un iterador'''
        iterador = 0
        '''Se genera un ciclo que corrererá cada lote de la transformación con sus
        hiperparámetros'''
        for lote in generacionDatos.flow(elemento_iterado, batch_size=1,
                save_to_dir="./"+str(clases), 
                save_prefix= clases, 
                save_format='jpg'):
            '''Se aumenta en una unidad en el iterador'''
            iterador += 1
            '''Se crea 10 imágenes de cada imagen'''
            if iterador == 10: 
                break
# Out:
# Aumentando la cantidad de imágenes para la clase Anthony Goyes...: 100%|███████████████| 10/10 [00:01<00:00,  9.76it/s]
# Aumentando la cantidad de imágenes para la clase Ariel Chabla...: 100%|██████████████████| 8/8 [00:00<00:00, 10.00it/s]
# Aumentando la cantidad de imágenes para la clase Bryan Solorzano...: 100%|███████████████| 9/9 [00:00<00:00, 10.10it/s]
# Aumentando la cantidad de imágenes para la clase Davila Raymond...: 100%|████████████████| 9/9 [00:00<00:00, 14.89it/s]
# Aumentando la cantidad de imágenes para la clase Fernando Masache...: 100%|████████████| 10/10 [00:00<00:00, 10.76it/s]
# Aumentando la cantidad de imágenes para la clase Genesis Heredia...: 100%|█████████████| 10/10 [00:00<00:00, 13.97it/s]
# Aumentando la cantidad de imágenes para la clase Hector Cedenio...: 100%|██████████████| 10/10 [00:01<00:00,  8.17it/s]
# Aumentando la cantidad de imágenes para la clase Jhon Zambrano...: 100%|███████████████| 13/13 [00:01<00:00,  9.14it/s]
# Aumentando la cantidad de imágenes para la clase Joan Cevallos...: 100%|█████████████████| 9/9 [00:00<00:00, 12.25it/s]
# Aumentando la cantidad de imágenes para la clase Johana Salazar...: 100%|████████████████| 8/8 [00:01<00:00,  5.03it/s]
# Aumentando la cantidad de imágenes para la clase Jordan Espinosa...: 100%|███████████████| 8/8 [00:01<00:00,  4.24it/s]
# Aumentando la cantidad de imágenes para la clase Jorge Borrero...: 100%|█████████████████| 3/3 [00:00<00:00,  8.09it/s]
# Aumentando la cantidad de imágenes para la clase Jose Ruiz...: 100%|███████████████████| 10/10 [00:00<00:00, 10.08it/s]
# Aumentando la cantidad de imágenes para la clase Kevin Paute...: 100%|█████████████████| 10/10 [00:00<00:00, 13.96it/s]
# Aumentando la cantidad de imágenes para la clase Leonardo Borja...: 100%|██████████████| 10/10 [00:01<00:00,  5.80it/s]
# Aumentando la cantidad de imágenes para la clase LucioCarlos...: 100%|█████████████████| 10/10 [00:00<00:00, 14.15it/s]
# Aumentando la cantidad de imágenes para la clase Lucy Mosquera...: 100%|█████████████████| 9/9 [00:00<00:00, 12.39it/s]
# Aumentando la cantidad de imágenes para la clase Luis Olalla...: 100%|█████████████████| 13/13 [00:01<00:00,  7.23it/s]
# Aumentando la cantidad de imágenes para la clase Maria Jose Parraga...: 100%|██████████| 10/10 [00:00<00:00, 17.42it/s]
# Aumentando la cantidad de imágenes para la clase Melany Lopez...: 100%|████████████████| 11/11 [00:00<00:00, 15.55it/s]
# Aumentando la cantidad de imágenes para la clase Mercy Arrobo...: 100%|██████████████████| 8/8 [00:00<00:00, 11.32it/s]
# Aumentando la cantidad de imágenes para la clase Nataly Acosta...: 100%|█████████████████| 8/8 [00:00<00:00, 14.30it/s]
# Aumentando la cantidad de imágenes para la clase Selena Enriquez...: 100%|███████████████| 8/8 [00:00<00:00, 10.96it/s]
# Aumentando la cantidad de imágenes para la clase Selena Rivas...: 100%|████████████████| 11/11 [00:00<00:00, 13.38it/s]
# Aumentando la cantidad de imágenes para la clase Solano Wilmer...: 100%|█████████████████| 5/5 [00:00<00:00, 10.21it/s]
# Aumentando la cantidad de imágenes para la clase Steven Barragan...: 100%|█████████████| 14/14 [00:01<00:00,  7.58it/s]

# %%
'''Se redirecciona con una ruta dinámica para el sistema'''
os.chdir(r'C:/Users/Personal/IA/ProyectoU3/')
instancias = 0
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = './Estudiantes_datos_aumentados' + "/" + nombre_clase
    '''Se obtiene una lista de los elementos por clase'''
    elementos = os.listdir(ruta_actual) 
    '''Se genera un nuevo ciclo que recorre cada elemento por clase'''
    for elemento in elementos:
        '''Se contabiliza el total de instancias'''
        instancias+=1
print(f'Existen un total de {colorear.OK} ' + str(len(nombre_clases)) + f' clases {colorear.REINICIAR}')
print(f'Y un total de {colorear.OK}' + str(instancias) + f' fotos {colorear.REINICIAR}')
# Out:
# Existen un total de  26 clases
# Y un total de 2673 fotos

# %%
'''Se establece la ruta general de espacio de trabajo'''
os.chdir('C:/Users/Personal/IA/ProyectoU3/')
# fotos por clases
cantidad = 0
for clases in os.listdir('./Estudiantes_datos_aumentados/'):
    for contador in os.listdir('./Estudiantes_datos_aumentados/' + clases):
        cantidad+=1
    print('Para la clase ',bcolors.OK + clases + bcolors.RESET,
          ' se tiene un total de ',bcolors.OK + str(cantidad) + bcolors.RESET,' fotos')     
    cantidad = 0
# Out:
# Para la clase  Anthony Goyes  se tiene un total de  110  fotos
# Para la clase  Ariel Chabla  se tiene un total de  88  fotos
# Para la clase  Bryan Solorzano  se tiene un total de  98  fotos
# Para la clase  Davila Raymond  se tiene un total de  98  fotos
# Para la clase  Fernando Masache  se tiene un total de  110  fotos
# Para la clase  Genesis Heredia  se tiene un total de  108  fotos
# Para la clase  Hector Cedenio  se tiene un total de  109  fotos
# Para la clase  Jhon Zambrano  se tiene un total de  143  fotos
# Para la clase  Joan Cevallos  se tiene un total de  99  fotos
# Para la clase  Johana Salazar  se tiene un total de  87  fotos
# Para la clase  Jordan Espinosa  se tiene un total de  88  fotos
# Para la clase  Jorge Borrero  se tiene un total de  33  fotos
# Para la clase  Jose Ruiz  se tiene un total de  110  fotos
# Para la clase  Kevin Paute  se tiene un total de  108  fotos
# Para la clase  Leonardo Borja  se tiene un total de  110  fotos
# Para la clase  LucioCarlos  se tiene un total de  110  fotos
# Para la clase  Lucy Mosquera  se tiene un total de  99  fotos
# Para la clase  Luis Olalla  se tiene un total de  143  fotos
# Para la clase  Maria Jose Parraga  se tiene un total de  109  fotos
# Para la clase  Melany Lopez  se tiene un total de  121  fotos
# Para la clase  Mercy Arrobo  se tiene un total de  88  fotos
# Para la clase  Nataly Acosta  se tiene un total de  88  fotos
# Para la clase  Selena Enriquez  se tiene un total de  88  fotos
# Para la clase  Selena Rivas  se tiene un total de  119  fotos
# Para la clase  Solano Wilmer  se tiene un total de  55  fotos
# Para la clase  Steven Barragan  se tiene un total de  154  fotos

# %% [markdown]
# ## Filtro NLM para la eliminación de ruido de las imágenes

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_Aumentados"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:     
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se almacenan las etiquetas de las clases'''
    etiqueta_actual = nombre_clase
    '''Se genera un iterador'''
    iterador = 1
    '''Se recorre cada imagen por clase sin importar su nombre o extensión'''
    for file in glob.glob(ruta_actual + "/*"):
        '''Se imprime el proceso'''
        print("Procesando imagen - {} en {}".format(iterador, etiqueta_actual))
        '''Se leen las rutas de las imágenes'''
        imagen = cv2.imread(file)
        '''Se establece la denotación de imágenes'''
        dst = cv2.fastNlMeansDenoisingColored(imagen,None,10,10,7,21)
        '''Se divide por capa de color'''
        b,g,r = cv2.split(dst)
        '''Se unen las capas seperadas en orden (r,g,b)'''
        rgb_dst = cv2.merge([r,g,b])
        '''Se guardan las imagenes'''
        ruta_guardado = './Estudiantes_datos_ruidoEliminado/'+ etiqueta_actual
        '''Se genera cada imagen según la ruta de guardado'''
        cv2.imwrite(os.path.join(ruta_guardado , etiqueta_actual + '_' + str(iterador) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        
        '''Se muestra la actualización del bucle'''
        iterador += 1
# Out:
# Procesando imagen - 1 en Anthony Goyes
# Procesando imagen - 2 en Anthony Goyes
# Procesando imagen - 3 en Anthony Goyes
# Procesando imagen - 4 en Anthony Goyes
# Procesando imagen - 5 en Anthony Goyes
# Procesando imagen - 6 en Anthony Goyes
# Procesando imagen - 7 en Anthony Goyes
# Procesando imagen - 8 en Anthony Goyes
# Procesando imagen - 9 en Anthony Goyes
# Procesando imagen - 10 en Anthony Goyes
# Procesando imagen - 11 en Anthony Goyes
# Procesando imagen - 12 en Anthony Goyes
# Procesando imagen - 13 en Anthony Goyes
# Procesando imagen - 14 en Anthony Goyes
# Procesando imagen - 15 en Anthony Goyes
# Procesando imagen - 16 en Anthony Goyes
# Procesando imagen - 17 en Anthony Goyes
# Procesando imagen - 18 en Anthony Goyes
# Procesando imagen - 19 en Anthony Goyes
# Procesando imagen - 20 en Anthony Goyes
# Procesando imagen - 21 en Anthony Goyes
# Procesando imagen - 22 en Anthony Goyes
# Procesando imagen - 23 en Anthony Goyes
# Procesando imagen - 24 en Anthony Goyes
# Procesando imagen - 25 en Anthony Goyes
# Procesando imagen - 26 en Anthony Goyes
# Procesando imagen - 27 en Anthony Goyes
# Procesando imagen - 28 en Anthony Goyes
# Procesando imagen - 29 en Anthony Goyes
# Procesando imagen - 30 en Anthony Goyes
# Procesando imagen - 31 en Anthony Goyes
# Procesando imagen - 32 en Anthony Goyes
# Procesando imagen - 33 en Anthony Goyes
# Procesando imagen - 34 en Anthony Goyes
# Procesando imagen - 35 en Anthony Goyes
# Procesando imagen - 36 en Anthony Goyes
# Procesando imagen - 37 en Anthony Goyes
# Procesando imagen - 38 en Anthony Goyes
# Procesando imagen - 39 en Anthony Goyes
# Procesando imagen - 40 en Anthony Goyes
# Procesando imagen - 41 en Anthony Goyes
# Procesando imagen - 42 en Anthony Goyes
# Procesando imagen - 43 en Anthony Goyes
# Procesando imagen - 44 en Anthony Goyes
# Procesando imagen - 45 en Anthony Goyes
# Procesando imagen - 46 en Anthony Goyes
# Procesando imagen - 47 en Anthony Goyes
# Procesando imagen - 48 en Anthony Goyes
# Procesando imagen - 49 en Anthony Goyes
# Procesando imagen - 50 en Anthony Goyes
# Procesando imagen - 51 en Anthony Goyes
# Procesando imagen - 52 en Anthony Goyes
# Procesando imagen - 53 en Anthony Goyes
# Procesando imagen - 54 en Anthony Goyes
# Procesando imagen - 55 en Anthony Goyes
# Procesando imagen - 56 en Anthony Goyes
# Procesando imagen - 57 en Anthony Goyes
# Procesando imagen - 58 en Anthony Goyes
# Procesando imagen - 59 en Anthony Goyes
# Procesando imagen - 60 en Anthony Goyes
# Procesando imagen - 61 en Anthony Goyes
# Procesando imagen - 62 en Anthony Goyes
# Procesando imagen - 63 en Anthony Goyes
# Procesando imagen - 64 en Anthony Goyes
# Procesando imagen - 65 en Anthony Goyes
# Procesando imagen - 66 en Anthony Goyes
# Procesando imagen - 67 en Anthony Goyes
# Procesando imagen - 68 en Anthony Goyes
# Procesando imagen - 69 en Anthony Goyes
# Procesando imagen - 70 en Anthony Goyes
# Procesando imagen - 71 en Anthony Goyes
# Procesando imagen - 72 en Anthony Goyes
# Procesando imagen - 73 en Anthony Goyes
# Procesando imagen - 74 en Anthony Goyes
# Procesando imagen - 75 en Anthony Goyes
# Procesando imagen - 76 en Anthony Goyes
# Procesando imagen - 77 en Anthony Goyes
# Procesando imagen - 78 en Anthony Goyes
# Procesando imagen - 79 en Anthony Goyes
# Procesando imagen - 80 en Anthony Goyes
# Procesando imagen - 81 en Anthony Goyes
# Procesando imagen - 82 en Anthony Goyes
# Procesando imagen - 83 en Anthony Goyes
# Procesando imagen - 84 en Anthony Goyes
# Procesando imagen - 85 en Anthony Goyes
# Procesando imagen - 86 en Anthony Goyes
# Procesando imagen - 87 en Anthony Goyes
# Procesando imagen - 88 en Anthony Goyes
# Procesando imagen - 89 en Anthony Goyes
# Procesando imagen - 90 en Anthony Goyes
# Procesando imagen - 91 en Anthony Goyes
# Procesando imagen - 92 en Anthony Goyes
# Procesando imagen - 93 en Anthony Goyes
# Procesando imagen - 94 en Anthony Goyes
# Procesando imagen - 95 en Anthony Goyes
# Procesando imagen - 96 en Anthony Goyes
# Procesando imagen - 97 en Anthony Goyes
# Procesando imagen - 98 en Anthony Goyes
# Procesando imagen - 99 en Anthony Goyes
# Procesando imagen - 100 en Anthony Goyes
# Procesando imagen - 101 en Anthony Goyes
# Procesando imagen - 102 en Anthony Goyes
# Procesando imagen - 103 en Anthony Goyes
# Procesando imagen - 104 en Anthony Goyes
# Procesando imagen - 105 en Anthony Goyes
# Procesando imagen - 106 en Anthony Goyes
# Procesando imagen - 107 en Anthony Goyes
# Procesando imagen - 108 en Anthony Goyes
# Procesando imagen - 109 en Anthony Goyes
# Procesando imagen - 110 en Anthony Goyes
# Procesando imagen - 1 en Ariel Chabla
# Procesando imagen - 2 en Ariel Chabla
# Procesando imagen - 3 en Ariel Chabla
# Procesando imagen - 4 en Ariel Chabla
# Procesando imagen - 5 en Ariel Chabla
# Procesando imagen - 6 en Ariel Chabla
# Procesando imagen - 7 en Ariel Chabla
# Procesando imagen - 8 en Ariel Chabla
# Procesando imagen - 9 en Ariel Chabla
# Procesando imagen - 10 en Ariel Chabla
# Procesando imagen - 11 en Ariel Chabla
# Procesando imagen - 12 en Ariel Chabla
# Procesando imagen - 13 en Ariel Chabla
# Procesando imagen - 14 en Ariel Chabla
# Procesando imagen - 15 en Ariel Chabla
# Procesando imagen - 16 en Ariel Chabla
# Procesando imagen - 17 en Ariel Chabla
# Procesando imagen - 18 en Ariel Chabla
# Procesando imagen - 19 en Ariel Chabla
# Procesando imagen - 20 en Ariel Chabla
# Procesando imagen - 21 en Ariel Chabla
# Procesando imagen - 22 en Ariel Chabla
# Procesando imagen - 23 en Ariel Chabla
# Procesando imagen - 24 en Ariel Chabla
# Procesando imagen - 25 en Ariel Chabla
# Procesando imagen - 26 en Ariel Chabla
# Procesando imagen - 27 en Ariel Chabla
# Procesando imagen - 28 en Ariel Chabla
# Procesando imagen - 29 en Ariel Chabla
# Procesando imagen - 30 en Ariel Chabla
# Procesando imagen - 31 en Ariel Chabla
# Procesando imagen - 32 en Ariel Chabla
# Procesando imagen - 33 en Ariel Chabla
# Procesando imagen - 34 en Ariel Chabla
# Procesando imagen - 35 en Ariel Chabla
# Procesando imagen - 36 en Ariel Chabla
# Procesando imagen - 37 en Ariel Chabla
# Procesando imagen - 38 en Ariel Chabla
# Procesando imagen - 39 en Ariel Chabla
# Procesando imagen - 40 en Ariel Chabla
# Procesando imagen - 41 en Ariel Chabla
# Procesando imagen - 42 en Ariel Chabla
# Procesando imagen - 43 en Ariel Chabla
# Procesando imagen - 44 en Ariel Chabla
# Procesando imagen - 45 en Ariel Chabla
# Procesando imagen - 46 en Ariel Chabla
# Procesando imagen - 47 en Ariel Chabla
# Procesando imagen - 48 en Ariel Chabla
# Procesando imagen - 49 en Ariel Chabla
# Procesando imagen - 50 en Ariel Chabla
# Procesando imagen - 51 en Ariel Chabla
# Procesando imagen - 52 en Ariel Chabla
# Procesando imagen - 53 en Ariel Chabla
# Procesando imagen - 54 en Ariel Chabla
# Procesando imagen - 55 en Ariel Chabla
# Procesando imagen - 56 en Ariel Chabla
# Procesando imagen - 57 en Ariel Chabla
# Procesando imagen - 58 en Ariel Chabla
# Procesando imagen - 59 en Ariel Chabla
# Procesando imagen - 60 en Ariel Chabla
# Procesando imagen - 61 en Ariel Chabla
# Procesando imagen - 62 en Ariel Chabla
# Procesando imagen - 63 en Ariel Chabla
# Procesando imagen - 64 en Ariel Chabla
# Procesando imagen - 65 en Ariel Chabla
# Procesando imagen - 66 en Ariel Chabla
# Procesando imagen - 67 en Ariel Chabla
# Procesando imagen - 68 en Ariel Chabla
# Procesando imagen - 69 en Ariel Chabla
# Procesando imagen - 70 en Ariel Chabla
# Procesando imagen - 71 en Ariel Chabla
# Procesando imagen - 72 en Ariel Chabla
# Procesando imagen - 73 en Ariel Chabla
# Procesando imagen - 74 en Ariel Chabla
# Procesando imagen - 75 en Ariel Chabla
# Procesando imagen - 76 en Ariel Chabla
# Procesando imagen - 77 en Ariel Chabla
# Procesando imagen - 78 en Ariel Chabla
# Procesando imagen - 79 en Ariel Chabla
# Procesando imagen - 80 en Ariel Chabla
# Procesando imagen - 81 en Ariel Chabla
# Procesando imagen - 82 en Ariel Chabla
# Procesando imagen - 83 en Ariel Chabla
# Procesando imagen - 84 en Ariel Chabla
# Procesando imagen - 85 en Ariel Chabla
# Procesando imagen - 86 en Ariel Chabla
# Procesando imagen - 87 en Ariel Chabla
# Procesando imagen - 88 en Ariel Chabla
# Procesando imagen - 1 en Bryan Solorzano
# Procesando imagen - 2 en Bryan Solorzano
# Procesando imagen - 3 en Bryan Solorzano
# Procesando imagen - 4 en Bryan Solorzano
# Procesando imagen - 5 en Bryan Solorzano
# Procesando imagen - 6 en Bryan Solorzano
# Procesando imagen - 7 en Bryan Solorzano
# Procesando imagen - 8 en Bryan Solorzano
# Procesando imagen - 9 en Bryan Solorzano
# Procesando imagen - 10 en Bryan Solorzano
# Procesando imagen - 11 en Bryan Solorzano
# Procesando imagen - 12 en Bryan Solorzano
# Procesando imagen - 13 en Bryan Solorzano
# Procesando imagen - 14 en Bryan Solorzano
# Procesando imagen - 15 en Bryan Solorzano
# Procesando imagen - 16 en Bryan Solorzano
# Procesando imagen - 17 en Bryan Solorzano
# Procesando imagen - 18 en Bryan Solorzano
# Procesando imagen - 19 en Bryan Solorzano
# Procesando imagen - 20 en Bryan Solorzano
# Procesando imagen - 21 en Bryan Solorzano
# Procesando imagen - 22 en Bryan Solorzano
# Procesando imagen - 23 en Bryan Solorzano
# Procesando imagen - 24 en Bryan Solorzano
# Procesando imagen - 25 en Bryan Solorzano
# Procesando imagen - 26 en Bryan Solorzano
# Procesando imagen - 27 en Bryan Solorzano
# Procesando imagen - 28 en Bryan Solorzano
# Procesando imagen - 29 en Bryan Solorzano
# Procesando imagen - 30 en Bryan Solorzano
# Procesando imagen - 31 en Bryan Solorzano
# Procesando imagen - 32 en Bryan Solorzano
# Procesando imagen - 33 en Bryan Solorzano
# Procesando imagen - 34 en Bryan Solorzano
# Procesando imagen - 35 en Bryan Solorzano
# Procesando imagen - 36 en Bryan Solorzano
# Procesando imagen - 37 en Bryan Solorzano
# Procesando imagen - 38 en Bryan Solorzano
# Procesando imagen - 39 en Bryan Solorzano
# Procesando imagen - 40 en Bryan Solorzano
# Procesando imagen - 41 en Bryan Solorzano
# Procesando imagen - 42 en Bryan Solorzano
# Procesando imagen - 43 en Bryan Solorzano
# Procesando imagen - 44 en Bryan Solorzano
# Procesando imagen - 45 en Bryan Solorzano
# Procesando imagen - 46 en Bryan Solorzano
# Procesando imagen - 47 en Bryan Solorzano
# Procesando imagen - 48 en Bryan Solorzano
# Procesando imagen - 49 en Bryan Solorzano
# Procesando imagen - 50 en Bryan Solorzano
# Procesando imagen - 51 en Bryan Solorzano
# Procesando imagen - 52 en Bryan Solorzano
# Procesando imagen - 53 en Bryan Solorzano
# Procesando imagen - 54 en Bryan Solorzano
# Procesando imagen - 55 en Bryan Solorzano
# Procesando imagen - 56 en Bryan Solorzano
# Procesando imagen - 57 en Bryan Solorzano
# Procesando imagen - 58 en Bryan Solorzano
# Procesando imagen - 59 en Bryan Solorzano
# Procesando imagen - 60 en Bryan Solorzano
# Procesando imagen - 61 en Bryan Solorzano
# Procesando imagen - 62 en Bryan Solorzano
# Procesando imagen - 63 en Bryan Solorzano
# Procesando imagen - 64 en Bryan Solorzano
# Procesando imagen - 65 en Bryan Solorzano
# Procesando imagen - 66 en Bryan Solorzano
# Procesando imagen - 67 en Bryan Solorzano
# Procesando imagen - 68 en Bryan Solorzano
# Procesando imagen - 69 en Bryan Solorzano
# Procesando imagen - 70 en Bryan Solorzano
# Procesando imagen - 71 en Bryan Solorzano
# Procesando imagen - 72 en Bryan Solorzano
# Procesando imagen - 73 en Bryan Solorzano
# Procesando imagen - 74 en Bryan Solorzano
# Procesando imagen - 75 en Bryan Solorzano
# Procesando imagen - 76 en Bryan Solorzano
# Procesando imagen - 77 en Bryan Solorzano
# Procesando imagen - 78 en Bryan Solorzano
# Procesando imagen - 79 en Bryan Solorzano
# Procesando imagen - 80 en Bryan Solorzano
# Procesando imagen - 81 en Bryan Solorzano
# Procesando imagen - 82 en Bryan Solorzano
# Procesando imagen - 83 en Bryan Solorzano
# Procesando imagen - 84 en Bryan Solorzano
# Procesando imagen - 85 en Bryan Solorzano
# Procesando imagen - 86 en Bryan Solorzano
# Procesando imagen - 87 en Bryan Solorzano
# Procesando imagen - 88 en Bryan Solorzano
# Procesando imagen - 89 en Bryan Solorzano
# Procesando imagen - 90 en Bryan Solorzano
# Procesando imagen - 91 en Bryan Solorzano
# Procesando imagen - 92 en Bryan Solorzano
# Procesando imagen - 93 en Bryan Solorzano
# Procesando imagen - 94 en Bryan Solorzano
# Procesando imagen - 95 en Bryan Solorzano
# Procesando imagen - 96 en Bryan Solorzano
# Procesando imagen - 97 en Bryan Solorzano
# Procesando imagen - 98 en Bryan Solorzano
# Procesando imagen - 1 en Davila Raymond
# Procesando imagen - 2 en Davila Raymond
# Procesando imagen - 3 en Davila Raymond
# Procesando imagen - 4 en Davila Raymond
# Procesando imagen - 5 en Davila Raymond
# Procesando imagen - 6 en Davila Raymond
# Procesando imagen - 7 en Davila Raymond
# Procesando imagen - 8 en Davila Raymond
# Procesando imagen - 9 en Davila Raymond
# Procesando imagen - 10 en Davila Raymond
# Procesando imagen - 11 en Davila Raymond
# Procesando imagen - 12 en Davila Raymond
# Procesando imagen - 13 en Davila Raymond
# Procesando imagen - 14 en Davila Raymond
# Procesando imagen - 15 en Davila Raymond
# Procesando imagen - 16 en Davila Raymond
# Procesando imagen - 17 en Davila Raymond
# Procesando imagen - 18 en Davila Raymond
# Procesando imagen - 19 en Davila Raymond
# Procesando imagen - 20 en Davila Raymond
# Procesando imagen - 21 en Davila Raymond
# Procesando imagen - 22 en Davila Raymond
# Procesando imagen - 23 en Davila Raymond
# Procesando imagen - 24 en Davila Raymond
# Procesando imagen - 25 en Davila Raymond
# Procesando imagen - 26 en Davila Raymond
# Procesando imagen - 27 en Davila Raymond
# Procesando imagen - 28 en Davila Raymond
# Procesando imagen - 29 en Davila Raymond
# Procesando imagen - 30 en Davila Raymond
# Procesando imagen - 31 en Davila Raymond
# Procesando imagen - 7 en Fernando Masache
# Procesando imagen - 8 en Fernando Masache
# Procesando imagen - 9 en Fernando Masache
# Procesando imagen - 10 en Fernando Masache
# Procesando imagen - 11 en Fernando Masache
# Procesando imagen - 12 en Fernando Masache
# Procesando imagen - 13 en Fernando Masache
# Procesando imagen - 14 en Fernando Masache
# Procesando imagen - 15 en Fernando Masache
# Procesando imagen - 16 en Fernando Masache
# Procesando imagen - 17 en Fernando Masache
# Procesando imagen - 18 en Fernando Masache
# Procesando imagen - 19 en Fernando Masache
# Procesando imagen - 20 en Fernando Masache
# Procesando imagen - 21 en Fernando Masache
# Procesando imagen - 22 en Fernando Masache
# Procesando imagen - 23 en Fernando Masache
# Procesando imagen - 24 en Fernando Masache
# Procesando imagen - 25 en Fernando Masache
# Procesando imagen - 26 en Fernando Masache
# Procesando imagen - 27 en Fernando Masache
# Procesando imagen - 28 en Fernando Masache
# Procesando imagen - 29 en Fernando Masache
# Procesando imagen - 30 en Fernando Masache
# Procesando imagen - 31 en Fernando Masache
# Procesando imagen - 32 en Fernando Masache
# Procesando imagen - 33 en Fernando Masache
# Procesando imagen - 34 en Fernando Masache
# Procesando imagen - 35 en Fernando Masache
# Procesando imagen - 36 en Fernando Masache
# Procesando imagen - 37 en Fernando Masache
# Procesando imagen - 38 en Fernando Masache
# Procesando imagen - 39 en Fernando Masache
# Procesando imagen - 40 en Fernando Masache
# Procesando imagen - 41 en Fernando Masache
# Procesando imagen - 42 en Fernando Masache
# Procesando imagen - 43 en Fernando Masache
# Procesando imagen - 44 en Fernando Masache
# Procesando imagen - 45 en Fernando Masache
# Procesando imagen - 46 en Fernando Masache
# Procesando imagen - 47 en Fernando Masache
# Procesando imagen - 48 en Fernando Masache
# Procesando imagen - 49 en Fernando Masache
# Procesando imagen - 50 en Fernando Masache
# Procesando imagen - 51 en Fernando Masache
# Procesando imagen - 52 en Fernando Masache
# Procesando imagen - 53 en Fernando Masache
# Procesando imagen - 54 en Fernando Masache
# Procesando imagen - 55 en Fernando Masache
# Procesando imagen - 56 en Fernando Masache
# Procesando imagen - 57 en Fernando Masache
# Procesando imagen - 58 en Fernando Masache
# Procesando imagen - 59 en Fernando Masache
# Procesando imagen - 60 en Fernando Masache
# Procesando imagen - 61 en Fernando Masache
# Procesando imagen - 62 en Fernando Masache
# Procesando imagen - 63 en Fernando Masache
# Procesando imagen - 64 en Fernando Masache
# Procesando imagen - 65 en Fernando Masache
# Procesando imagen - 66 en Fernando Masache
# Procesando imagen - 67 en Fernando Masache
# Procesando imagen - 68 en Fernando Masache
# Procesando imagen - 69 en Fernando Masache
# Procesando imagen - 70 en Fernando Masache
# Procesando imagen - 71 en Fernando Masache
# Procesando imagen - 72 en Fernando Masache
# Procesando imagen - 73 en Fernando Masache
# Procesando imagen - 74 en Fernando Masache
# Procesando imagen - 75 en Fernando Masache
# Procesando imagen - 76 en Fernando Masache
# Procesando imagen - 77 en Fernando Masache
# Procesando imagen - 78 en Fernando Masache
# Procesando imagen - 79 en Fernando Masache
# Procesando imagen - 80 en Fernando Masache
# Procesando imagen - 81 en Fernando Masache
# Procesando imagen - 82 en Fernando Masache
# Procesando imagen - 83 en Fernando Masache
# Procesando imagen - 84 en Fernando Masache
# Procesando imagen - 85 en Fernando Masache
# Procesando imagen - 86 en Fernando Masache
# Procesando imagen - 87 en Fernando Masache
# Procesando imagen - 88 en Fernando Masache
# Procesando imagen - 89 en Fernando Masache
# Procesando imagen - 90 en Fernando Masache
# Procesando imagen - 91 en Fernando Masache
# Procesando imagen - 92 en Fernando Masache
# Procesando imagen - 93 en Fernando Masache
# Procesando imagen - 94 en Fernando Masache
# Procesando imagen - 95 en Fernando Masache
# Procesando imagen - 96 en Fernando Masache
# Procesando imagen - 97 en Fernando Masache
# Procesando imagen - 98 en Fernando Masache
# Procesando imagen - 99 en Fernando Masache
# Procesando imagen - 100 en Fernando Masache
# Procesando imagen - 101 en Fernando Masache
# Procesando imagen - 102 en Fernando Masache
# Procesando imagen - 103 en Fernando Masache
# Procesando imagen - 104 en Fernando Masache
# Procesando imagen - 105 en Fernando Masache
# Procesando imagen - 106 en Fernando Masache
# Procesando imagen - 107 en Fernando Masache
# Procesando imagen - 108 en Fernando Masache
# Procesando imagen - 109 en Fernando Masache
# Procesando imagen - 110 en Fernando Masache
# Procesando imagen - 1 en Genesis Heredia
# Procesando imagen - 2 en Genesis Heredia
# Procesando imagen - 3 en Genesis Heredia
# Procesando imagen - 4 en Genesis Heredia
# Procesando imagen - 5 en Genesis Heredia
# Procesando imagen - 6 en Genesis Heredia
# Procesando imagen - 7 en Genesis Heredia
# Procesando imagen - 8 en Genesis Heredia
# Procesando imagen - 9 en Genesis Heredia
# Procesando imagen - 10 en Genesis Heredia
# Procesando imagen - 11 en Genesis Heredia
# Procesando imagen - 12 en Genesis Heredia
# Procesando imagen - 13 en Genesis Heredia
# Procesando imagen - 14 en Genesis Heredia
# Procesando imagen - 15 en Genesis Heredia
# Procesando imagen - 16 en Genesis Heredia
# Procesando imagen - 17 en Genesis Heredia
# Procesando imagen - 18 en Genesis Heredia
# Procesando imagen - 19 en Genesis Heredia
# Procesando imagen - 20 en Genesis Heredia
# Procesando imagen - 21 en Genesis Heredia
# Procesando imagen - 22 en Genesis Heredia
# Procesando imagen - 23 en Genesis Heredia
# Procesando imagen - 24 en Genesis Heredia
# Procesando imagen - 25 en Genesis Heredia
# Procesando imagen - 26 en Genesis Heredia
# Procesando imagen - 27 en Genesis Heredia
# Procesando imagen - 28 en Genesis Heredia
# Procesando imagen - 29 en Genesis Heredia
# Procesando imagen - 30 en Genesis Heredia
# Procesando imagen - 31 en Genesis Heredia
# Procesando imagen - 32 en Genesis Heredia
# Procesando imagen - 33 en Genesis Heredia
# Procesando imagen - 34 en Genesis Heredia
# Procesando imagen - 35 en Genesis Heredia
# Procesando imagen - 36 en Genesis Heredia
# Procesando imagen - 37 en Genesis Heredia
# Procesando imagen - 38 en Genesis Heredia
# Procesando imagen - 39 en Genesis Heredia
# Procesando imagen - 40 en Genesis Heredia
# Procesando imagen - 41 en Genesis Heredia
# Procesando imagen - 42 en Genesis Heredia
# Procesando imagen - 43 en Genesis Heredia
# Procesando imagen - 44 en Genesis Heredia
# Procesando imagen - 45 en Genesis Heredia
# Procesando imagen - 46 en Genesis Heredia
# Procesando imagen - 47 en Genesis Heredia
# Procesando imagen - 48 en Genesis Heredia
# Procesando imagen - 49 en Genesis Heredia
# Procesando imagen - 50 en Genesis Heredia
# Procesando imagen - 51 en Genesis Heredia
# Procesando imagen - 52 en Genesis Heredia
# Procesando imagen - 53 en Genesis Heredia
# Procesando imagen - 54 en Genesis Heredia
# Procesando imagen - 55 en Genesis Heredia
# Procesando imagen - 56 en Genesis Heredia
# Procesando imagen - 57 en Genesis Heredia
# Procesando imagen - 58 en Genesis Heredia
# Procesando imagen - 59 en Genesis Heredia
# Procesando imagen - 60 en Genesis Heredia
# Procesando imagen - 61 en Genesis Heredia
# Procesando imagen - 62 en Genesis Heredia
# Procesando imagen - 63 en Genesis Heredia
# Procesando imagen - 64 en Genesis Heredia
# Procesando imagen - 65 en Genesis Heredia
# Procesando imagen - 66 en Genesis Heredia
# Procesando imagen - 67 en Genesis Heredia
# Procesando imagen - 68 en Genesis Heredia
# Procesando imagen - 69 en Genesis Heredia
# Procesando imagen - 70 en Genesis Heredia
# Procesando imagen - 71 en Genesis Heredia
# Procesando imagen - 72 en Genesis Heredia
# Procesando imagen - 73 en Genesis Heredia
# Procesando imagen - 74 en Genesis Heredia
# Procesando imagen - 75 en Genesis Heredia
# Procesando imagen - 76 en Genesis Heredia
# Procesando imagen - 77 en Genesis Heredia
# Procesando imagen - 78 en Genesis Heredia
# Procesando imagen - 79 en Genesis Heredia
# Procesando imagen - 80 en Genesis Heredia
# Procesando imagen - 81 en Genesis Heredia
# Procesando imagen - 82 en Genesis Heredia
# Procesando imagen - 83 en Genesis Heredia
# Procesando imagen - 84 en Genesis Heredia
# Procesando imagen - 85 en Genesis Heredia
# Procesando imagen - 86 en Genesis Heredia
# Procesando imagen - 87 en Genesis Heredia
# Procesando imagen - 88 en Genesis Heredia
# Procesando imagen - 89 en Genesis Heredia
# Procesando imagen - 90 en Genesis Heredia
# Procesando imagen - 91 en Genesis Heredia
# Procesando imagen - 92 en Genesis Heredia
# Procesando imagen - 93 en Genesis Heredia
# Procesando imagen - 94 en Genesis Heredia
# Procesando imagen - 95 en Genesis Heredia
# Procesando imagen - 96 en Genesis Heredia
# Procesando imagen - 97 en Genesis Heredia
# Procesando imagen - 98 en Genesis Heredia
# Procesando imagen - 99 en Genesis Heredia
# Procesando imagen - 100 en Genesis Heredia
# Procesando imagen - 101 en Genesis Heredia
# Procesando imagen - 102 en Genesis Heredia
# Procesando imagen - 103 en Genesis Heredia
# Procesando imagen - 104 en Genesis Heredia
# Procesando imagen - 105 en Genesis Heredia
# Procesando imagen - 106 en Genesis Heredia
# Procesando imagen - 107 en Genesis Heredia
# Procesando imagen - 108 en Genesis Heredia
# Procesando imagen - 1 en Hector Cedenio
# Procesando imagen - 2 en Hector Cedenio
# Procesando imagen - 92 en Joan Cevallos
# Procesando imagen - 93 en Joan Cevallos
# Procesando imagen - 94 en Joan Cevallos
# Procesando imagen - 95 en Joan Cevallos
# Procesando imagen - 96 en Joan Cevallos
# Procesando imagen - 97 en Joan Cevallos
# Procesando imagen - 98 en Joan Cevallos
# Procesando imagen - 99 en Joan Cevallos
# Procesando imagen - 1 en Johana Salazar
# Procesando imagen - 2 en Johana Salazar
# Procesando imagen - 3 en Johana Salazar
# Procesando imagen - 4 en Johana Salazar
# Procesando imagen - 5 en Johana Salazar
# Procesando imagen - 6 en Johana Salazar
# Procesando imagen - 7 en Johana Salazar
# Procesando imagen - 8 en Johana Salazar
# Procesando imagen - 9 en Johana Salazar
# Procesando imagen - 10 en Johana Salazar
# Procesando imagen - 11 en Johana Salazar
# Procesando imagen - 12 en Johana Salazar
# Procesando imagen - 13 en Johana Salazar
# Procesando imagen - 14 en Johana Salazar
# Procesando imagen - 15 en Johana Salazar
# Procesando imagen - 16 en Johana Salazar
# Procesando imagen - 17 en Johana Salazar
# Procesando imagen - 18 en Johana Salazar
# Procesando imagen - 19 en Johana Salazar
# Procesando imagen - 20 en Johana Salazar
# Procesando imagen - 21 en Johana Salazar
# Procesando imagen - 22 en Johana Salazar
# Procesando imagen - 23 en Johana Salazar
# Procesando imagen - 24 en Johana Salazar
# Procesando imagen - 25 en Johana Salazar
# Procesando imagen - 26 en Johana Salazar
# Procesando imagen - 27 en Johana Salazar
# Procesando imagen - 28 en Johana Salazar
# Procesando imagen - 29 en Johana Salazar
# Procesando imagen - 30 en Johana Salazar
# Procesando imagen - 31 en Johana Salazar
# Procesando imagen - 32 en Johana Salazar
# Procesando imagen - 33 en Johana Salazar
# Procesando imagen - 34 en Johana Salazar
# Procesando imagen - 35 en Johana Salazar
# Procesando imagen - 36 en Johana Salazar
# Procesando imagen - 37 en Johana Salazar
# Procesando imagen - 38 en Johana Salazar
# Procesando imagen - 39 en Johana Salazar
# Procesando imagen - 40 en Johana Salazar
# Procesando imagen - 41 en Johana Salazar
# Procesando imagen - 42 en Johana Salazar
# Procesando imagen - 43 en Johana Salazar
# Procesando imagen - 44 en Johana Salazar
# Procesando imagen - 45 en Johana Salazar
# Procesando imagen - 46 en Johana Salazar
# Procesando imagen - 47 en Johana Salazar
# Procesando imagen - 48 en Johana Salazar
# Procesando imagen - 49 en Johana Salazar
# Procesando imagen - 50 en Johana Salazar
# Procesando imagen - 51 en Johana Salazar
# Procesando imagen - 52 en Johana Salazar
# Procesando imagen - 53 en Johana Salazar
# Procesando imagen - 54 en Johana Salazar
# Procesando imagen - 55 en Johana Salazar
# Procesando imagen - 56 en Johana Salazar
# Procesando imagen - 57 en Johana Salazar
# Procesando imagen - 58 en Johana Salazar
# Procesando imagen - 59 en Johana Salazar
# Procesando imagen - 60 en Johana Salazar
# Procesando imagen - 61 en Johana Salazar
# Procesando imagen - 62 en Johana Salazar
# Procesando imagen - 63 en Johana Salazar
# Procesando imagen - 64 en Johana Salazar
# Procesando imagen - 115 en Steven Barragan
# Procesando imagen - 116 en Steven Barragan
# Procesando imagen - 117 en Steven Barragan
# Procesando imagen - 118 en Steven Barragan
# Procesando imagen - 119 en Steven Barragan
# Procesando imagen - 120 en Steven Barragan
# Procesando imagen - 121 en Steven Barragan
# Procesando imagen - 122 en Steven Barragan
# Procesando imagen - 123 en Steven Barragan
# Procesando imagen - 124 en Steven Barragan
# Procesando imagen - 125 en Steven Barragan
# Procesando imagen - 126 en Steven Barragan
# Procesando imagen - 127 en Steven Barragan
# Procesando imagen - 128 en Steven Barragan
# Procesando imagen - 129 en Steven Barragan
# Procesando imagen - 130 en Steven Barragan
# Procesando imagen - 131 en Steven Barragan
# Procesando imagen - 132 en Steven Barragan
# Procesando imagen - 133 en Steven Barragan
# Procesando imagen - 134 en Steven Barragan
# Procesando imagen - 135 en Steven Barragan
# Procesando imagen - 136 en Steven Barragan
# Procesando imagen - 137 en Steven Barragan
# Procesando imagen - 138 en Steven Barragan
# Procesando imagen - 139 en Steven Barragan
# Procesando imagen - 140 en Steven Barragan
# Procesando imagen - 141 en Steven Barragan
# Procesando imagen - 142 en Steven Barragan
# Procesando imagen - 143 en Steven Barragan
# Procesando imagen - 144 en Steven Barragan
# Procesando imagen - 145 en Steven Barragan
# Procesando imagen - 146 en Steven Barragan
# Procesando imagen - 147 en Steven Barragan
# Procesando imagen - 148 en Steven Barragan
# Procesando imagen - 149 en Steven Barragan
# Procesando imagen - 150 en Steven Barragan
# Procesando imagen - 151 en Steven Barragan
# Procesando imagen - 152 en Steven Barragan
# Procesando imagen - 153 en Steven Barragan
# Procesando imagen - 154 en Steven Barragan

# %% [markdown]
# ## Eliminando el fondo sin aplicar filtro NLM

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_aumentados"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se almacenan las etiquetas de las clases'''
    etiqueta_actual = nombre_clase
    '''Se genera un iterador'''
    iterador = 1
    '''Se recorre cada imagen por clase sin importar su nombre o extensión'''
    for file in glob.glob(ruta_actual + "/*"):
        '''Se imprime el proceso'''
        print("Procesando imaegen - {} en {}".format(iterador, etiqueta_actual))
        '''Se leen las rutas de las imágenes'''
        imagen = cv2.imread(file)
        '''Se remueve el fondo'''
        salida = remove(imagen)
        '''Se guardan las imagenes'''
        ruta_guardado = './Estudiantes_datos_fondoEliminadoSinNLM/'+ etiqueta_actual
        '''Se genera cada imagen según la ruta de guardado'''
        cv2.imwrite(os.path.join(ruta_guardado , etiqueta_actual + '_' + str(iterador) + '.jpg'), salida)       
        '''Se aumenta el iterador'''
        iterador += 1
# Out:
# Procesando imaegen - 1 en Anthony Goyes
# Procesando imaegen - 2 en Anthony Goyes
# Procesando imaegen - 3 en Anthony Goyes
# Procesando imaegen - 4 en Anthony Goyes
# Procesando imaegen - 5 en Anthony Goyes
# Procesando imaegen - 6 en Anthony Goyes
# Procesando imaegen - 7 en Anthony Goyes
# Procesando imaegen - 8 en Anthony Goyes
# Procesando imaegen - 9 en Anthony Goyes
# Procesando imaegen - 10 en Anthony Goyes
# Procesando imaegen - 11 en Anthony Goyes
# Procesando imaegen - 12 en Anthony Goyes
# Procesando imaegen - 13 en Anthony Goyes
# Procesando imaegen - 14 en Anthony Goyes
# Procesando imaegen - 15 en Anthony Goyes
# Procesando imaegen - 16 en Anthony Goyes
# Procesando imaegen - 17 en Anthony Goyes
# Procesando imaegen - 18 en Anthony Goyes
# Procesando imaegen - 19 en Anthony Goyes
# Procesando imaegen - 20 en Anthony Goyes
# Procesando imaegen - 21 en Anthony Goyes
# Procesando imaegen - 22 en Anthony Goyes
# Procesando imaegen - 23 en Anthony Goyes
# Procesando imaegen - 24 en Anthony Goyes
# Procesando imaegen - 25 en Anthony Goyes
# Procesando imaegen - 26 en Anthony Goyes
# Procesando imaegen - 27 en Anthony Goyes
# Procesando imaegen - 28 en Anthony Goyes
# Procesando imaegen - 29 en Anthony Goyes
# Procesando imaegen - 30 en Anthony Goyes
# Procesando imaegen - 31 en Anthony Goyes
# Procesando imaegen - 32 en Anthony Goyes
# Procesando imaegen - 33 en Anthony Goyes
# Procesando imaegen - 34 en Anthony Goyes
# Procesando imaegen - 35 en Anthony Goyes
# Procesando imaegen - 36 en Anthony Goyes
# Procesando imaegen - 37 en Anthony Goyes
# Procesando imaegen - 38 en Anthony Goyes
# Procesando imaegen - 39 en Anthony Goyes
# Procesando imaegen - 40 en Anthony Goyes
# Procesando imaegen - 41 en Anthony Goyes
# Procesando imaegen - 42 en Anthony Goyes
# Procesando imaegen - 43 en Anthony Goyes
# Procesando imaegen - 44 en Anthony Goyes
# Procesando imaegen - 45 en Anthony Goyes
# Procesando imaegen - 46 en Anthony Goyes
# Procesando imaegen - 47 en Anthony Goyes
# Procesando imaegen - 48 en Anthony Goyes
# Procesando imaegen - 49 en Anthony Goyes
# Procesando imaegen - 50 en Anthony Goyes
# Procesando imaegen - 51 en Anthony Goyes
# Procesando imaegen - 52 en Anthony Goyes
# Procesando imaegen - 53 en Anthony Goyes
# Procesando imaegen - 54 en Anthony Goyes
# Procesando imaegen - 55 en Anthony Goyes
# Procesando imaegen - 56 en Anthony Goyes
# Procesando imaegen - 57 en Anthony Goyes
# Procesando imaegen - 58 en Anthony Goyes
# Procesando imaegen - 59 en Anthony Goyes
# Procesando imaegen - 60 en Anthony Goyes
# Procesando imaegen - 61 en Anthony Goyes
# Procesando imaegen - 62 en Anthony Goyes
# Procesando imaegen - 63 en Anthony Goyes
# Procesando imaegen - 64 en Anthony Goyes
# Procesando imaegen - 65 en Anthony Goyes
# Procesando imaegen - 66 en Anthony Goyes
# Procesando imaegen - 67 en Anthony Goyes
# Procesando imaegen - 68 en Anthony Goyes
# Procesando imaegen - 69 en Anthony Goyes
# Procesando imaegen - 70 en Anthony Goyes
# Procesando imaegen - 71 en Anthony Goyes
# Procesando imaegen - 72 en Anthony Goyes
# Procesando imaegen - 73 en Anthony Goyes
# Procesando imaegen - 74 en Anthony Goyes
# Procesando imaegen - 75 en Anthony Goyes
# Procesando imaegen - 76 en Anthony Goyes
# Procesando imaegen - 77 en Anthony Goyes
# Procesando imaegen - 78 en Anthony Goyes
# Procesando imaegen - 79 en Anthony Goyes
# Procesando imaegen - 80 en Anthony Goyes
# Procesando imaegen - 81 en Anthony Goyes
# Procesando imaegen - 82 en Anthony Goyes
# Procesando imaegen - 83 en Anthony Goyes
# Procesando imaegen - 84 en Anthony Goyes
# Procesando imaegen - 85 en Anthony Goyes
# Procesando imaegen - 86 en Anthony Goyes
# Procesando imaegen - 87 en Anthony Goyes
# Procesando imaegen - 88 en Anthony Goyes
# Procesando imaegen - 89 en Anthony Goyes
# Procesando imaegen - 90 en Anthony Goyes
# Procesando imaegen - 91 en Anthony Goyes
# Procesando imaegen - 92 en Anthony Goyes
# Procesando imaegen - 93 en Anthony Goyes
# Procesando imaegen - 94 en Anthony Goyes
# Procesando imaegen - 95 en Anthony Goyes
# Procesando imaegen - 96 en Anthony Goyes
# Procesando imaegen - 97 en Anthony Goyes
# Procesando imaegen - 98 en Anthony Goyes
# Procesando imaegen - 99 en Anthony Goyes
# Procesando imaegen - 100 en Anthony Goyes
# Procesando imaegen - 101 en Anthony Goyes
# Procesando imaegen - 102 en Anthony Goyes
# Procesando imaegen - 103 en Anthony Goyes
# Procesando imaegen - 104 en Anthony Goyes
# Procesando imaegen - 105 en Anthony Goyes
# Procesando imaegen - 106 en Anthony Goyes
# Procesando imaegen - 107 en Anthony Goyes
# Procesando imaegen - 108 en Anthony Goyes
# Procesando imaegen - 109 en Anthony Goyes
# Procesando imaegen - 110 en Anthony Goyes
# Procesando imaegen - 1 en Ariel Chabla
# Procesando imaegen - 2 en Ariel Chabla
# Procesando imaegen - 3 en Ariel Chabla
# Procesando imaegen - 4 en Ariel Chabla
# Procesando imaegen - 5 en Ariel Chabla
# Procesando imaegen - 6 en Ariel Chabla
# Procesando imaegen - 7 en Ariel Chabla
# Procesando imaegen - 8 en Ariel Chabla
# Procesando imaegen - 9 en Ariel Chabla
# Procesando imaegen - 10 en Ariel Chabla
# Procesando imaegen - 11 en Ariel Chabla
# Procesando imaegen - 12 en Ariel Chabla
# Procesando imaegen - 13 en Ariel Chabla
# Procesando imaegen - 14 en Ariel Chabla
# Procesando imaegen - 15 en Ariel Chabla
# Procesando imaegen - 16 en Ariel Chabla
# Procesando imaegen - 17 en Ariel Chabla
# Procesando imaegen - 18 en Ariel Chabla
# Procesando imaegen - 19 en Ariel Chabla
# Procesando imaegen - 20 en Ariel Chabla
# Procesando imaegen - 21 en Ariel Chabla
# Procesando imaegen - 22 en Ariel Chabla
# Procesando imaegen - 23 en Ariel Chabla
# Procesando imaegen - 24 en Ariel Chabla
# Procesando imaegen - 25 en Ariel Chabla
# Procesando imaegen - 26 en Ariel Chabla
# Procesando imaegen - 27 en Ariel Chabla
# Procesando imaegen - 28 en Ariel Chabla
# Procesando imaegen - 29 en Ariel Chabla
# Procesando imaegen - 30 en Ariel Chabla
# Procesando imaegen - 31 en Ariel Chabla
# Procesando imaegen - 32 en Ariel Chabla
# Procesando imaegen - 33 en Ariel Chabla
# Procesando imaegen - 34 en Ariel Chabla
# Procesando imaegen - 35 en Ariel Chabla
# Procesando imaegen - 36 en Ariel Chabla
# Procesando imaegen - 37 en Ariel Chabla
# Procesando imaegen - 38 en Ariel Chabla
# Procesando imaegen - 39 en Ariel Chabla
# Procesando imaegen - 40 en Ariel Chabla
# Procesando imaegen - 41 en Ariel Chabla
# Procesando imaegen - 42 en Ariel Chabla
# Procesando imaegen - 43 en Ariel Chabla
# Procesando imaegen - 44 en Ariel Chabla
# Procesando imaegen - 45 en Ariel Chabla
# Procesando imaegen - 46 en Ariel Chabla
# Procesando imaegen - 47 en Ariel Chabla
# Procesando imaegen - 48 en Ariel Chabla
# Procesando imaegen - 49 en Ariel Chabla
# Procesando imaegen - 50 en Ariel Chabla
# Procesando imaegen - 51 en Ariel Chabla
# Procesando imaegen - 52 en Ariel Chabla
# Procesando imaegen - 53 en Ariel Chabla
# Procesando imaegen - 54 en Ariel Chabla
# Procesando imaegen - 55 en Ariel Chabla
# Procesando imaegen - 56 en Ariel Chabla
# Procesando imaegen - 57 en Ariel Chabla
# Procesando imaegen - 58 en Ariel Chabla
# Procesando imaegen - 59 en Ariel Chabla
# Procesando imaegen - 60 en Ariel Chabla
# Procesando imaegen - 61 en Ariel Chabla
# Procesando imaegen - 62 en Ariel Chabla
# Procesando imaegen - 63 en Ariel Chabla
# Procesando imaegen - 64 en Ariel Chabla
# Procesando imaegen - 65 en Ariel Chabla
# Procesando imaegen - 66 en Ariel Chabla
# Procesando imaegen - 67 en Ariel Chabla
# Procesando imaegen - 68 en Ariel Chabla
# Procesando imaegen - 69 en Ariel Chabla
# Procesando imaegen - 70 en Ariel Chabla
# Procesando imaegen - 71 en Ariel Chabla
# Procesando imaegen - 72 en Ariel Chabla
# Procesando imaegen - 73 en Ariel Chabla
# Procesando imaegen - 74 en Ariel Chabla
# Procesando imaegen - 75 en Ariel Chabla
# Procesando imaegen - 76 en Ariel Chabla
# Procesando imaegen - 77 en Ariel Chabla
# Procesando imaegen - 78 en Ariel Chabla
# Procesando imaegen - 79 en Ariel Chabla
# Procesando imaegen - 80 en Ariel Chabla
# Procesando imaegen - 81 en Ariel Chabla
# Procesando imaegen - 82 en Ariel Chabla
# Procesando imaegen - 83 en Ariel Chabla
# Procesando imaegen - 84 en Ariel Chabla
# Procesando imaegen - 85 en Ariel Chabla
# Procesando imaegen - 86 en Ariel Chabla
# Procesando imaegen - 87 en Ariel Chabla
# Procesando imaegen - 88 en Ariel Chabla
# Procesando imaegen - 1 en Bryan Solorzano
# Procesando imaegen - 2 en Bryan Solorzano
# Procesando imaegen - 3 en Bryan Solorzano
# Procesando imaegen - 4 en Bryan Solorzano
# Procesando imaegen - 5 en Bryan Solorzano
# Procesando imaegen - 6 en Bryan Solorzano
# Procesando imaegen - 7 en Bryan Solorzano
# Procesando imaegen - 8 en Bryan Solorzano
# Procesando imaegen - 9 en Bryan Solorzano
# Procesando imaegen - 10 en Bryan Solorzano
# Procesando imaegen - 11 en Bryan Solorzano
# Procesando imaegen - 12 en Bryan Solorzano
# Procesando imaegen - 13 en Bryan Solorzano
# Procesando imaegen - 14 en Bryan Solorzano
# Procesando imaegen - 15 en Bryan Solorzano
# Procesando imaegen - 16 en Bryan Solorzano
# Procesando imaegen - 17 en Bryan Solorzano
# Procesando imaegen - 18 en Bryan Solorzano
# Procesando imaegen - 19 en Bryan Solorzano
# Procesando imaegen - 20 en Bryan Solorzano
# Procesando imaegen - 21 en Bryan Solorzano
# Procesando imaegen - 22 en Bryan Solorzano
# Procesando imaegen - 23 en Bryan Solorzano
# Procesando imaegen - 24 en Bryan Solorzano
# Procesando imaegen - 25 en Bryan Solorzano
# Procesando imaegen - 26 en Bryan Solorzano
# Procesando imaegen - 27 en Bryan Solorzano
# Procesando imaegen - 28 en Bryan Solorzano
# Procesando imaegen - 29 en Bryan Solorzano
# Procesando imaegen - 30 en Bryan Solorzano
# Procesando imaegen - 31 en Bryan Solorzano
# Procesando imaegen - 32 en Bryan Solorzano
# Procesando imaegen - 33 en Bryan Solorzano
# Procesando imaegen - 34 en Bryan Solorzano
# Procesando imaegen - 35 en Bryan Solorzano
# Procesando imaegen - 36 en Bryan Solorzano
# Procesando imaegen - 37 en Bryan Solorzano
# Procesando imaegen - 38 en Bryan Solorzano
# Procesando imaegen - 39 en Bryan Solorzano
# Procesando imaegen - 40 en Bryan Solorzano
# Procesando imaegen - 41 en Bryan Solorzano
# Procesando imaegen - 42 en Bryan Solorzano
# Procesando imaegen - 43 en Bryan Solorzano
# Procesando imaegen - 44 en Bryan Solorzano
# Procesando imaegen - 45 en Bryan Solorzano
# Procesando imaegen - 46 en Bryan Solorzano
# Procesando imaegen - 47 en Bryan Solorzano
# Procesando imaegen - 48 en Bryan Solorzano
# Procesando imaegen - 49 en Bryan Solorzano
# Procesando imaegen - 50 en Bryan Solorzano
# Procesando imaegen - 51 en Bryan Solorzano
# Procesando imaegen - 52 en Bryan Solorzano
# Procesando imaegen - 53 en Bryan Solorzano
# Procesando imaegen - 54 en Bryan Solorzano
# Procesando imaegen - 55 en Bryan Solorzano
# Procesando imaegen - 56 en Bryan Solorzano
# Procesando imaegen - 57 en Bryan Solorzano
# Procesando imaegen - 58 en Bryan Solorzano
# Procesando imaegen - 59 en Bryan Solorzano
# Procesando imaegen - 60 en Bryan Solorzano
# Procesando imaegen - 61 en Bryan Solorzano
# Procesando imaegen - 62 en Bryan Solorzano
# Procesando imaegen - 63 en Bryan Solorzano
# Procesando imaegen - 64 en Bryan Solorzano
# Procesando imaegen - 65 en Bryan Solorzano
# Procesando imaegen - 66 en Bryan Solorzano
# Procesando imaegen - 67 en Bryan Solorzano
# Procesando imaegen - 68 en Bryan Solorzano
# Procesando imaegen - 69 en Bryan Solorzano
# Procesando imaegen - 70 en Bryan Solorzano
# Procesando imaegen - 71 en Bryan Solorzano
# Procesando imaegen - 72 en Bryan Solorzano
# Procesando imaegen - 73 en Bryan Solorzano
# Procesando imaegen - 74 en Bryan Solorzano
# Procesando imaegen - 75 en Bryan Solorzano
# Procesando imaegen - 76 en Bryan Solorzano
# Procesando imaegen - 77 en Bryan Solorzano
# Procesando imaegen - 78 en Bryan Solorzano
# Procesando imaegen - 79 en Bryan Solorzano
# Procesando imaegen - 80 en Bryan Solorzano
# Procesando imaegen - 81 en Bryan Solorzano
# Procesando imaegen - 82 en Bryan Solorzano
# Procesando imaegen - 83 en Bryan Solorzano
# Procesando imaegen - 84 en Bryan Solorzano
# Procesando imaegen - 85 en Bryan Solorzano
# Procesando imaegen - 86 en Bryan Solorzano
# Procesando imaegen - 87 en Bryan Solorzano
# Procesando imaegen - 88 en Bryan Solorzano
# Procesando imaegen - 89 en Bryan Solorzano
# Procesando imaegen - 90 en Bryan Solorzano
# Procesando imaegen - 91 en Bryan Solorzano
# Procesando imaegen - 92 en Bryan Solorzano
# Procesando imaegen - 93 en Bryan Solorzano
# Procesando imaegen - 94 en Bryan Solorzano
# Procesando imaegen - 95 en Bryan Solorzano
# Procesando imaegen - 96 en Bryan Solorzano
# Procesando imaegen - 97 en Bryan Solorzano
# Procesando imaegen - 98 en Bryan Solorzano
# Procesando imaegen - 1 en Davila Raymond
# Procesando imaegen - 2 en Davila Raymond
# Procesando imaegen - 3 en Davila Raymond
# Procesando imaegen - 4 en Davila Raymond
# Procesando imaegen - 5 en Davila Raymond
# Procesando imaegen - 6 en Davila Raymond
# Procesando imaegen - 7 en Davila Raymond
# Procesando imaegen - 8 en Davila Raymond
# Procesando imaegen - 9 en Davila Raymond
# Procesando imaegen - 10 en Davila Raymond
# Procesando imaegen - 11 en Davila Raymond
# Procesando imaegen - 12 en Davila Raymond
# Procesando imaegen - 13 en Davila Raymond
# Procesando imaegen - 14 en Davila Raymond
# Procesando imaegen - 15 en Davila Raymond
# Procesando imaegen - 16 en Davila Raymond
# Procesando imaegen - 17 en Davila Raymond
# Procesando imaegen - 18 en Davila Raymond
# Procesando imaegen - 19 en Davila Raymond
# Procesando imaegen - 20 en Davila Raymond
# Procesando imaegen - 21 en Davila Raymond
# Procesando imaegen - 22 en Davila Raymond
# Procesando imaegen - 23 en Davila Raymond
# Procesando imaegen - 24 en Davila Raymond
# Procesando imaegen - 25 en Davila Raymond
# Procesando imaegen - 26 en Davila Raymond
# Procesando imaegen - 27 en Davila Raymond
# Procesando imaegen - 28 en Davila Raymond
# Procesando imaegen - 29 en Davila Raymond
# Procesando imaegen - 30 en Davila Raymond
# Procesando imaegen - 31 en Davila Raymond
# Procesando imaegen - 32 en Davila Raymond
# Procesando imaegen - 33 en Davila Raymond
# Procesando imaegen - 34 en Davila Raymond
# Procesando imaegen - 35 en Davila Raymond
# Procesando imaegen - 36 en Davila Raymond
# Procesando imaegen - 37 en Davila Raymond
# Procesando imaegen - 38 en Davila Raymond
# Procesando imaegen - 39 en Davila Raymond
# Procesando imaegen - 40 en Davila Raymond
# Procesando imaegen - 41 en Davila Raymond
# Procesando imaegen - 42 en Davila Raymond
# Procesando imaegen - 43 en Davila Raymond
# Procesando imaegen - 44 en Davila Raymond
# Procesando imaegen - 45 en Davila Raymond
# Procesando imaegen - 46 en Davila Raymond
# Procesando imaegen - 47 en Davila Raymond
# Procesando imaegen - 48 en Davila Raymond
# Procesando imaegen - 49 en Davila Raymond
# Procesando imaegen - 50 en Davila Raymond
# Procesando imaegen - 51 en Davila Raymond
# Procesando imaegen - 52 en Davila Raymond
# Procesando imaegen - 53 en Davila Raymond
# Procesando imaegen - 54 en Davila Raymond
# Procesando imaegen - 55 en Davila Raymond
# Procesando imaegen - 56 en Davila Raymond
# Procesando imaegen - 57 en Davila Raymond
# Procesando imaegen - 58 en Davila Raymond
# Procesando imaegen - 59 en Davila Raymond
# Procesando imaegen - 60 en Davila Raymond
# Procesando imaegen - 61 en Davila Raymond
# Procesando imaegen - 62 en Davila Raymond
# Procesando imaegen - 63 en Davila Raymond
# Procesando imaegen - 64 en Davila Raymond
# Procesando imaegen - 65 en Davila Raymond
# Procesando imaegen - 66 en Davila Raymond
# Procesando imaegen - 67 en Davila Raymond
# Procesando imaegen - 68 en Davila Raymond
# Procesando imaegen - 69 en Davila Raymond
# Procesando imaegen - 70 en Davila Raymond
# Procesando imaegen - 71 en Davila Raymond
# Procesando imaegen - 72 en Davila Raymond
# Procesando imaegen - 73 en Davila Raymond
# Procesando imaegen - 74 en Davila Raymond
# Procesando imaegen - 75 en Davila Raymond
# Procesando imaegen - 76 en Davila Raymond
# Procesando imaegen - 77 en Davila Raymond
# Procesando imaegen - 78 en Davila Raymond
# Procesando imaegen - 79 en Davila Raymond
# Procesando imaegen - 80 en Davila Raymond
# Procesando imaegen - 81 en Davila Raymond
# Procesando imaegen - 82 en Davila Raymond
# Procesando imaegen - 83 en Davila Raymond
# Procesando imaegen - 84 en Davila Raymond
# Procesando imaegen - 85 en Davila Raymond
# Procesando imaegen - 86 en Davila Raymond
# Procesando imaegen - 87 en Davila Raymond
# Procesando imaegen - 88 en Davila Raymond
# Procesando imaegen - 89 en Davila Raymond
# Procesando imaegen - 90 en Davila Raymond
# Procesando imaegen - 91 en Davila Raymond
# Procesando imaegen - 92 en Davila Raymond
# Procesando imaegen - 93 en Davila Raymond
# Procesando imaegen - 94 en Davila Raymond
# Procesando imaegen - 95 en Davila Raymond
# Procesando imaegen - 96 en Davila Raymond
# Procesando imaegen - 97 en Davila Raymond
# Procesando imaegen - 98 en Davila Raymond
# Procesando imaegen - 1 en Fernando Masache
# Procesando imaegen - 2 en Fernando Masache
# Procesando imaegen - 3 en Fernando Masache
# Procesando imaegen - 4 en Fernando Masache
# Procesando imaegen - 5 en Fernando Masache
# Procesando imaegen - 6 en Fernando Masache
# Procesando imaegen - 7 en Fernando Masache
# Procesando imaegen - 8 en Fernando Masache
# Procesando imaegen - 9 en Fernando Masache
# Procesando imaegen - 10 en Fernando Masache
# Procesando imaegen - 11 en Fernando Masache
# Procesando imaegen - 12 en Fernando Masache
# Procesando imaegen - 13 en Fernando Masache
# Procesando imaegen - 14 en Fernando Masache
# Procesando imaegen - 15 en Fernando Masache
# Procesando imaegen - 16 en Fernando Masache
# Procesando imaegen - 17 en Fernando Masache
# Procesando imaegen - 18 en Fernando Masache
# Procesando imaegen - 19 en Fernando Masache
# Procesando imaegen - 20 en Fernando Masache
# Procesando imaegen - 21 en Fernando Masache
# Procesando imaegen - 22 en Fernando Masache
# Procesando imaegen - 23 en Fernando Masache
# Procesando imaegen - 24 en Fernando Masache
# Procesando imaegen - 25 en Fernando Masache
# Procesando imaegen - 26 en Fernando Masache
# Procesando imaegen - 27 en Fernando Masache
# Procesando imaegen - 28 en Fernando Masache
# Procesando imaegen - 29 en Fernando Masache
# Procesando imaegen - 30 en Fernando Masache
# Procesando imaegen - 31 en Fernando Masache
# Procesando imaegen - 32 en Fernando Masache
# Procesando imaegen - 33 en Fernando Masache
# Procesando imaegen - 34 en Fernando Masache
# Procesando imaegen - 35 en Fernando Masache
# Procesando imaegen - 36 en Fernando Masache
# Procesando imaegen - 37 en Fernando Masache
# Procesando imaegen - 38 en Fernando Masache
# Procesando imaegen - 39 en Fernando Masache
# Procesando imaegen - 40 en Fernando Masache
# Procesando imaegen - 41 en Fernando Masache
# Procesando imaegen - 42 en Fernando Masache
# Procesando imaegen - 43 en Fernando Masache
# Procesando imaegen - 44 en Fernando Masache
# Procesando imaegen - 45 en Fernando Masache
# Procesando imaegen - 46 en Fernando Masache
# Procesando imaegen - 47 en Fernando Masache
# Procesando imaegen - 48 en Fernando Masache
# Procesando imaegen - 49 en Fernando Masache
# Procesando imaegen - 50 en Fernando Masache
# Procesando imaegen - 51 en Fernando Masache
# Procesando imaegen - 52 en Fernando Masache
# Procesando imaegen - 53 en Fernando Masache
# Procesando imaegen - 54 en Fernando Masache
# Procesando imaegen - 55 en Fernando Masache
# Procesando imaegen - 56 en Fernando Masache
# Procesando imaegen - 57 en Fernando Masache
# Procesando imaegen - 58 en Fernando Masache
# Procesando imaegen - 59 en Fernando Masache
# Procesando imaegen - 60 en Fernando Masache
# Procesando imaegen - 61 en Fernando Masache
# Procesando imaegen - 62 en Fernando Masache
# Procesando imaegen - 63 en Fernando Masache
# Procesando imaegen - 64 en Fernando Masache
# Procesando imaegen - 65 en Fernando Masache
# Procesando imaegen - 66 en Fernando Masache
# Procesando imaegen - 67 en Fernando Masache
# Procesando imaegen - 68 en Fernando Masache
# Procesando imaegen - 69 en Fernando Masache
# Procesando imaegen - 70 en Fernando Masache
# Procesando imaegen - 71 en Fernando Masache
# Procesando imaegen - 72 en Fernando Masache
# Procesando imaegen - 73 en Fernando Masache
# Procesando imaegen - 74 en Fernando Masache
# Procesando imaegen - 75 en Fernando Masache
# Procesando imaegen - 76 en Fernando Masache
# Procesando imaegen - 77 en Fernando Masache
# Procesando imaegen - 78 en Fernando Masache
# Procesando imaegen - 79 en Fernando Masache
# Procesando imaegen - 80 en Fernando Masache
# Procesando imaegen - 81 en Fernando Masache
# Procesando imaegen - 82 en Fernando Masache
# Procesando imaegen - 83 en Fernando Masache
# Procesando imaegen - 84 en Fernando Masache
# Procesando imaegen - 85 en Fernando Masache
# Procesando imaegen - 86 en Fernando Masache
# Procesando imaegen - 87 en Fernando Masache
# Procesando imaegen - 88 en Fernando Masache
# Procesando imaegen - 89 en Fernando Masache
# Procesando imaegen - 90 en Fernando Masache
# Procesando imaegen - 91 en Fernando Masache
# Procesando imaegen - 92 en Fernando Masache
# Procesando imaegen - 93 en Fernando Masache
# Procesando imaegen - 94 en Fernando Masache
# Procesando imaegen - 95 en Fernando Masache
# Procesando imaegen - 96 en Fernando Masache
# Procesando imaegen - 97 en Fernando Masache
# Procesando imaegen - 98 en Fernando Masache
# Procesando imaegen - 99 en Fernando Masache
# Procesando imaegen - 100 en Fernando Masache
# Procesando imaegen - 101 en Fernando Masache
# Procesando imaegen - 102 en Fernando Masache
# Procesando imaegen - 103 en Fernando Masache
# Procesando imaegen - 104 en Fernando Masache
# Procesando imaegen - 105 en Fernando Masache
# Procesando imaegen - 106 en Fernando Masache
# Procesando imaegen - 107 en Fernando Masache
# Procesando imaegen - 108 en Fernando Masache
# Procesando imaegen - 109 en Fernando Masache
# Procesando imaegen - 110 en Fernando Masache
# Procesando imaegen - 1 en Genesis Heredia
# Procesando imaegen - 2 en Genesis Heredia
# Procesando imaegen - 3 en Genesis Heredia
# Procesando imaegen - 4 en Genesis Heredia
# Procesando imaegen - 5 en Genesis Heredia
# Procesando imaegen - 6 en Genesis Heredia
# Procesando imaegen - 7 en Genesis Heredia
# Procesando imaegen - 8 en Genesis Heredia
# Procesando imaegen - 9 en Genesis Heredia
# Procesando imaegen - 10 en Genesis Heredia
# Procesando imaegen - 11 en Genesis Heredia
# Procesando imaegen - 12 en Genesis Heredia
# Procesando imaegen - 13 en Genesis Heredia
# Procesando imaegen - 14 en Genesis Heredia
# Procesando imaegen - 15 en Genesis Heredia
# Procesando imaegen - 16 en Genesis Heredia
# Procesando imaegen - 17 en Genesis Heredia
# Procesando imaegen - 18 en Genesis Heredia
# Procesando imaegen - 19 en Genesis Heredia
# Procesando imaegen - 20 en Genesis Heredia
# Procesando imaegen - 21 en Genesis Heredia
# Procesando imaegen - 22 en Genesis Heredia
# Procesando imaegen - 23 en Genesis Heredia
# Procesando imaegen - 24 en Genesis Heredia
# Procesando imaegen - 25 en Genesis Heredia
# Procesando imaegen - 26 en Genesis Heredia
# Procesando imaegen - 27 en Genesis Heredia
# Procesando imaegen - 28 en Genesis Heredia
# Procesando imaegen - 29 en Genesis Heredia
# Procesando imaegen - 30 en Genesis Heredia
# Procesando imaegen - 31 en Genesis Heredia
# Procesando imaegen - 32 en Genesis Heredia
# Procesando imaegen - 33 en Genesis Heredia
# Procesando imaegen - 34 en Genesis Heredia
# Procesando imaegen - 35 en Genesis Heredia
# Procesando imaegen - 36 en Genesis Heredia
# Procesando imaegen - 37 en Genesis Heredia
# Procesando imaegen - 38 en Genesis Heredia
# Procesando imaegen - 39 en Genesis Heredia
# Procesando imaegen - 40 en Genesis Heredia
# Procesando imaegen - 41 en Genesis Heredia
# Procesando imaegen - 42 en Genesis Heredia
# Procesando imaegen - 43 en Genesis Heredia
# Procesando imaegen - 44 en Genesis Heredia
# Procesando imaegen - 45 en Genesis Heredia
# Procesando imaegen - 46 en Genesis Heredia
# Procesando imaegen - 47 en Genesis Heredia
# Procesando imaegen - 48 en Genesis Heredia
# Procesando imaegen - 49 en Genesis Heredia
# Procesando imaegen - 50 en Genesis Heredia
# Procesando imaegen - 51 en Genesis Heredia
# Procesando imaegen - 52 en Genesis Heredia
# Procesando imaegen - 53 en Genesis Heredia
# Procesando imaegen - 54 en Genesis Heredia
# Procesando imaegen - 55 en Genesis Heredia
# Procesando imaegen - 56 en Genesis Heredia
# Procesando imaegen - 57 en Genesis Heredia
# Procesando imaegen - 58 en Genesis Heredia
# Procesando imaegen - 59 en Genesis Heredia
# Procesando imaegen - 60 en Genesis Heredia
# Procesando imaegen - 61 en Genesis Heredia
# Procesando imaegen - 62 en Genesis Heredia
# Procesando imaegen - 63 en Genesis Heredia
# Procesando imaegen - 64 en Genesis Heredia
# Procesando imaegen - 65 en Genesis Heredia
# Procesando imaegen - 66 en Genesis Heredia
# Procesando imaegen - 67 en Genesis Heredia
# Procesando imaegen - 68 en Genesis Heredia
# Procesando imaegen - 69 en Genesis Heredia
# Procesando imaegen - 70 en Genesis Heredia
# Procesando imaegen - 71 en Genesis Heredia
# Procesando imaegen - 72 en Genesis Heredia
# Procesando imaegen - 73 en Genesis Heredia
# Procesando imaegen - 74 en Genesis Heredia
# Procesando imaegen - 75 en Genesis Heredia
# Procesando imaegen - 76 en Genesis Heredia
# Procesando imaegen - 77 en Genesis Heredia
# Procesando imaegen - 78 en Genesis Heredia
# Procesando imaegen - 79 en Genesis Heredia
# Procesando imaegen - 80 en Genesis Heredia
# Procesando imaegen - 81 en Genesis Heredia
# Procesando imaegen - 82 en Genesis Heredia
# Procesando imaegen - 83 en Genesis Heredia
# Procesando imaegen - 84 en Genesis Heredia
# Procesando imaegen - 85 en Genesis Heredia
# Procesando imaegen - 86 en Genesis Heredia
# Procesando imaegen - 87 en Genesis Heredia
# Procesando imaegen - 88 en Genesis Heredia
# Procesando imaegen - 89 en Genesis Heredia
# Procesando imaegen - 90 en Genesis Heredia
# Procesando imaegen - 91 en Genesis Heredia
# Procesando imaegen - 92 en Genesis Heredia
# Procesando imaegen - 93 en Genesis Heredia
# Procesando imaegen - 94 en Genesis Heredia
# Procesando imaegen - 95 en Genesis Heredia
# Procesando imaegen - 96 en Genesis Heredia
# Procesando imaegen - 97 en Genesis Heredia
# Procesando imaegen - 98 en Genesis Heredia
# Procesando imaegen - 99 en Genesis Heredia
# Procesando imaegen - 100 en Genesis Heredia
# Procesando imaegen - 101 en Genesis Heredia
# Procesando imaegen - 102 en Genesis Heredia
# Procesando imaegen - 103 en Genesis Heredia
# Procesando imaegen - 104 en Genesis Heredia
# Procesando imaegen - 105 en Genesis Heredia
# Procesando imaegen - 106 en Genesis Heredia
# Procesando imaegen - 107 en Genesis Heredia
# Procesando imaegen - 108 en Genesis Heredia
# Procesando imaegen - 1 en Hector Cedenio
# Procesando imaegen - 2 en Hector Cedenio
# Procesando imaegen - 3 en Hector Cedenio
# Procesando imaegen - 4 en Hector Cedenio
# Procesando imaegen - 5 en Hector Cedenio
# Procesando imaegen - 6 en Hector Cedenio
# Procesando imaegen - 7 en Hector Cedenio
# Procesando imaegen - 8 en Hector Cedenio
# Procesando imaegen - 9 en Hector Cedenio
# Procesando imaegen - 10 en Hector Cedenio
# Procesando imaegen - 11 en Hector Cedenio
# Procesando imaegen - 12 en Hector Cedenio
# Procesando imaegen - 13 en Hector Cedenio
# Procesando imaegen - 14 en Hector Cedenio
# Procesando imaegen - 15 en Hector Cedenio
# Procesando imaegen - 16 en Hector Cedenio
# Procesando imaegen - 17 en Hector Cedenio
# Procesando imaegen - 18 en Hector Cedenio
# Procesando imaegen - 19 en Hector Cedenio
# Procesando imaegen - 20 en Hector Cedenio
# Procesando imaegen - 21 en Hector Cedenio
# Procesando imaegen - 22 en Hector Cedenio
# Procesando imaegen - 23 en Hector Cedenio
# Procesando imaegen - 24 en Hector Cedenio
# Procesando imaegen - 25 en Hector Cedenio
# Procesando imaegen - 26 en Hector Cedenio
# Procesando imaegen - 27 en Hector Cedenio
# Procesando imaegen - 28 en Hector Cedenio
# Procesando imaegen - 29 en Hector Cedenio
# Procesando imaegen - 30 en Hector Cedenio
# Procesando imaegen - 31 en Hector Cedenio
# Procesando imaegen - 32 en Hector Cedenio
# Procesando imaegen - 33 en Hector Cedenio
# Procesando imaegen - 34 en Hector Cedenio
# Procesando imaegen - 35 en Hector Cedenio
# Procesando imaegen - 36 en Hector Cedenio
# Procesando imaegen - 37 en Hector Cedenio
# Procesando imaegen - 38 en Hector Cedenio
# Procesando imaegen - 39 en Hector Cedenio
# Procesando imaegen - 40 en Hector Cedenio
# Procesando imaegen - 41 en Hector Cedenio
# Procesando imaegen - 42 en Hector Cedenio
# Procesando imaegen - 43 en Hector Cedenio
# Procesando imaegen - 44 en Hector Cedenio
# Procesando imaegen - 45 en Hector Cedenio
# Procesando imaegen - 46 en Hector Cedenio
# Procesando imaegen - 47 en Hector Cedenio
# Procesando imaegen - 48 en Hector Cedenio
# Procesando imaegen - 49 en Hector Cedenio
# Procesando imaegen - 50 en Hector Cedenio
# Procesando imaegen - 51 en Hector Cedenio
# Procesando imaegen - 52 en Hector Cedenio
# Procesando imaegen - 53 en Hector Cedenio
# Procesando imaegen - 54 en Hector Cedenio
# Procesando imaegen - 55 en Hector Cedenio
# Procesando imaegen - 56 en Hector Cedenio
# Procesando imaegen - 57 en Hector Cedenio
# Procesando imaegen - 58 en Hector Cedenio
# Procesando imaegen - 59 en Hector Cedenio
# Procesando imaegen - 60 en Hector Cedenio
# Procesando imaegen - 61 en Hector Cedenio
# Procesando imaegen - 62 en Hector Cedenio
# Procesando imaegen - 63 en Hector Cedenio
# Procesando imaegen - 64 en Hector Cedenio
# Procesando imaegen - 65 en Hector Cedenio
# Procesando imaegen - 66 en Hector Cedenio
# Procesando imaegen - 67 en Hector Cedenio
# Procesando imaegen - 68 en Hector Cedenio
# Procesando imaegen - 69 en Hector Cedenio
# Procesando imaegen - 70 en Hector Cedenio
# Procesando imaegen - 71 en Hector Cedenio
# Procesando imaegen - 72 en Hector Cedenio
# Procesando imaegen - 73 en Hector Cedenio
# Procesando imaegen - 74 en Hector Cedenio
# Procesando imaegen - 75 en Hector Cedenio
# Procesando imaegen - 76 en Hector Cedenio
# Procesando imaegen - 77 en Hector Cedenio
# Procesando imaegen - 78 en Hector Cedenio
# Procesando imaegen - 79 en Hector Cedenio
# Procesando imaegen - 80 en Hector Cedenio
# Procesando imaegen - 81 en Hector Cedenio
# Procesando imaegen - 82 en Hector Cedenio
# Procesando imaegen - 83 en Hector Cedenio
# Procesando imaegen - 84 en Hector Cedenio
# Procesando imaegen - 85 en Hector Cedenio
# Procesando imaegen - 86 en Hector Cedenio
# Procesando imaegen - 87 en Hector Cedenio
# Procesando imaegen - 88 en Hector Cedenio
# Procesando imaegen - 89 en Hector Cedenio
# Procesando imaegen - 90 en Hector Cedenio
# Procesando imaegen - 91 en Hector Cedenio
# Procesando imaegen - 92 en Hector Cedenio
# Procesando imaegen - 93 en Hector Cedenio
# Procesando imaegen - 94 en Hector Cedenio
# Procesando imaegen - 95 en Hector Cedenio
# Procesando imaegen - 96 en Hector Cedenio
# Procesando imaegen - 97 en Hector Cedenio
# Procesando imaegen - 98 en Hector Cedenio
# Procesando imaegen - 99 en Hector Cedenio
# Procesando imaegen - 100 en Hector Cedenio
# Procesando imaegen - 101 en Hector Cedenio
# Procesando imaegen - 102 en Hector Cedenio
# Procesando imaegen - 103 en Hector Cedenio
# Procesando imaegen - 104 en Hector Cedenio
# Procesando imaegen - 105 en Hector Cedenio
# Procesando imaegen - 106 en Hector Cedenio
# Procesando imaegen - 107 en Hector Cedenio
# Procesando imaegen - 108 en Hector Cedenio
# Procesando imaegen - 109 en Hector Cedenio
# Procesando imaegen - 1 en Jhon Zambrano
# Procesando imaegen - 2 en Jhon Zambrano
# Procesando imaegen - 3 en Jhon Zambrano
# Procesando imaegen - 4 en Jhon Zambrano
# Procesando imaegen - 5 en Jhon Zambrano
# Procesando imaegen - 6 en Jhon Zambrano
# Procesando imaegen - 7 en Jhon Zambrano
# Procesando imaegen - 8 en Jhon Zambrano
# Procesando imaegen - 9 en Jhon Zambrano
# Procesando imaegen - 10 en Jhon Zambrano
# Procesando imaegen - 11 en Jhon Zambrano
# Procesando imaegen - 12 en Jhon Zambrano
# Procesando imaegen - 13 en Jhon Zambrano
# Procesando imaegen - 14 en Jhon Zambrano
# Procesando imaegen - 15 en Jhon Zambrano
# Procesando imaegen - 16 en Jhon Zambrano
# Procesando imaegen - 17 en Jhon Zambrano
# Procesando imaegen - 18 en Jhon Zambrano
# Procesando imaegen - 19 en Jhon Zambrano
# Procesando imaegen - 20 en Jhon Zambrano
# Procesando imaegen - 21 en Jhon Zambrano
# Procesando imaegen - 22 en Jhon Zambrano
# Procesando imaegen - 23 en Jhon Zambrano
# Procesando imaegen - 24 en Jhon Zambrano
# Procesando imaegen - 25 en Jhon Zambrano
# Procesando imaegen - 26 en Jhon Zambrano
# Procesando imaegen - 27 en Jhon Zambrano
# Procesando imaegen - 28 en Jhon Zambrano
# Procesando imaegen - 29 en Jhon Zambrano
# Procesando imaegen - 30 en Jhon Zambrano
# Procesando imaegen - 31 en Jhon Zambrano
# Procesando imaegen - 32 en Jhon Zambrano
# Procesando imaegen - 33 en Jhon Zambrano
# Procesando imaegen - 34 en Jhon Zambrano
# Procesando imaegen - 35 en Jhon Zambrano
# Procesando imaegen - 36 en Jhon Zambrano
# Procesando imaegen - 37 en Jhon Zambrano
# Procesando imaegen - 38 en Jhon Zambrano
# Procesando imaegen - 39 en Jhon Zambrano
# Procesando imaegen - 40 en Jhon Zambrano
# Procesando imaegen - 41 en Jhon Zambrano
# Procesando imaegen - 42 en Jhon Zambrano
# Procesando imaegen - 43 en Jhon Zambrano
# Procesando imaegen - 44 en Jhon Zambrano
# Procesando imaegen - 45 en Jhon Zambrano
# Procesando imaegen - 46 en Jhon Zambrano
# Procesando imaegen - 47 en Jhon Zambrano
# Procesando imaegen - 48 en Jhon Zambrano
# Procesando imaegen - 49 en Jhon Zambrano
# Procesando imaegen - 50 en Jhon Zambrano
# Procesando imaegen - 51 en Jhon Zambrano
# Procesando imaegen - 52 en Jhon Zambrano
# Procesando imaegen - 53 en Jhon Zambrano
# Procesando imaegen - 54 en Jhon Zambrano
# Procesando imaegen - 55 en Jhon Zambrano
# Procesando imaegen - 56 en Jhon Zambrano
# Procesando imaegen - 57 en Jhon Zambrano
# Procesando imaegen - 58 en Jhon Zambrano
# Procesando imaegen - 59 en Jhon Zambrano
# Procesando imaegen - 60 en Jhon Zambrano
# Procesando imaegen - 61 en Jhon Zambrano
# Procesando imaegen - 62 en Jhon Zambrano
# Procesando imaegen - 63 en Jhon Zambrano
# Procesando imaegen - 64 en Jhon Zambrano
# Procesando imaegen - 65 en Jhon Zambrano
# Procesando imaegen - 66 en Jhon Zambrano
# Procesando imaegen - 67 en Jhon Zambrano
# Procesando imaegen - 68 en Jhon Zambrano
# Procesando imaegen - 69 en Jhon Zambrano
# Procesando imaegen - 70 en Jhon Zambrano
# Procesando imaegen - 71 en Jhon Zambrano
# Procesando imaegen - 72 en Jhon Zambrano
# Procesando imaegen - 73 en Jhon Zambrano
# Procesando imaegen - 74 en Jhon Zambrano
# Procesando imaegen - 75 en Jhon Zambrano
# Procesando imaegen - 76 en Jhon Zambrano
# Procesando imaegen - 77 en Jhon Zambrano
# Procesando imaegen - 78 en Jhon Zambrano
# Procesando imaegen - 79 en Jhon Zambrano
# Procesando imaegen - 80 en Jhon Zambrano
# Procesando imaegen - 81 en Jhon Zambrano
# Procesando imaegen - 82 en Jhon Zambrano
# Procesando imaegen - 83 en Jhon Zambrano
# Procesando imaegen - 84 en Jhon Zambrano
# Procesando imaegen - 85 en Jhon Zambrano
# Procesando imaegen - 86 en Jhon Zambrano
# Procesando imaegen - 87 en Jhon Zambrano
# Procesando imaegen - 88 en Jhon Zambrano
# Procesando imaegen - 89 en Jhon Zambrano
# Procesando imaegen - 90 en Jhon Zambrano
# Procesando imaegen - 91 en Jhon Zambrano
# Procesando imaegen - 92 en Jhon Zambrano
# Procesando imaegen - 93 en Jhon Zambrano
# Procesando imaegen - 94 en Jhon Zambrano
# Procesando imaegen - 95 en Jhon Zambrano
# Procesando imaegen - 96 en Jhon Zambrano
# Procesando imaegen - 97 en Jhon Zambrano
# Procesando imaegen - 98 en Jhon Zambrano
# Procesando imaegen - 99 en Jhon Zambrano
# Procesando imaegen - 100 en Jhon Zambrano
# Procesando imaegen - 101 en Jhon Zambrano
# Procesando imaegen - 102 en Jhon Zambrano
# Procesando imaegen - 103 en Jhon Zambrano
# Procesando imaegen - 104 en Jhon Zambrano
# Procesando imaegen - 105 en Jhon Zambrano
# Procesando imaegen - 106 en Jhon Zambrano
# Procesando imaegen - 107 en Jhon Zambrano
# Procesando imaegen - 108 en Jhon Zambrano
# Procesando imaegen - 109 en Jhon Zambrano
# Procesando imaegen - 110 en Jhon Zambrano
# Procesando imaegen - 111 en Jhon Zambrano
# Procesando imaegen - 112 en Jhon Zambrano
# Procesando imaegen - 113 en Jhon Zambrano
# Procesando imaegen - 114 en Jhon Zambrano
# Procesando imaegen - 115 en Jhon Zambrano
# Procesando imaegen - 116 en Jhon Zambrano
# Procesando imaegen - 117 en Jhon Zambrano
# Procesando imaegen - 118 en Jhon Zambrano
# Procesando imaegen - 119 en Jhon Zambrano
# Procesando imaegen - 120 en Jhon Zambrano
# Procesando imaegen - 121 en Jhon Zambrano
# Procesando imaegen - 122 en Jhon Zambrano
# Procesando imaegen - 123 en Jhon Zambrano
# Procesando imaegen - 124 en Jhon Zambrano
# Procesando imaegen - 125 en Jhon Zambrano
# Procesando imaegen - 126 en Jhon Zambrano
# Procesando imaegen - 127 en Jhon Zambrano
# Procesando imaegen - 128 en Jhon Zambrano
# Procesando imaegen - 129 en Jhon Zambrano
# Procesando imaegen - 130 en Jhon Zambrano
# Procesando imaegen - 131 en Jhon Zambrano
# Procesando imaegen - 132 en Jhon Zambrano
# Procesando imaegen - 133 en Jhon Zambrano
# Procesando imaegen - 134 en Jhon Zambrano
# Procesando imaegen - 135 en Jhon Zambrano
# Procesando imaegen - 136 en Jhon Zambrano
# Procesando imaegen - 137 en Jhon Zambrano
# Procesando imaegen - 138 en Jhon Zambrano
# Procesando imaegen - 139 en Jhon Zambrano
# Procesando imaegen - 140 en Jhon Zambrano
# Procesando imaegen - 141 en Jhon Zambrano
# Procesando imaegen - 142 en Jhon Zambrano
# Procesando imaegen - 143 en Jhon Zambrano
# Procesando imaegen - 1 en Joan Cevallos
# Procesando imaegen - 2 en Joan Cevallos
# Procesando imaegen - 3 en Joan Cevallos
# Procesando imaegen - 4 en Joan Cevallos
# Procesando imaegen - 5 en Joan Cevallos
# Procesando imaegen - 6 en Joan Cevallos
# Procesando imaegen - 7 en Joan Cevallos
# Procesando imaegen - 8 en Joan Cevallos
# Procesando imaegen - 9 en Joan Cevallos
# Procesando imaegen - 10 en Joan Cevallos
# Procesando imaegen - 11 en Joan Cevallos
# Procesando imaegen - 12 en Joan Cevallos
# Procesando imaegen - 13 en Joan Cevallos
# Procesando imaegen - 14 en Joan Cevallos
# Procesando imaegen - 15 en Joan Cevallos
# Procesando imaegen - 16 en Joan Cevallos
# Procesando imaegen - 17 en Joan Cevallos
# Procesando imaegen - 18 en Joan Cevallos
# Procesando imaegen - 19 en Joan Cevallos
# Procesando imaegen - 20 en Joan Cevallos
# Procesando imaegen - 21 en Joan Cevallos
# Procesando imaegen - 22 en Joan Cevallos
# Procesando imaegen - 23 en Joan Cevallos
# Procesando imaegen - 24 en Joan Cevallos
# Procesando imaegen - 25 en Joan Cevallos
# Procesando imaegen - 26 en Joan Cevallos
# Procesando imaegen - 27 en Joan Cevallos
# Procesando imaegen - 28 en Joan Cevallos
# Procesando imaegen - 29 en Joan Cevallos
# Procesando imaegen - 30 en Joan Cevallos
# Procesando imaegen - 31 en Joan Cevallos
# Procesando imaegen - 32 en Joan Cevallos
# Procesando imaegen - 33 en Joan Cevallos
# Procesando imaegen - 34 en Joan Cevallos
# Procesando imaegen - 35 en Joan Cevallos
# Procesando imaegen - 36 en Joan Cevallos
# Procesando imaegen - 37 en Joan Cevallos
# Procesando imaegen - 38 en Joan Cevallos
# Procesando imaegen - 39 en Joan Cevallos
# Procesando imaegen - 40 en Joan Cevallos
# Procesando imaegen - 41 en Joan Cevallos
# Procesando imaegen - 42 en Joan Cevallos
# Procesando imaegen - 43 en Joan Cevallos
# Procesando imaegen - 44 en Joan Cevallos
# Procesando imaegen - 45 en Joan Cevallos
# Procesando imaegen - 46 en Joan Cevallos
# Procesando imaegen - 47 en Joan Cevallos
# Procesando imaegen - 48 en Joan Cevallos
# Procesando imaegen - 49 en Joan Cevallos
# Procesando imaegen - 50 en Joan Cevallos
# Procesando imaegen - 51 en Joan Cevallos
# Procesando imaegen - 52 en Joan Cevallos
# Procesando imaegen - 53 en Joan Cevallos
# Procesando imaegen - 54 en Joan Cevallos
# Procesando imaegen - 55 en Joan Cevallos
# Procesando imaegen - 56 en Joan Cevallos
# Procesando imaegen - 57 en Joan Cevallos
# Procesando imaegen - 58 en Joan Cevallos
# Procesando imaegen - 59 en Joan Cevallos
# Procesando imaegen - 60 en Joan Cevallos
# Procesando imaegen - 61 en Joan Cevallos
# Procesando imaegen - 62 en Joan Cevallos
# Procesando imaegen - 63 en Joan Cevallos
# Procesando imaegen - 64 en Joan Cevallos
# Procesando imaegen - 65 en Joan Cevallos
# Procesando imaegen - 66 en Joan Cevallos
# Procesando imaegen - 67 en Joan Cevallos
# Procesando imaegen - 68 en Joan Cevallos
# Procesando imaegen - 69 en Joan Cevallos
# Procesando imaegen - 70 en Joan Cevallos
# Procesando imaegen - 71 en Joan Cevallos
# Procesando imaegen - 72 en Joan Cevallos
# Procesando imaegen - 73 en Joan Cevallos
# Procesando imaegen - 74 en Joan Cevallos
# Procesando imaegen - 75 en Joan Cevallos
# Procesando imaegen - 76 en Joan Cevallos
# Procesando imaegen - 77 en Joan Cevallos
# Procesando imaegen - 78 en Joan Cevallos
# Procesando imaegen - 79 en Joan Cevallos
# Procesando imaegen - 80 en Joan Cevallos
# Procesando imaegen - 81 en Joan Cevallos
# Procesando imaegen - 82 en Joan Cevallos
# Procesando imaegen - 83 en Joan Cevallos
# Procesando imaegen - 84 en Joan Cevallos
# Procesando imaegen - 85 en Joan Cevallos
# Procesando imaegen - 86 en Joan Cevallos
# Procesando imaegen - 87 en Joan Cevallos
# Procesando imaegen - 88 en Joan Cevallos
# Procesando imaegen - 89 en Joan Cevallos
# Procesando imaegen - 90 en Joan Cevallos
# Procesando imaegen - 91 en Joan Cevallos
# Procesando imaegen - 92 en Joan Cevallos
# Procesando imaegen - 93 en Joan Cevallos
# Procesando imaegen - 94 en Joan Cevallos
# Procesando imaegen - 95 en Joan Cevallos
# Procesando imaegen - 96 en Joan Cevallos
# Procesando imaegen - 97 en Joan Cevallos
# Procesando imaegen - 98 en Joan Cevallos
# Procesando imaegen - 99 en Joan Cevallos
# Procesando imaegen - 1 en Johana Salazar
# Procesando imaegen - 2 en Johana Salazar
# Procesando imaegen - 3 en Johana Salazar
# Procesando imaegen - 4 en Johana Salazar
# Procesando imaegen - 5 en Johana Salazar
# Procesando imaegen - 6 en Johana Salazar
# Procesando imaegen - 7 en Johana Salazar
# Procesando imaegen - 8 en Johana Salazar
# Procesando imaegen - 9 en Johana Salazar
# Procesando imaegen - 10 en Johana Salazar
# Procesando imaegen - 11 en Johana Salazar
# Procesando imaegen - 12 en Johana Salazar
# Procesando imaegen - 13 en Johana Salazar
# Procesando imaegen - 14 en Johana Salazar
# Procesando imaegen - 15 en Johana Salazar
# Procesando imaegen - 16 en Johana Salazar
# Procesando imaegen - 17 en Johana Salazar
# Procesando imaegen - 18 en Johana Salazar
# Procesando imaegen - 19 en Johana Salazar
# Procesando imaegen - 20 en Johana Salazar
# Procesando imaegen - 21 en Johana Salazar
# Procesando imaegen - 22 en Johana Salazar
# Procesando imaegen - 23 en Johana Salazar
# Procesando imaegen - 24 en Johana Salazar
# Procesando imaegen - 25 en Johana Salazar
# Procesando imaegen - 26 en Johana Salazar
# Procesando imaegen - 27 en Johana Salazar
# Procesando imaegen - 28 en Johana Salazar
# Procesando imaegen - 29 en Johana Salazar
# Procesando imaegen - 30 en Johana Salazar
# Procesando imaegen - 31 en Johana Salazar
# Procesando imaegen - 32 en Johana Salazar
# Procesando imaegen - 33 en Johana Salazar
# Procesando imaegen - 34 en Johana Salazar
# Procesando imaegen - 35 en Johana Salazar
# Procesando imaegen - 36 en Johana Salazar
# Procesando imaegen - 37 en Johana Salazar
# Procesando imaegen - 38 en Johana Salazar
# Procesando imaegen - 39 en Johana Salazar
# Procesando imaegen - 40 en Johana Salazar
# Procesando imaegen - 41 en Johana Salazar
# Procesando imaegen - 42 en Johana Salazar
# Procesando imaegen - 43 en Johana Salazar
# Procesando imaegen - 44 en Johana Salazar
# Procesando imaegen - 45 en Johana Salazar
# Procesando imaegen - 46 en Johana Salazar
# Procesando imaegen - 47 en Johana Salazar
# Procesando imaegen - 48 en Johana Salazar
# Procesando imaegen - 49 en Johana Salazar
# Procesando imaegen - 50 en Johana Salazar
# Procesando imaegen - 51 en Johana Salazar
# Procesando imaegen - 52 en Johana Salazar
# Procesando imaegen - 53 en Johana Salazar
# Procesando imaegen - 54 en Johana Salazar
# Procesando imaegen - 55 en Johana Salazar
# Procesando imaegen - 56 en Johana Salazar
# Procesando imaegen - 57 en Johana Salazar
# Procesando imaegen - 58 en Johana Salazar
# Procesando imaegen - 59 en Johana Salazar
# Procesando imaegen - 60 en Johana Salazar
# Procesando imaegen - 61 en Johana Salazar
# Procesando imaegen - 62 en Johana Salazar
# Procesando imaegen - 63 en Johana Salazar
# Procesando imaegen - 64 en Johana Salazar
# Procesando imaegen - 65 en Johana Salazar
# Procesando imaegen - 66 en Johana Salazar
# Procesando imaegen - 67 en Johana Salazar
# Procesando imaegen - 68 en Johana Salazar
# Procesando imaegen - 69 en Johana Salazar
# Procesando imaegen - 70 en Johana Salazar
# Procesando imaegen - 71 en Johana Salazar
# Procesando imaegen - 72 en Johana Salazar
# Procesando imaegen - 73 en Johana Salazar
# Procesando imaegen - 74 en Johana Salazar
# Procesando imaegen - 75 en Johana Salazar
# Procesando imaegen - 76 en Johana Salazar
# Procesando imaegen - 77 en Johana Salazar
# Procesando imaegen - 78 en Johana Salazar
# Procesando imaegen - 79 en Johana Salazar
# Procesando imaegen - 80 en Johana Salazar
# Procesando imaegen - 81 en Johana Salazar
# Procesando imaegen - 82 en Johana Salazar
# Procesando imaegen - 83 en Johana Salazar
# Procesando imaegen - 84 en Johana Salazar
# Procesando imaegen - 85 en Johana Salazar
# Procesando imaegen - 86 en Johana Salazar
# Procesando imaegen - 87 en Johana Salazar
# Procesando imaegen - 1 en Jordan Espinosa
# Procesando imaegen - 2 en Jordan Espinosa
# Procesando imaegen - 3 en Jordan Espinosa
# Procesando imaegen - 4 en Jordan Espinosa
# Procesando imaegen - 5 en Jordan Espinosa
# Procesando imaegen - 6 en Jordan Espinosa
# Procesando imaegen - 7 en Jordan Espinosa
# Procesando imaegen - 8 en Jordan Espinosa
# Procesando imaegen - 9 en Jordan Espinosa
# Procesando imaegen - 10 en Jordan Espinosa
# Procesando imaegen - 11 en Jordan Espinosa
# Procesando imaegen - 12 en Jordan Espinosa
# Procesando imaegen - 13 en Jordan Espinosa
# Procesando imaegen - 14 en Jordan Espinosa
# Procesando imaegen - 15 en Jordan Espinosa
# Procesando imaegen - 16 en Jordan Espinosa
# Procesando imaegen - 17 en Jordan Espinosa
# Procesando imaegen - 18 en Jordan Espinosa
# Procesando imaegen - 83 en Jordan Espinosa
# Procesando imaegen - 84 en Jordan Espinosa
# Procesando imaegen - 85 en Jordan Espinosa
# Procesando imaegen - 86 en Jordan Espinosa
# Procesando imaegen - 87 en Jordan Espinosa
# Procesando imaegen - 88 en Jordan Espinosa
# Procesando imaegen - 1 en Jorge Borrero
# Procesando imaegen - 2 en Jorge Borrero
# Procesando imaegen - 3 en Jorge Borrero
# Procesando imaegen - 4 en Jorge Borrero
# Procesando imaegen - 5 en Jorge Borrero
# ...
# Procesando imaegen - 36 en Selena Enriquez
# Procesando imaegen - 37 en Selena Enriquez
# Procesando imaegen - 38 en Selena Enriquez
# Procesando imaegen - 39 en Selena Enriquez
# Procesando imaegen - 40 en Selena Enriquez
# Procesando imaegen - 41 en Selena Enriquez
# Procesando imaegen - 42 en Selena Enriquez
# Procesando imaegen - 43 en Selena Enriquez
# Procesando imaegen - 44 en Selena Enriquez
# Procesando imaegen - 45 en Selena Enriquez
# Procesando imaegen - 46 en Selena Enriquez
# Procesando imaegen - 47 en Selena Enriquez
# Procesando imaegen - 48 en Selena Enriquez
# Procesando imaegen - 49 en Selena Enriquez
# Procesando imaegen - 50 en Selena Enriquez
# Procesando imaegen - 51 en Selena Enriquez
# Procesando imaegen - 52 en Selena Enriquez
# Procesando imaegen - 53 en Selena Enriquez
# Procesando imaegen - 54 en Selena Enriquez
# Procesando imaegen - 55 en Selena Enriquez
# Procesando imaegen - 56 en Selena Enriquez
# Procesando imaegen - 57 en Selena Enriquez
# Procesando imaegen - 58 en Selena Enriquez
# Procesando imaegen - 59 en Selena Enriquez
# Procesando imaegen - 60 en Selena Enriquez
# Procesando imaegen - 61 en Selena Enriquez
# Procesando imaegen - 62 en Selena Enriquez
# Procesando imaegen - 63 en Selena Enriquez
# Procesando imaegen - 64 en Selena Enriquez
# Procesando imaegen - 65 en Selena Enriquez
# Procesando imaegen - 66 en Selena Enriquez
# Procesando imaegen - 67 en Selena Enriquez
# Procesando imaegen - 68 en Selena Enriquez
# Procesando imaegen - 69 en Selena Enriquez
# Procesando imaegen - 70 en Selena Enriquez
# Procesando imaegen - 71 en Selena Enriquez
# Procesando imaegen - 72 en Selena Enriquez
# Procesando imaegen - 73 en Selena Enriquez
# Procesando imaegen - 74 en Selena Enriquez
# Procesando imaegen - 75 en Selena Enriquez
# Procesando imaegen - 76 en Selena Enriquez
# Procesando imaegen - 77 en Selena Enriquez
# Procesando imaegen - 78 en Selena Enriquez
# Procesando imaegen - 79 en Selena Enriquez
# Procesando imaegen - 80 en Selena Enriquez
# Procesando imaegen - 81 en Selena Enriquez
# Procesando imaegen - 82 en Selena Enriquez
# Procesando imaegen - 83 en Selena Enriquez
# Procesando imaegen - 84 en Selena Enriquez
# Procesando imaegen - 85 en Selena Enriquez
# Procesando imaegen - 86 en Selena Enriquez
# Procesando imaegen - 87 en Selena Enriquez
# Procesando imaegen - 88 en Selena Enriquez
# Procesando imaegen - 1 en Selena Rivas
# Procesando imaegen - 2 en Selena Rivas
# Procesando imaegen - 3 en Selena Rivas
# Procesando imaegen - 4 en Selena Rivas
# Procesando imaegen - 5 en Selena Rivas
# Procesando imaegen - 6 en Selena Rivas
# Procesando imaegen - 7 en Selena Rivas
# Procesando imaegen - 8 en Selena Rivas
# Procesando imaegen - 9 en Selena Rivas
# Procesando imaegen - 10 en Selena Rivas
# Procesando imaegen - 11 en Selena Rivas
# Procesando imaegen - 12 en Selena Rivas
# Procesando imaegen - 13 en Selena Rivas
# Procesando imaegen - 14 en Selena Rivas
# Procesando imaegen - 15 en Selena Rivas
# Procesando imaegen - 16 en Selena Rivas
# Procesando imaegen - 17 en Selena Rivas
# Procesando imaegen - 18 en Selena Rivas
# Procesando imaegen - 19 en Selena Rivas
# Procesando imaegen - 20 en Selena Rivas
# Procesando imaegen - 21 en Selena Rivas
# Procesando imaegen - 22 en Selena Rivas
# Procesando imaegen - 23 en Selena Rivas
# Procesando imaegen - 24 en Selena Rivas
# Procesando imaegen - 25 en Selena Rivas
# Procesando imaegen - 26 en Selena Rivas
# Procesando imaegen - 27 en Selena Rivas
# Procesando imaegen - 28 en Selena Rivas
# Procesando imaegen - 29 en Selena Rivas
# Procesando imaegen - 30 en Selena Rivas
# Procesando imaegen - 31 en Selena Rivas
# Procesando imaegen - 32 en Selena Rivas
# Procesando imaegen - 33 en Selena Rivas
# Procesando imaegen - 34 en Selena Rivas
# Procesando imaegen - 35 en Selena Rivas
# Procesando imaegen - 36 en Selena Rivas
# Procesando imaegen - 37 en Selena Rivas
# Procesando imaegen - 38 en Selena Rivas
# Procesando imaegen - 39 en Selena Rivas
# Procesando imaegen - 40 en Selena Rivas
# Procesando imaegen - 41 en Selena Rivas
# Procesando imaegen - 42 en Selena Rivas
# Procesando imaegen - 43 en Selena Rivas
# Procesando imaegen - 44 en Selena Rivas
# Procesando imaegen - 45 en Selena Rivas
# Procesando imaegen - 46 en Selena Rivas
# Procesando imaegen - 47 en Selena Rivas
# Procesando imaegen - 48 en Selena Rivas
# Procesando imaegen - 49 en Selena Rivas
# Procesando imaegen - 50 en Selena Rivas
# Procesando imaegen - 51 en Selena Rivas
# Procesando imaegen - 52 en Selena Rivas
# Procesando imaegen - 53 en Selena Rivas
# Procesando imaegen - 54 en Selena Rivas
# Procesando imaegen - 55 en Selena Rivas
# Procesando imaegen - 56 en Selena Rivas
# Procesando imaegen - 57 en Selena Rivas
# Procesando imaegen - 58 en Selena Rivas
# Procesando imaegen - 59 en Selena Rivas
# Procesando imaegen - 60 en Selena Rivas
# Procesando imaegen - 61 en Selena Rivas
# Procesando imaegen - 62 en Selena Rivas
# Procesando imaegen - 63 en Selena Rivas
# Procesando imaegen - 64 en Selena Rivas
# Procesando imaegen - 65 en Selena Rivas
# Procesando imaegen - 66 en Selena Rivas
# Procesando imaegen - 67 en Selena Rivas
# Procesando imaegen - 68 en Selena Rivas
# Procesando imaegen - 69 en Selena Rivas
# Procesando imaegen - 70 en Selena Rivas
# Procesando imaegen - 71 en Selena Rivas
# Procesando imaegen - 72 en Selena Rivas
# Procesando imaegen - 73 en Selena Rivas
# Procesando imaegen - 74 en Selena Rivas
# Procesando imaegen - 75 en Selena Rivas
# Procesando imaegen - 76 en Selena Rivas
# Procesando imaegen - 77 en Selena Rivas
# Procesando imaegen - 78 en Selena Rivas
# Procesando imaegen - 79 en Selena Rivas
# Procesando imaegen - 80 en Selena Rivas
# Procesando imaegen - 81 en Selena Rivas
# Procesando imaegen - 82 en Selena Rivas
# Procesando imaegen - 83 en Selena Rivas
# Procesando imaegen - 84 en Selena Rivas
# Procesando imaegen - 85 en Selena Rivas
# Procesando imaegen - 86 en Selena Rivas
# Procesando imaegen - 87 en Selena Rivas
# Procesando imaegen - 88 en Selena Rivas
# Procesando imaegen - 89 en Selena Rivas
# Procesando imaegen - 90 en Selena Rivas
# Procesando imaegen - 91 en Selena Rivas
# Procesando imaegen - 92 en Selena Rivas
# Procesando imaegen - 93 en Selena Rivas
# Procesando imaegen - 94 en Selena Rivas
# Procesando imaegen - 95 en Selena Rivas
# Procesando imaegen - 96 en Selena Rivas
# Procesando imaegen - 97 en Selena Rivas
# Procesando imaegen - 98 en Selena Rivas
# Procesando imaegen - 99 en Selena Rivas
# Procesando imaegen - 100 en Selena Rivas
# Procesando imaegen - 101 en Selena Rivas
# Procesando imaegen - 102 en Selena Rivas
# Procesando imaegen - 103 en Selena Rivas
# Procesando imaegen - 104 en Selena Rivas
# Procesando imaegen - 105 en Selena Rivas
# Procesando imaegen - 106 en Selena Rivas
# Procesando imaegen - 107 en Selena Rivas
# Procesando imaegen - 108 en Selena Rivas
# Procesando imaegen - 109 en Selena Rivas
# Procesando imaegen - 110 en Selena Rivas
# Procesando imaegen - 111 en Selena Rivas
# Procesando imaegen - 112 en Selena Rivas
# Procesando imaegen - 113 en Selena Rivas
# Procesando imaegen - 114 en Selena Rivas
# Procesando imaegen - 115 en Selena Rivas
# Procesando imaegen - 116 en Selena Rivas
# Procesando imaegen - 117 en Selena Rivas
# Procesando imaegen - 118 en Selena Rivas
# Procesando imaegen - 119 en Selena Rivas
# Procesando imaegen - 1 en Solano Wilmer
# Procesando imaegen - 2 en Solano Wilmer
# Procesando imaegen - 3 en Solano Wilmer
# Procesando imaegen - 4 en Solano Wilmer
# Procesando imaegen - 5 en Solano Wilmer
# Procesando imaegen - 6 en Solano Wilmer
# Procesando imaegen - 7 en Solano Wilmer
# Procesando imaegen - 8 en Solano Wilmer
# Procesando imaegen - 9 en Solano Wilmer
# Procesando imaegen - 10 en Solano Wilmer
# Procesando imaegen - 11 en Solano Wilmer
# Procesando imaegen - 12 en Solano Wilmer
# Procesando imaegen - 13 en Solano Wilmer
# Procesando imaegen - 14 en Solano Wilmer
# Procesando imaegen - 15 en Solano Wilmer
# Procesando imaegen - 16 en Solano Wilmer
# Procesando imaegen - 17 en Solano Wilmer
# Procesando imaegen - 18 en Solano Wilmer
# Procesando imaegen - 19 en Solano Wilmer
# Procesando imaegen - 20 en Solano Wilmer
# Procesando imaegen - 21 en Solano Wilmer
# Procesando imaegen - 22 en Solano Wilmer
# Procesando imaegen - 23 en Solano Wilmer
# Procesando imaegen - 24 en Solano Wilmer
# Procesando imaegen - 25 en Solano Wilmer
# Procesando imaegen - 26 en Solano Wilmer
# Procesando imaegen - 27 en Solano Wilmer
# Procesando imaegen - 28 en Solano Wilmer
# Procesando imaegen - 29 en Solano Wilmer
# Procesando imaegen - 30 en Solano Wilmer
# Procesando imaegen - 31 en Solano Wilmer
# Procesando imaegen - 32 en Solano Wilmer
# Procesando imaegen - 33 en Solano Wilmer
# Procesando imaegen - 34 en Solano Wilmer
# Procesando imaegen - 35 en Solano Wilmer
# Procesando imaegen - 36 en Solano Wilmer
# Procesando imaegen - 37 en Solano Wilmer
# Procesando imaegen - 38 en Solano Wilmer
# Procesando imaegen - 39 en Solano Wilmer
# Procesando imaegen - 40 en Solano Wilmer
# Procesando imaegen - 41 en Solano Wilmer
# Procesando imaegen - 42 en Solano Wilmer
# Procesando imaegen - 43 en Solano Wilmer
# Procesando imaegen - 44 en Solano Wilmer
# Procesando imaegen - 45 en Solano Wilmer
# Procesando imaegen - 46 en Solano Wilmer
# Procesando imaegen - 47 en Solano Wilmer
# Procesando imaegen - 48 en Solano Wilmer
# Procesando imaegen - 49 en Solano Wilmer
# Procesando imaegen - 50 en Solano Wilmer
# Procesando imaegen - 51 en Solano Wilmer
# Procesando imaegen - 52 en Solano Wilmer
# Procesando imaegen - 53 en Solano Wilmer
# Procesando imaegen - 54 en Solano Wilmer
# Procesando imaegen - 55 en Solano Wilmer
# Procesando imaegen - 1 en Steven Barragan
# Procesando imaegen - 2 en Steven Barragan
# Procesando imaegen - 3 en Steven Barragan
# Procesando imaegen - 4 en Steven Barragan
# Procesando imaegen - 5 en Steven Barragan
# Procesando imaegen - 6 en Steven Barragan
# Procesando imaegen - 7 en Steven Barragan
# Procesando imaegen - 8 en Steven Barragan
# Procesando imaegen - 9 en Steven Barragan
# Procesando imaegen - 10 en Steven Barragan
# Procesando imaegen - 11 en Steven Barragan
# Procesando imaegen - 12 en Steven Barragan
# Procesando imaegen - 13 en Steven Barragan
# Procesando imaegen - 14 en Steven Barragan
# Procesando imaegen - 15 en Steven Barragan
# Procesando imaegen - 16 en Steven Barragan
# Procesando imaegen - 17 en Steven Barragan
# Procesando imaegen - 18 en Steven Barragan
# Procesando imaegen - 19 en Steven Barragan
# Procesando imaegen - 20 en Steven Barragan
# Procesando imaegen - 21 en Steven Barragan
# Procesando imaegen - 22 en Steven Barragan
# Procesando imaegen - 23 en Steven Barragan
# Procesando imaegen - 24 en Steven Barragan
# Procesando imaegen - 25 en Steven Barragan
# Procesando imaegen - 26 en Steven Barragan
# Procesando imaegen - 27 en Steven Barragan
# Procesando imaegen - 28 en Steven Barragan
# Procesando imaegen - 29 en Steven Barragan
# Procesando imaegen - 30 en Steven Barragan
# Procesando imaegen - 31 en Steven Barragan
# Procesando imaegen - 32 en Steven Barragan
# Procesando imaegen - 33 en Steven Barragan
# Procesando imaegen - 34 en Steven Barragan
# Procesando imaegen - 35 en Steven Barragan
# Procesando imaegen - 36 en Steven Barragan
# Procesando imaegen - 37 en Steven Barragan
# Procesando imaegen - 38 en Steven Barragan
# Procesando imaegen - 39 en Steven Barragan
# Procesando imaegen - 40 en Steven Barragan
# Procesando imaegen - 41 en Steven Barragan
# Procesando imaegen - 42 en Steven Barragan
# Procesando imaegen - 43 en Steven Barragan
# Procesando imaegen - 44 en Steven Barragan
# Procesando imaegen - 45 en Steven Barragan
# Procesando imaegen - 46 en Steven Barragan
# Procesando imaegen - 47 en Steven Barragan
# Procesando imaegen - 48 en Steven Barragan
# Procesando imaegen - 49 en Steven Barragan
# Procesando imaegen - 50 en Steven Barragan
# Procesando imaegen - 51 en Steven Barragan
# Procesando imaegen - 52 en Steven Barragan
# Procesando imaegen - 53 en Steven Barragan
# Procesando imaegen - 54 en Steven Barragan
# Procesando imaegen - 55 en Steven Barragan
# Procesando imaegen - 56 en Steven Barragan
# Procesando imaegen - 57 en Steven Barragan
# Procesando imaegen - 58 en Steven Barragan
# Procesando imaegen - 59 en Steven Barragan
# Procesando imaegen - 60 en Steven Barragan
# Procesando imaegen - 61 en Steven Barragan
# Procesando imaegen - 62 en Steven Barragan
# Procesando imaegen - 63 en Steven Barragan
# Procesando imaegen - 64 en Steven Barragan
# Procesando imaegen - 65 en Steven Barragan
# Procesando imaegen - 66 en Steven Barragan
# Procesando imaegen - 67 en Steven Barragan
# Procesando imaegen - 68 en Steven Barragan
# Procesando imaegen - 69 en Steven Barragan
# Procesando imaegen - 70 en Steven Barragan
# Procesando imaegen - 71 en Steven Barragan
# Procesando imaegen - 72 en Steven Barragan
# Procesando imaegen - 73 en Steven Barragan
# Procesando imaegen - 74 en Steven Barragan
# Procesando imaegen - 75 en Steven Barragan
# Procesando imaegen - 76 en Steven Barragan
# Procesando imaegen - 77 en Steven Barragan
# Procesando imaegen - 78 en Steven Barragan
# Procesando imaegen - 79 en Steven Barragan
# Procesando imaegen - 80 en Steven Barragan
# Procesando imaegen - 81 en Steven Barragan
# Procesando imaegen - 82 en Steven Barragan
# Procesando imaegen - 83 en Steven Barragan
# Procesando imaegen - 84 en Steven Barragan
# Procesando imaegen - 85 en Steven Barragan
# Procesando imaegen - 86 en Steven Barragan
# Procesando imaegen - 87 en Steven Barragan
# Procesando imaegen - 88 en Steven Barragan
# Procesando imaegen - 89 en Steven Barragan
# Procesando imaegen - 90 en Steven Barragan
# Procesando imaegen - 91 en Steven Barragan
# Procesando imaegen - 92 en Steven Barragan
# Procesando imaegen - 93 en Steven Barragan
# Procesando imaegen - 94 en Steven Barragan
# Procesando imaegen - 95 en Steven Barragan
# Procesando imaegen - 96 en Steven Barragan
# Procesando imaegen - 97 en Steven Barragan
# Procesando imaegen - 98 en Steven Barragan
# Procesando imaegen - 99 en Steven Barragan
# Procesando imaegen - 100 en Steven Barragan
# Procesando imaegen - 101 en Steven Barragan
# Procesando imaegen - 102 en Steven Barragan
# Procesando imaegen - 103 en Steven Barragan
# Procesando imaegen - 104 en Steven Barragan
# Procesando imaegen - 105 en Steven Barragan
# Procesando imaegen - 106 en Steven Barragan
# Procesando imaegen - 107 en Steven Barragan
# Procesando imaegen - 108 en Steven Barragan
# Procesando imaegen - 109 en Steven Barragan
# Procesando imaegen - 110 en Steven Barragan
# Procesando imaegen - 111 en Steven Barragan
# Procesando imaegen - 112 en Steven Barragan
# Procesando imaegen - 113 en Steven Barragan
# Procesando imaegen - 114 en Steven Barragan
# Procesando imaegen - 115 en Steven Barragan
# Procesando imaegen - 116 en Steven Barragan
# Procesando imaegen - 117 en Steven Barragan
# Procesando imaegen - 118 en Steven Barragan
# Procesando imaegen - 119 en Steven Barragan
# Procesando imaegen - 120 en Steven Barragan
# Procesando imaegen - 121 en Steven Barragan
# Procesando imaegen - 122 en Steven Barragan
# Procesando imaegen - 123 en Steven Barragan
# Procesando imaegen - 124 en Steven Barragan
# Procesando imaegen - 125 en Steven Barragan
# Procesando imaegen - 126 en Steven Barragan
# Procesando imaegen - 127 en Steven Barragan
# Procesando imaegen - 128 en Steven Barragan
# Procesando imaegen - 129 en Steven Barragan
# Procesando imaegen - 130 en Steven Barragan
# Procesando imaegen - 131 en Steven Barragan
# Procesando imaegen - 132 en Steven Barragan
# Procesando imaegen - 133 en Steven Barragan
# Procesando imaegen - 134 en Steven Barragan
# Procesando imaegen - 135 en Steven Barragan
# Procesando imaegen - 136 en Steven Barragan
# Procesando imaegen - 137 en Steven Barragan
# Procesando imaegen - 138 en Steven Barragan
# Procesando imaegen - 139 en Steven Barragan
# Procesando imaegen - 140 en Steven Barragan
# Procesando imaegen - 141 en Steven Barragan
# Procesando imaegen - 142 en Steven Barragan
# Procesando imaegen - 143 en Steven Barragan
# Procesando imaegen - 144 en Steven Barragan
# Procesando imaegen - 145 en Steven Barragan
# Procesando imaegen - 146 en Steven Barragan
# Procesando imaegen - 147 en Steven Barragan
# Procesando imaegen - 148 en Steven Barragan
# Procesando imaegen - 149 en Steven Barragan
# Procesando imaegen - 150 en Steven Barragan
# Procesando imaegen - 151 en Steven Barragan
# Procesando imaegen - 152 en Steven Barragan
# Procesando imaegen - 153 en Steven Barragan
# Procesando imaegen - 154 en Steven Barragan

# %% [markdown]
# ## Eliminando el fondo con aplicar filtro NLM

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_ruidoEliminado"
'''Se almacena los directorios de cada clase'''
nombre_clases = os.listdir(ruta_imagenes)

# %%
'''Se genera un bucle para recorrer cada etiqueta de las clases'''
for nombre_clase in nombre_clases:
    '''Se almacena la ruta actual de cada clase por ciclo'''
    ruta_actual = ruta_imagenes + "/" + nombre_clase
    '''Se almacenan las etiquetas de las clases'''
    etiqueta_actual = nombre_clase
    '''Se genera un iterador'''
    iterador = 1
    '''Se recorre cada imagen por clase sin importar su nombre o extensión'''
    for file in glob.glob(ruta_actual + "/*"):
        '''Se imprime el proceso'''
        print("Procesando imaegen - {} en {}".format(iterador, etiqueta_actual))
        '''Se leen las rutas de las imágenes'''
        imagen = cv2.imread(file)
        '''Se remueve el fondo'''
        salida = remove(imagen)
        '''Se guardan las imagenes'''
        ruta_guardado = './Estudiantes_datos_fondoEliminadoNLM/'+ etiqueta_actual
        '''Se genera cada imagen según la ruta de guardado'''
        cv2.imwrite(os.path.join(ruta_guardado , etiqueta_actual + '_' + str(iterador) + '.jpg'), salida)       
        '''Se aumenta el iterador'''
        iterador += 1
# Out:
# Procesando imaegen - 1 en Anthony Goyes
# Procesando imaegen - 2 en Anthony Goyes
# Procesando imaegen - 3 en Anthony Goyes
# Procesando imaegen - 4 en Anthony Goyes
# Procesando imaegen - 5 en Anthony Goyes
# Procesando imaegen - 6 en Anthony Goyes
# Procesando imaegen - 7 en Anthony Goyes
# Procesando imaegen - 8 en Anthony Goyes
# Procesando imaegen - 9 en Anthony Goyes
# Procesando imaegen - 10 en Anthony Goyes
# Procesando imaegen - 11 en Anthony Goyes
# Procesando imaegen - 12 en Anthony Goyes
# Procesando imaegen - 13 en Anthony Goyes
# Procesando imaegen - 14 en Anthony Goyes
# Procesando imaegen - 15 en Anthony Goyes
# Procesando imaegen - 16 en Anthony Goyes
# Procesando imaegen - 17 en Anthony Goyes
# Procesando imaegen - 18 en Anthony Goyes
# Procesando imaegen - 19 en Anthony Goyes
# Procesando imaegen - 20 en Anthony Goyes
# Procesando imaegen - 21 en Anthony Goyes
# Procesando imaegen - 22 en Anthony Goyes
# Procesando imaegen - 23 en Anthony Goyes
# Procesando imaegen - 24 en Anthony Goyes
# Procesando imaegen - 25 en Anthony Goyes
# Procesando imaegen - 26 en Anthony Goyes
# Procesando imaegen - 27 en Anthony Goyes
# Procesando imaegen - 28 en Anthony Goyes
# Procesando imaegen - 29 en Anthony Goyes
# Procesando imaegen - 30 en Anthony Goyes
# Procesando imaegen - 31 en Anthony Goyes
# Procesando imaegen - 32 en Anthony Goyes
# Procesando imaegen - 33 en Anthony Goyes
# Procesando imaegen - 34 en Anthony Goyes
# Procesando imaegen - 35 en Anthony Goyes
# Procesando imaegen - 36 en Anthony Goyes
# Procesando imaegen - 37 en Anthony Goyes
# Procesando imaegen - 38 en Anthony Goyes
# Procesando imaegen - 39 en Anthony Goyes
# Procesando imaegen - 40 en Anthony Goyes
# Procesando imaegen - 41 en Anthony Goyes
# Procesando imaegen - 42 en Anthony Goyes
# Procesando imaegen - 43 en Anthony Goyes
# Procesando imaegen - 44 en Anthony Goyes
# Procesando imaegen - 45 en Anthony Goyes
# Procesando imaegen - 46 en Anthony Goyes
# Procesando imaegen - 47 en Anthony Goyes
# Procesando imaegen - 48 en Anthony Goyes
# Procesando imaegen - 49 en Anthony Goyes
# Procesando imaegen - 50 en Anthony Goyes
# Procesando imaegen - 51 en Anthony Goyes
# Procesando imaegen - 52 en Anthony Goyes
# Procesando imaegen - 53 en Anthony Goyes
# Procesando imaegen - 54 en Anthony Goyes
# Procesando imaegen - 55 en Anthony Goyes
# Procesando imaegen - 56 en Anthony Goyes
# Procesando imaegen - 57 en Anthony Goyes
# Procesando imaegen - 58 en Anthony Goyes
# Procesando imaegen - 59 en Anthony Goyes
# Procesando imaegen - 60 en Anthony Goyes
# Procesando imaegen - 61 en Anthony Goyes
# Procesando imaegen - 62 en Anthony Goyes
# Procesando imaegen - 63 en Anthony Goyes
# Procesando imaegen - 64 en Anthony Goyes
# Procesando imaegen - 65 en Anthony Goyes
# Procesando imaegen - 66 en Anthony Goyes
# Procesando imaegen - 67 en Anthony Goyes
# Procesando imaegen - 68 en Anthony Goyes
# Procesando imaegen - 69 en Anthony Goyes
# Procesando imaegen - 70 en Anthony Goyes
# Procesando imaegen - 71 en Anthony Goyes
# Procesando imaegen - 72 en Anthony Goyes
# Procesando imaegen - 73 en Anthony Goyes
# Procesando imaegen - 74 en Anthony Goyes
# Procesando imaegen - 75 en Anthony Goyes
# Procesando imaegen - 76 en Anthony Goyes
# Procesando imaegen - 77 en Anthony Goyes
# Procesando imaegen - 78 en Anthony Goyes
# Procesando imaegen - 79 en Anthony Goyes
# Procesando imaegen - 80 en Anthony Goyes
# Procesando imaegen - 81 en Anthony Goyes
# Procesando imaegen - 82 en Anthony Goyes
# Procesando imaegen - 83 en Anthony Goyes
# Procesando imaegen - 84 en Anthony Goyes
# Procesando imaegen - 85 en Anthony Goyes
# Procesando imaegen - 86 en Anthony Goyes
# Procesando imaegen - 87 en Anthony Goyes
# Procesando imaegen - 88 en Anthony Goyes
# Procesando imaegen - 89 en Anthony Goyes
# Procesando imaegen - 90 en Anthony Goyes
# Procesando imaegen - 91 en Anthony Goyes
# Procesando imaegen - 92 en Anthony Goyes
# Procesando imaegen - 93 en Anthony Goyes
# Procesando imaegen - 94 en Anthony Goyes
# Procesando imaegen - 95 en Anthony Goyes
# Procesando imaegen - 96 en Anthony Goyes
# Procesando imaegen - 97 en Anthony Goyes
# Procesando imaegen - 98 en Anthony Goyes
# Procesando imaegen - 99 en Anthony Goyes
# Procesando imaegen - 100 en Anthony Goyes
# Procesando imaegen - 101 en Anthony Goyes
# Procesando imaegen - 102 en Anthony Goyes
# Procesando imaegen - 103 en Anthony Goyes
# Procesando imaegen - 104 en Anthony Goyes
# Procesando imaegen - 105 en Anthony Goyes
# Procesando imaegen - 106 en Anthony Goyes
# Procesando imaegen - 107 en Anthony Goyes
# Procesando imaegen - 108 en Anthony Goyes
# Procesando imaegen - 109 en Anthony Goyes
# Procesando imaegen - 110 en Anthony Goyes
# Procesando imaegen - 1 en Ariel Chabla
# Procesando imaegen - 2 en Ariel Chabla
# Procesando imaegen - 3 en Ariel Chabla
# Procesando imaegen - 4 en Ariel Chabla
# Procesando imaegen - 5 en Ariel Chabla
# Procesando imaegen - 6 en Ariel Chabla
# Procesando imaegen - 7 en Ariel Chabla
# Procesando imaegen - 8 en Ariel Chabla
# Procesando imaegen - 9 en Ariel Chabla
# Procesando imaegen - 10 en Ariel Chabla
# Procesando imaegen - 11 en Ariel Chabla
# Procesando imaegen - 12 en Ariel Chabla
# Procesando imaegen - 13 en Ariel Chabla
# Procesando imaegen - 14 en Ariel Chabla
# Procesando imaegen - 15 en Ariel Chabla
# Procesando imaegen - 16 en Ariel Chabla
# Procesando imaegen - 17 en Ariel Chabla
# Procesando imaegen - 18 en Ariel Chabla
# Procesando imaegen - 19 en Ariel Chabla
# Procesando imaegen - 20 en Ariel Chabla
# Procesando imaegen - 21 en Ariel Chabla
# Procesando imaegen - 22 en Ariel Chabla
# Procesando imaegen - 23 en Ariel Chabla
# Procesando imaegen - 24 en Ariel Chabla
# Procesando imaegen - 25 en Ariel Chabla
# Procesando imaegen - 26 en Ariel Chabla
# Procesando imaegen - 27 en Ariel Chabla
# Procesando imaegen - 28 en Ariel Chabla
# Procesando imaegen - 29 en Ariel Chabla
# Procesando imaegen - 30 en Ariel Chabla
# Procesando imaegen - 31 en Ariel Chabla
# Procesando imaegen - 32 en Ariel Chabla
# Procesando imaegen - 33 en Ariel Chabla
# Procesando imaegen - 34 en Ariel Chabla
# Procesando imaegen - 35 en Ariel Chabla
# Procesando imaegen - 36 en Ariel Chabla
# Procesando imaegen - 37 en Ariel Chabla
# Procesando imaegen - 38 en Ariel Chabla
# Procesando imaegen - 39 en Ariel Chabla
# Procesando imaegen - 40 en Ariel Chabla
# Procesando imaegen - 41 en Ariel Chabla
# Procesando imaegen - 42 en Ariel Chabla
# Procesando imaegen - 43 en Ariel Chabla
# Procesando imaegen - 44 en Ariel Chabla
# Procesando imaegen - 45 en Ariel Chabla
# Procesando imaegen - 46 en Ariel Chabla
# Procesando imaegen - 47 en Ariel Chabla
# Procesando imaegen - 48 en Ariel Chabla
# Procesando imaegen - 49 en Ariel Chabla
# Procesando imaegen - 50 en Ariel Chabla
# Procesando imaegen - 51 en Ariel Chabla
# Procesando imaegen - 52 en Ariel Chabla
# Procesando imaegen - 53 en Ariel Chabla
# Procesando imaegen - 54 en Ariel Chabla
# Procesando imaegen - 55 en Ariel Chabla
# Procesando imaegen - 56 en Ariel Chabla
# Procesando imaegen - 57 en Ariel Chabla
# Procesando imaegen - 58 en Ariel Chabla
# Procesando imaegen - 59 en Ariel Chabla
# Procesando imaegen - 60 en Ariel Chabla
# Procesando imaegen - 61 en Ariel Chabla
# Procesando imaegen - 62 en Ariel Chabla
# Procesando imaegen - 63 en Ariel Chabla
# Procesando imaegen - 64 en Ariel Chabla
# Procesando imaegen - 65 en Ariel Chabla
# Procesando imaegen - 66 en Ariel Chabla
# Procesando imaegen - 67 en Ariel Chabla
# Procesando imaegen - 68 en Ariel Chabla
# Procesando imaegen - 69 en Ariel Chabla
# Procesando imaegen - 70 en Ariel Chabla
# Procesando imaegen - 71 en Ariel Chabla
# Procesando imaegen - 72 en Ariel Chabla
# Procesando imaegen - 73 en Ariel Chabla
# Procesando imaegen - 74 en Ariel Chabla
# Procesando imaegen - 75 en Ariel Chabla
# Procesando imaegen - 76 en Ariel Chabla
# Procesando imaegen - 77 en Ariel Chabla
# Procesando imaegen - 78 en Ariel Chabla
# Procesando imaegen - 79 en Ariel Chabla
# Procesando imaegen - 80 en Ariel Chabla
# Procesando imaegen - 81 en Ariel Chabla
# Procesando imaegen - 82 en Ariel Chabla
# Procesando imaegen - 83 en Ariel Chabla
# Procesando imaegen - 84 en Ariel Chabla
# Procesando imaegen - 85 en Ariel Chabla
# Procesando imaegen - 86 en Ariel Chabla
# Procesando imaegen - 87 en Ariel Chabla
# Procesando imaegen - 88 en Ariel Chabla
# Procesando imaegen - 1 en Bryan Solorzano
# Procesando imaegen - 2 en Bryan Solorzano
# Procesando imaegen - 3 en Bryan Solorzano
# Procesando imaegen - 4 en Bryan Solorzano
# Procesando imaegen - 5 en Bryan Solorzano
# Procesando imaegen - 6 en Bryan Solorzano
# Procesando imaegen - 7 en Bryan Solorzano
# Procesando imaegen - 8 en Bryan Solorzano
# Procesando imaegen - 9 en Bryan Solorzano
# Procesando imaegen - 10 en Bryan Solorzano
# Procesando imaegen - 11 en Bryan Solorzano
# Procesando imaegen - 12 en Bryan Solorzano
# Procesando imaegen - 13 en Bryan Solorzano
# Procesando imaegen - 14 en Bryan Solorzano
# Procesando imaegen - 15 en Bryan Solorzano
# Procesando imaegen - 16 en Bryan Solorzano
# Procesando imaegen - 17 en Bryan Solorzano
# Procesando imaegen - 18 en Bryan Solorzano
# Procesando imaegen - 19 en Bryan Solorzano
# Procesando imaegen - 20 en Bryan Solorzano
# Procesando imaegen - 21 en Bryan Solorzano
# Procesando imaegen - 22 en Bryan Solorzano
# Procesando imaegen - 23 en Bryan Solorzano
# Procesando imaegen - 24 en Bryan Solorzano
# Procesando imaegen - 25 en Bryan Solorzano
# Procesando imaegen - 26 en Bryan Solorzano
# Procesando imaegen - 27 en Bryan Solorzano
# Procesando imaegen - 28 en Bryan Solorzano
# Procesando imaegen - 29 en Bryan Solorzano
# Procesando imaegen - 30 en Bryan Solorzano
# Procesando imaegen - 31 en Bryan Solorzano
# Procesando imaegen - 32 en Bryan Solorzano
# Procesando imaegen - 33 en Bryan Solorzano
# Procesando imaegen - 34 en Bryan Solorzano
# Procesando imaegen - 35 en Bryan Solorzano
# Procesando imaegen - 36 en Bryan Solorzano
# Procesando imaegen - 37 en Bryan Solorzano
# Procesando imaegen - 38 en Bryan Solorzano
# Procesando imaegen - 39 en Bryan Solorzano
# Procesando imaegen - 40 en Bryan Solorzano
# Procesando imaegen - 41 en Bryan Solorzano
# Procesando imaegen - 42 en Bryan Solorzano
# Procesando imaegen - 43 en Bryan Solorzano
# Procesando imaegen - 44 en Bryan Solorzano
# Procesando imaegen - 45 en Bryan Solorzano
# Procesando imaegen - 46 en Bryan Solorzano
# Procesando imaegen - 47 en Bryan Solorzano
# Procesando imaegen - 48 en Bryan Solorzano
# Procesando imaegen - 49 en Bryan Solorzano
# Procesando imaegen - 50 en Bryan Solorzano
# Procesando imaegen - 51 en Bryan Solorzano
# Procesando imaegen - 52 en Bryan Solorzano
# Procesando imaegen - 53 en Bryan Solorzano
# Procesando imaegen - 54 en Bryan Solorzano
# Procesando imaegen - 55 en Bryan Solorzano
# Procesando imaegen - 56 en Bryan Solorzano
# Procesando imaegen - 57 en Bryan Solorzano
# Procesando imaegen - 58 en Bryan Solorzano
# Procesando imaegen - 59 en Bryan Solorzano
# Procesando imaegen - 60 en Bryan Solorzano
# Procesando imaegen - 61 en Bryan Solorzano
# Procesando imaegen - 62 en Bryan Solorzano
# Procesando imaegen - 63 en Bryan Solorzano
# Procesando imaegen - 64 en Bryan Solorzano
# Procesando imaegen - 65 en Bryan Solorzano
# Procesando imaegen - 66 en Bryan Solorzano
# Procesando imaegen - 67 en Bryan Solorzano
# Procesando imaegen - 68 en Bryan Solorzano
# Procesando imaegen - 69 en Bryan Solorzano
# Procesando imaegen - 70 en Bryan Solorzano
# Procesando imaegen - 71 en Bryan Solorzano
# Procesando imaegen - 72 en Bryan Solorzano
# Procesando imaegen - 73 en Bryan Solorzano
# Procesando imaegen - 74 en Bryan Solorzano
# Procesando imaegen - 75 en Bryan Solorzano
# Procesando imaegen - 76 en Bryan Solorzano
# Procesando imaegen - 77 en Bryan Solorzano
# Procesando imaegen - 78 en Bryan Solorzano
# Procesando imaegen - 79 en Bryan Solorzano
# Procesando imaegen - 80 en Bryan Solorzano
# Procesando imaegen - 81 en Bryan Solorzano
# Procesando imaegen - 82 en Bryan Solorzano
# Procesando imaegen - 83 en Bryan Solorzano
# Procesando imaegen - 84 en Bryan Solorzano
# Procesando imaegen - 85 en Bryan Solorzano
# Procesando imaegen - 86 en Bryan Solorzano
# Procesando imaegen - 87 en Bryan Solorzano
# Procesando imaegen - 88 en Bryan Solorzano
# Procesando imaegen - 89 en Bryan Solorzano
# Procesando imaegen - 90 en Bryan Solorzano
# Procesando imaegen - 91 en Bryan Solorzano
# Procesando imaegen - 92 en Bryan Solorzano
# Procesando imaegen - 93 en Bryan Solorzano
# Procesando imaegen - 94 en Bryan Solorzano
# Procesando imaegen - 95 en Bryan Solorzano
# Procesando imaegen - 96 en Bryan Solorzano
# Procesando imaegen - 97 en Bryan Solorzano
# Procesando imaegen - 98 en Bryan Solorzano
# Procesando imaegen - 1 en Davila Raymond
# Procesando imaegen - 2 en Davila Raymond
# Procesando imaegen - 3 en Davila Raymond
# Procesando imaegen - 4 en Davila Raymond
# Procesando imaegen - 5 en Davila Raymond
# Procesando imaegen - 6 en Davila Raymond
# Procesando imaegen - 7 en Davila Raymond
# Procesando imaegen - 8 en Davila Raymond
# Procesando imaegen - 9 en Davila Raymond
# Procesando imaegen - 10 en Davila Raymond
# Procesando imaegen - 11 en Davila Raymond
# Procesando imaegen - 12 en Davila Raymond
# Procesando imaegen - 13 en Davila Raymond
# Procesando imaegen - 14 en Davila Raymond
# Procesando imaegen - 15 en Davila Raymond
# Procesando imaegen - 16 en Davila Raymond
# Procesando imaegen - 17 en Davila Raymond
# Procesando imaegen - 18 en Davila Raymond
# Procesando imaegen - 19 en Davila Raymond
# Procesando imaegen - 20 en Davila Raymond
# Procesando imaegen - 21 en Davila Raymond
# Procesando imaegen - 22 en Davila Raymond
# Procesando imaegen - 23 en Davila Raymond
# Procesando imaegen - 24 en Davila Raymond
# Procesando imaegen - 25 en Davila Raymond
# Procesando imaegen - 26 en Davila Raymond
# Procesando imaegen - 27 en Davila Raymond
# Procesando imaegen - 28 en Davila Raymond
# Procesando imaegen - 29 en Davila Raymond
# Procesando imaegen - 30 en Davila Raymond
# Procesando imaegen - 31 en Davila Raymond
# Procesando imaegen - 32 en Davila Raymond
# Procesando imaegen - 33 en Davila Raymond
# Procesando imaegen - 34 en Davila Raymond
# Procesando imaegen - 35 en Davila Raymond
# Procesando imaegen - 36 en Davila Raymond
# Procesando imaegen - 37 en Davila Raymond
# Procesando imaegen - 38 en Davila Raymond
# Procesando imaegen - 39 en Davila Raymond
# Procesando imaegen - 40 en Davila Raymond
# Procesando imaegen - 41 en Davila Raymond
# Procesando imaegen - 42 en Davila Raymond
# Procesando imaegen - 43 en Davila Raymond
# Procesando imaegen - 44 en Davila Raymond
# Procesando imaegen - 45 en Davila Raymond
# Procesando imaegen - 46 en Davila Raymond
# Procesando imaegen - 47 en Davila Raymond
# Procesando imaegen - 48 en Davila Raymond
# Procesando imaegen - 49 en Davila Raymond
# Procesando imaegen - 50 en Davila Raymond
# Procesando imaegen - 51 en Davila Raymond
# Procesando imaegen - 52 en Davila Raymond
# Procesando imaegen - 53 en Davila Raymond
# Procesando imaegen - 54 en Davila Raymond
# Procesando imaegen - 55 en Davila Raymond
# Procesando imaegen - 56 en Davila Raymond
# Procesando imaegen - 57 en Davila Raymond
# Procesando imaegen - 58 en Davila Raymond
# Procesando imaegen - 59 en Davila Raymond
# Procesando imaegen - 60 en Davila Raymond
# Procesando imaegen - 61 en Davila Raymond
# Procesando imaegen - 62 en Davila Raymond
# Procesando imaegen - 63 en Davila Raymond
# Procesando imaegen - 64 en Davila Raymond
# Procesando imaegen - 65 en Davila Raymond
# Procesando imaegen - 66 en Davila Raymond
# Procesando imaegen - 67 en Davila Raymond
# Procesando imaegen - 68 en Davila Raymond
# Procesando imaegen - 69 en Davila Raymond
# Procesando imaegen - 70 en Davila Raymond
# Procesando imaegen - 71 en Davila Raymond
# Procesando imaegen - 72 en Davila Raymond
# Procesando imaegen - 73 en Davila Raymond
# Procesando imaegen - 74 en Davila Raymond
# Procesando imaegen - 75 en Davila Raymond
# Procesando imaegen - 76 en Davila Raymond
# Procesando imaegen - 77 en Davila Raymond
# Procesando imaegen - 78 en Davila Raymond
# Procesando imaegen - 79 en Davila Raymond
# Procesando imaegen - 80 en Davila Raymond
# Procesando imaegen - 81 en Davila Raymond
# Procesando imaegen - 82 en Davila Raymond
# Procesando imaegen - 83 en Davila Raymond
# Procesando imaegen - 84 en Davila Raymond
# Procesando imaegen - 85 en Davila Raymond
# Procesando imaegen - 86 en Davila Raymond
# Procesando imaegen - 87 en Davila Raymond
# Procesando imaegen - 88 en Davila Raymond
# Procesando imaegen - 89 en Davila Raymond
# Procesando imaegen - 90 en Davila Raymond
# Procesando imaegen - 91 en Davila Raymond
# Procesando imaegen - 92 en Davila Raymond
# Procesando imaegen - 93 en Davila Raymond
# Procesando imaegen - 94 en Davila Raymond
# Procesando imaegen - 95 en Davila Raymond
# Procesando imaegen - 96 en Davila Raymond
# Procesando imaegen - 97 en Davila Raymond
# Procesando imaegen - 98 en Davila Raymond
# Procesando imaegen - 1 en Fernando Masache
# Procesando imaegen - 2 en Fernando Masache
# Procesando imaegen - 3 en Fernando Masache
# Procesando imaegen - 4 en Fernando Masache
# Procesando imaegen - 5 en Fernando Masache
# Procesando imaegen - 6 en Fernando Masache
# Procesando imaegen - 7 en Fernando Masache
# Procesando imaegen - 8 en Fernando Masache
# Procesando imaegen - 9 en Fernando Masache
# Procesando imaegen - 10 en Fernando Masache
# Procesando imaegen - 11 en Fernando Masache
# Procesando imaegen - 12 en Fernando Masache
# Procesando imaegen - 13 en Fernando Masache
# Procesando imaegen - 14 en Fernando Masache
# Procesando imaegen - 15 en Fernando Masache
# Procesando imaegen - 16 en Fernando Masache
# Procesando imaegen - 17 en Fernando Masache
# Procesando imaegen - 18 en Fernando Masache
# Procesando imaegen - 19 en Fernando Masache
# Procesando imaegen - 20 en Fernando Masache
# Procesando imaegen - 21 en Fernando Masache
# Procesando imaegen - 22 en Fernando Masache
# Procesando imaegen - 23 en Fernando Masache
# Procesando imaegen - 24 en Fernando Masache
# Procesando imaegen - 25 en Fernando Masache
# Procesando imaegen - 26 en Fernando Masache
# Procesando imaegen - 27 en Fernando Masache
# Procesando imaegen - 28 en Fernando Masache
# Procesando imaegen - 29 en Fernando Masache
# Procesando imaegen - 30 en Fernando Masache
# Procesando imaegen - 31 en Fernando Masache
# Procesando imaegen - 32 en Fernando Masache
# Procesando imaegen - 33 en Fernando Masache
# Procesando imaegen - 34 en Fernando Masache
# Procesando imaegen - 35 en Fernando Masache
# Procesando imaegen - 36 en Fernando Masache
# Procesando imaegen - 37 en Fernando Masache
# Procesando imaegen - 38 en Fernando Masache
# Procesando imaegen - 39 en Fernando Masache
# Procesando imaegen - 40 en Fernando Masache
# Procesando imaegen - 41 en Fernando Masache
# Procesando imaegen - 42 en Fernando Masache
# Procesando imaegen - 43 en Fernando Masache
# Procesando imaegen - 44 en Fernando Masache
# Procesando imaegen - 45 en Fernando Masache
# Procesando imaegen - 46 en Fernando Masache
# Procesando imaegen - 47 en Fernando Masache
# Procesando imaegen - 48 en Fernando Masache
# Procesando imaegen - 49 en Fernando Masache
# Procesando imaegen - 50 en Fernando Masache
# Procesando imaegen - 51 en Fernando Masache
# Procesando imaegen - 52 en Fernando Masache
# Procesando imaegen - 53 en Fernando Masache
# Procesando imaegen - 54 en Fernando Masache
# Procesando imaegen - 55 en Fernando Masache
# Procesando imaegen - 56 en Fernando Masache
# Procesando imaegen - 57 en Fernando Masache
# Procesando imaegen - 58 en Fernando Masache
# Procesando imaegen - 59 en Fernando Masache
# Procesando imaegen - 60 en Fernando Masache
# Procesando imaegen - 61 en Fernando Masache
# Procesando imaegen - 62 en Fernando Masache
# Procesando imaegen - 63 en Fernando Masache
# Procesando imaegen - 64 en Fernando Masache
# Procesando imaegen - 65 en Fernando Masache
# Procesando imaegen - 66 en Fernando Masache
# Procesando imaegen - 67 en Fernando Masache
# Procesando imaegen - 68 en Fernando Masache
# Procesando imaegen - 69 en Fernando Masache
# Procesando imaegen - 70 en Fernando Masache
# Procesando imaegen - 71 en Fernando Masache
# Procesando imaegen - 72 en Fernando Masache
# Procesando imaegen - 73 en Fernando Masache
# Procesando imaegen - 74 en Fernando Masache
# Procesando imaegen - 75 en Fernando Masache
# Procesando imaegen - 76 en Fernando Masache
# Procesando imaegen - 77 en Fernando Masache
# Procesando imaegen - 78 en Fernando Masache
# Procesando imaegen - 79 en Fernando Masache
# Procesando imaegen - 80 en Fernando Masache
# Procesando imaegen - 81 en Fernando Masache
# Procesando imaegen - 82 en Fernando Masache
# Procesando imaegen - 83 en Fernando Masache
# Procesando imaegen - 84 en Fernando Masache
# Procesando imaegen - 85 en Fernando Masache
# Procesando imaegen - 86 en Fernando Masache
# Procesando imaegen - 87 en Fernando Masache
# Procesando imaegen - 88 en Fernando Masache
# Procesando imaegen - 89 en Fernando Masache
# Procesando imaegen - 90 en Fernando Masache
# Procesando imaegen - 91 en Fernando Masache
# Procesando imaegen - 92 en Fernando Masache
# Procesando imaegen - 93 en Fernando Masache
# Procesando imaegen - 94 en Fernando Masache
# Procesando imaegen - 95 en Fernando Masache
# Procesando imaegen - 96 en Fernando Masache
# Procesando imaegen - 97 en Fernando Masache
# Procesando imaegen - 98 en Fernando Masache
# Procesando imaegen - 99 en Fernando Masache
# Procesando imaegen - 100 en Fernando Masache
# Procesando imaegen - 101 en Fernando Masache
# Procesando imaegen - 102 en Fernando Masache
# Procesando imaegen - 103 en Fernando Masache
# Procesando imaegen - 104 en Fernando Masache
# Procesando imaegen - 105 en Fernando Masache
# Procesando imaegen - 106 en Fernando Masache
# Procesando imaegen - 107 en Fernando Masache
# Procesando imaegen - 108 en Fernando Masache
# Procesando imaegen - 109 en Fernando Masache
# Procesando imaegen - 110 en Fernando Masache
# Procesando imaegen - 1 en Genesis Heredia
# Procesando imaegen - 2 en Genesis Heredia
# Procesando imaegen - 3 en Genesis Heredia
# Procesando imaegen - 4 en Genesis Heredia
# Procesando imaegen - 5 en Genesis Heredia
# Procesando imaegen - 6 en Genesis Heredia
# Procesando imaegen - 7 en Genesis Heredia
# Procesando imaegen - 8 en Genesis Heredia
# Procesando imaegen - 9 en Genesis Heredia
# Procesando imaegen - 10 en Genesis Heredia
# Procesando imaegen - 11 en Genesis Heredia
# Procesando imaegen - 12 en Genesis Heredia
# Procesando imaegen - 13 en Genesis Heredia
# Procesando imaegen - 14 en Genesis Heredia
# Procesando imaegen - 15 en Genesis Heredia
# Procesando imaegen - 16 en Genesis Heredia
# Procesando imaegen - 17 en Genesis Heredia
# Procesando imaegen - 18 en Genesis Heredia
# Procesando imaegen - 19 en Genesis Heredia
# Procesando imaegen - 20 en Genesis Heredia
# Procesando imaegen - 21 en Genesis Heredia
# Procesando imaegen - 22 en Genesis Heredia
# Procesando imaegen - 23 en Genesis Heredia
# Procesando imaegen - 24 en Genesis Heredia
# Procesando imaegen - 25 en Genesis Heredia
# Procesando imaegen - 26 en Genesis Heredia
# Procesando imaegen - 27 en Genesis Heredia
# Procesando imaegen - 28 en Genesis Heredia
# Procesando imaegen - 29 en Genesis Heredia
# Procesando imaegen - 30 en Genesis Heredia
# Procesando imaegen - 31 en Genesis Heredia
# Procesando imaegen - 32 en Genesis Heredia
# Procesando imaegen - 33 en Genesis Heredia
# Procesando imaegen - 34 en Genesis Heredia
# Procesando imaegen - 35 en Genesis Heredia
# Procesando imaegen - 36 en Genesis Heredia
# Procesando imaegen - 37 en Genesis Heredia
# Procesando imaegen - 38 en Genesis Heredia
# Procesando imaegen - 39 en Genesis Heredia
# Procesando imaegen - 40 en Genesis Heredia
# Procesando imaegen - 41 en Genesis Heredia
# Procesando imaegen - 42 en Genesis Heredia
# Procesando imaegen - 43 en Genesis Heredia
# Procesando imaegen - 44 en Genesis Heredia
# Procesando imaegen - 45 en Genesis Heredia
# Procesando imaegen - 46 en Genesis Heredia
# Procesando imaegen - 47 en Genesis Heredia
# Procesando imaegen - 48 en Genesis Heredia
# Procesando imaegen - 49 en Genesis Heredia
# Procesando imaegen - 50 en Genesis Heredia
# Procesando imaegen - 51 en Genesis Heredia
# Procesando imaegen - 52 en Genesis Heredia
# Procesando imaegen - 53 en Genesis Heredia
# Procesando imaegen - 54 en Genesis Heredia
# Procesando imaegen - 55 en Genesis Heredia
# Procesando imaegen - 56 en Genesis Heredia
# Procesando imaegen - 57 en Genesis Heredia
# Procesando imaegen - 58 en Genesis Heredia
# Procesando imaegen - 59 en Genesis Heredia
# Procesando imaegen - 60 en Genesis Heredia
# Procesando imaegen - 61 en Genesis Heredia
# Procesando imaegen - 62 en Genesis Heredia
# Procesando imaegen - 63 en Genesis Heredia
# Procesando imaegen - 64 en Genesis Heredia
# Procesando imaegen - 65 en Genesis Heredia
# Procesando imaegen - 66 en Genesis Heredia
# Procesando imaegen - 67 en Genesis Heredia
# Procesando imaegen - 68 en Genesis Heredia
# Procesando imaegen - 69 en Genesis Heredia
# Procesando imaegen - 70 en Genesis Heredia
# Procesando imaegen - 71 en Genesis Heredia
# Procesando imaegen - 72 en Genesis Heredia
# Procesando imaegen - 73 en Genesis Heredia
# Procesando imaegen - 74 en Genesis Heredia
# Procesando imaegen - 75 en Genesis Heredia
# Procesando imaegen - 76 en Genesis Heredia
# Procesando imaegen - 77 en Genesis Heredia
# Procesando imaegen - 78 en Genesis Heredia
# Procesando imaegen - 79 en Genesis Heredia
# Procesando imaegen - 80 en Genesis Heredia
# Procesando imaegen - 81 en Genesis Heredia
# Procesando imaegen - 82 en Genesis Heredia
# Procesando imaegen - 83 en Genesis Heredia
# Procesando imaegen - 84 en Genesis Heredia
# Procesando imaegen - 85 en Genesis Heredia
# Procesando imaegen - 86 en Genesis Heredia
# Procesando imaegen - 87 en Genesis Heredia
# Procesando imaegen - 88 en Genesis Heredia
# Procesando imaegen - 89 en Genesis Heredia
# Procesando imaegen - 90 en Genesis Heredia
# Procesando imaegen - 91 en Genesis Heredia
# Procesando imaegen - 92 en Genesis Heredia
# Procesando imaegen - 93 en Genesis Heredia
# Procesando imaegen - 94 en Genesis Heredia
# Procesando imaegen - 95 en Genesis Heredia
# Procesando imaegen - 96 en Genesis Heredia
# Procesando imaegen - 97 en Genesis Heredia
# Procesando imaegen - 98 en Genesis Heredia
# Procesando imaegen - 99 en Genesis Heredia
# Procesando imaegen - 100 en Genesis Heredia
# Procesando imaegen - 101 en Genesis Heredia
# Procesando imaegen - 102 en Genesis Heredia
# Procesando imaegen - 103 en Genesis Heredia
# Procesando imaegen - 104 en Genesis Heredia
# Procesando imaegen - 105 en Genesis Heredia
# Procesando imaegen - 106 en Genesis Heredia
# Procesando imaegen - 107 en Genesis Heredia
# Procesando imaegen - 108 en Genesis Heredia
# Procesando imaegen - 1 en Hector Cedenio
# Procesando imaegen - 2 en Hector Cedenio
# Procesando imaegen - 3 en Hector Cedenio
# Procesando imaegen - 4 en Hector Cedenio
# Procesando imaegen - 5 en Hector Cedenio
# Procesando imaegen - 6 en Hector Cedenio
# Procesando imaegen - 7 en Hector Cedenio
# Procesando imaegen - 8 en Hector Cedenio
# Procesando imaegen - 9 en Hector Cedenio
# Procesando imaegen - 10 en Hector Cedenio
# Procesando imaegen - 11 en Hector Cedenio
# Procesando imaegen - 12 en Hector Cedenio
# Procesando imaegen - 13 en Hector Cedenio
# Procesando imaegen - 14 en Hector Cedenio
# Procesando imaegen - 15 en Hector Cedenio
# Procesando imaegen - 16 en Hector Cedenio
# Procesando imaegen - 17 en Hector Cedenio
# Procesando imaegen - 18 en Hector Cedenio
# Procesando imaegen - 19 en Hector Cedenio
# Procesando imaegen - 20 en Hector Cedenio
# Procesando imaegen - 21 en Hector Cedenio
# Procesando imaegen - 22 en Hector Cedenio
# Procesando imaegen - 23 en Hector Cedenio
# Procesando imaegen - 24 en Hector Cedenio
# Procesando imaegen - 25 en Hector Cedenio
# Procesando imaegen - 26 en Hector Cedenio
# Procesando imaegen - 27 en Hector Cedenio
# Procesando imaegen - 28 en Hector Cedenio
# Procesando imaegen - 29 en Hector Cedenio
# Procesando imaegen - 30 en Hector Cedenio
# Procesando imaegen - 31 en Hector Cedenio
# Procesando imaegen - 32 en Hector Cedenio
# Procesando imaegen - 33 en Hector Cedenio
# Procesando imaegen - 34 en Hector Cedenio
# Procesando imaegen - 35 en Hector Cedenio
# Procesando imaegen - 36 en Hector Cedenio
# Procesando imaegen - 37 en Hector Cedenio
# Procesando imaegen - 38 en Hector Cedenio
# Procesando imaegen - 39 en Hector Cedenio
# Procesando imaegen - 40 en Hector Cedenio
# Procesando imaegen - 41 en Hector Cedenio
# Procesando imaegen - 42 en Hector Cedenio
# Procesando imaegen - 43 en Hector Cedenio
# Procesando imaegen - 44 en Hector Cedenio
# Procesando imaegen - 45 en Hector Cedenio
# Procesando imaegen - 46 en Hector Cedenio
# Procesando imaegen - 47 en Hector Cedenio
# Procesando imaegen - 48 en Hector Cedenio
# Procesando imaegen - 49 en Hector Cedenio
# Procesando imaegen - 50 en Hector Cedenio
# Procesando imaegen - 51 en Hector Cedenio
# Procesando imaegen - 52 en Hector Cedenio
# Procesando imaegen - 53 en Hector Cedenio
# Procesando imaegen - 54 en Hector Cedenio
# Procesando imaegen - 55 en Hector Cedenio
# Procesando imaegen - 56 en Hector Cedenio
# Procesando imaegen - 57 en Hector Cedenio
# Procesando imaegen - 58 en Hector Cedenio
# Procesando imaegen - 59 en Hector Cedenio
# Procesando imaegen - 60 en Hector Cedenio
# Procesando imaegen - 61 en Hector Cedenio
# Procesando imaegen - 62 en Hector Cedenio
# Procesando imaegen - 63 en Hector Cedenio
# Procesando imaegen - 64 en Hector Cedenio
# Procesando imaegen - 65 en Hector Cedenio
# Procesando imaegen - 66 en Hector Cedenio
# Procesando imaegen - 67 en Hector Cedenio
# Procesando imaegen - 68 en Hector Cedenio
# Procesando imaegen - 69 en Hector Cedenio
# Procesando imaegen - 70 en Hector Cedenio
# Procesando imaegen - 71 en Hector Cedenio
# Procesando imaegen - 72 en Hector Cedenio
# Procesando imaegen - 73 en Hector Cedenio
# Procesando imaegen - 74 en Hector Cedenio
# Procesando imaegen - 75 en Hector Cedenio
# Procesando imaegen - 76 en Hector Cedenio
# Procesando imaegen - 77 en Hector Cedenio
# Procesando imaegen - 78 en Hector Cedenio
# Procesando imaegen - 79 en Hector Cedenio
# Procesando imaegen - 80 en Hector Cedenio
# Procesando imaegen - 81 en Hector Cedenio
# Procesando imaegen - 82 en Hector Cedenio
# Procesando imaegen - 83 en Hector Cedenio
# Procesando imaegen - 84 en Hector Cedenio
# Procesando imaegen - 85 en Hector Cedenio
# Procesando imaegen - 86 en Hector Cedenio
# Procesando imaegen - 87 en Hector Cedenio
# Procesando imaegen - 88 en Hector Cedenio
# Procesando imaegen - 89 en Hector Cedenio
# Procesando imaegen - 90 en Hector Cedenio
# Procesando imaegen - 91 en Hector Cedenio
# Procesando imaegen - 92 en Hector Cedenio
# Procesando imaegen - 93 en Hector Cedenio
# Procesando imaegen - 94 en Hector Cedenio
# Procesando imaegen - 95 en Hector Cedenio
# Procesando imaegen - 96 en Hector Cedenio
# Procesando imaegen - 97 en Hector Cedenio
# Procesando imaegen - 98 en Hector Cedenio
# Procesando imaegen - 99 en Hector Cedenio
# Procesando imaegen - 100 en Hector Cedenio
# Procesando imaegen - 101 en Hector Cedenio
# Procesando imaegen - 102 en Hector Cedenio
# Procesando imaegen - 103 en Hector Cedenio
# Procesando imaegen - 104 en Hector Cedenio
# Procesando imaegen - 105 en Hector Cedenio
# Procesando imaegen - 106 en Hector Cedenio
# Procesando imaegen - 107 en Hector Cedenio
# Procesando imaegen - 108 en Hector Cedenio
# Procesando imaegen - 109 en Hector Cedenio
# Procesando imaegen - 1 en Jhon Zambrano
# Procesando imaegen - 2 en Jhon Zambrano
# Procesando imaegen - 3 en Jhon Zambrano
# Procesando imaegen - 4 en Jhon Zambrano
# Procesando imaegen - 5 en Jhon Zambrano
# Procesando imaegen - 6 en Jhon Zambrano
# Procesando imaegen - 7 en Jhon Zambrano
# Procesando imaegen - 8 en Jhon Zambrano
# Procesando imaegen - 9 en Jhon Zambrano
# Procesando imaegen - 10 en Jhon Zambrano
# Procesando imaegen - 11 en Jhon Zambrano
# Procesando imaegen - 12 en Jhon Zambrano
# Procesando imaegen - 13 en Jhon Zambrano
# Procesando imaegen - 14 en Jhon Zambrano
# Procesando imaegen - 15 en Jhon Zambrano
# Procesando imaegen - 16 en Jhon Zambrano
# Procesando imaegen - 17 en Jhon Zambrano
# Procesando imaegen - 18 en Jhon Zambrano
# Procesando imaegen - 19 en Jhon Zambrano
# Procesando imaegen - 20 en Jhon Zambrano
# Procesando imaegen - 21 en Jhon Zambrano
# Procesando imaegen - 22 en Jhon Zambrano
# Procesando imaegen - 23 en Jhon Zambrano
# Procesando imaegen - 24 en Jhon Zambrano
# Procesando imaegen - 25 en Jhon Zambrano
# Procesando imaegen - 26 en Jhon Zambrano
# Procesando imaegen - 27 en Jhon Zambrano
# Procesando imaegen - 28 en Jhon Zambrano
# Procesando imaegen - 29 en Jhon Zambrano
# Procesando imaegen - 30 en Jhon Zambrano
# Procesando imaegen - 31 en Jhon Zambrano
# Procesando imaegen - 32 en Jhon Zambrano
# Procesando imaegen - 33 en Jhon Zambrano
# Procesando imaegen - 34 en Jhon Zambrano
# Procesando imaegen - 35 en Jhon Zambrano
# Procesando imaegen - 36 en Jhon Zambrano
# Procesando imaegen - 37 en Jhon Zambrano
# Procesando imaegen - 38 en Jhon Zambrano
# Procesando imaegen - 39 en Jhon Zambrano
# Procesando imaegen - 40 en Jhon Zambrano
# Procesando imaegen - 41 en Jhon Zambrano
# Procesando imaegen - 42 en Jhon Zambrano
# Procesando imaegen - 43 en Jhon Zambrano
# Procesando imaegen - 44 en Jhon Zambrano
# Procesando imaegen - 45 en Jhon Zambrano
# Procesando imaegen - 46 en Jhon Zambrano
# Procesando imaegen - 47 en Jhon Zambrano
# Procesando imaegen - 48 en Jhon Zambrano
# Procesando imaegen - 49 en Jhon Zambrano
# Procesando imaegen - 50 en Jhon Zambrano
# Procesando imaegen - 51 en Jhon Zambrano
# Procesando imaegen - 52 en Jhon Zambrano
# Procesando imaegen - 53 en Jhon Zambrano
# Procesando imaegen - 54 en Jhon Zambrano
# Procesando imaegen - 55 en Jhon Zambrano
# Procesando imaegen - 56 en Jhon Zambrano
# Procesando imaegen - 57 en Jhon Zambrano
# Procesando imaegen - 58 en Jhon Zambrano
# Procesando imaegen - 59 en Jhon Zambrano
# Procesando imaegen - 60 en Jhon Zambrano
# Procesando imaegen - 61 en Jhon Zambrano
# Procesando imaegen - 62 en Jhon Zambrano
# Procesando imaegen - 63 en Jhon Zambrano
# Procesando imaegen - 64 en Jhon Zambrano
# Procesando imaegen - 65 en Jhon Zambrano
# Procesando imaegen - 66 en Jhon Zambrano
# Procesando imaegen - 67 en Jhon Zambrano
# Procesando imaegen - 68 en Jhon Zambrano
# Procesando imaegen - 69 en Jhon Zambrano
# Procesando imaegen - 70 en Jhon Zambrano
# Procesando imaegen - 71 en Jhon Zambrano
# Procesando imaegen - 72 en Jhon Zambrano
# Procesando imaegen - 73 en Jhon Zambrano
# Procesando imaegen - 74 en Jhon Zambrano
# Procesando imaegen - 75 en Jhon Zambrano
# Procesando imaegen - 76 en Jhon Zambrano
# Procesando imaegen - 77 en Jhon Zambrano
# Procesando imaegen - 78 en Jhon Zambrano
# Procesando imaegen - 79 en Jhon Zambrano
# Procesando imaegen - 80 en Jhon Zambrano
# Procesando imaegen - 81 en Jhon Zambrano
# Procesando imaegen - 82 en Jhon Zambrano
# Procesando imaegen - 83 en Jhon Zambrano
# Procesando imaegen - 84 en Jhon Zambrano
# Procesando imaegen - 85 en Jhon Zambrano
# Procesando imaegen - 86 en Jhon Zambrano
# Procesando imaegen - 87 en Jhon Zambrano
# Procesando imaegen - 88 en Jhon Zambrano
# Procesando imaegen - 89 en Jhon Zambrano
# Procesando imaegen - 90 en Jhon Zambrano
# Procesando imaegen - 91 en Jhon Zambrano
# Procesando imaegen - 92 en Jhon Zambrano
# Procesando imaegen - 93 en Jhon Zambrano
# Procesando imaegen - 94 en Jhon Zambrano
# Procesando imaegen - 95 en Jhon Zambrano
# Procesando imaegen - 96 en Jhon Zambrano
# Procesando imaegen - 97 en Jhon Zambrano
# Procesando imaegen - 98 en Jhon Zambrano
# Procesando imaegen - 99 en Jhon Zambrano
# Procesando imaegen - 100 en Jhon Zambrano
# Procesando imaegen - 101 en Jhon Zambrano
# Procesando imaegen - 102 en Jhon Zambrano
# Procesando imaegen - 103 en Jhon Zambrano
# Procesando imaegen - 104 en Jhon Zambrano
# Procesando imaegen - 105 en Jhon Zambrano
# Procesando imaegen - 106 en Jhon Zambrano
# Procesando imaegen - 107 en Jhon Zambrano
# Procesando imaegen - 108 en Jhon Zambrano
# Procesando imaegen - 109 en Jhon Zambrano
# Procesando imaegen - 110 en Jhon Zambrano
# Procesando imaegen - 111 en Jhon Zambrano
# Procesando imaegen - 112 en Jhon Zambrano
# Procesando imaegen - 113 en Jhon Zambrano
# Procesando imaegen - 114 en Jhon Zambrano
# Procesando imaegen - 115 en Jhon Zambrano
# Procesando imaegen - 116 en Jhon Zambrano
# Procesando imaegen - 117 en Jhon Zambrano
# Procesando imaegen - 118 en Jhon Zambrano
# Procesando imaegen - 119 en Jhon Zambrano
# Procesando imaegen - 120 en Jhon Zambrano
# Procesando imaegen - 121 en Jhon Zambrano
# Procesando imaegen - 122 en Jhon Zambrano
# Procesando imaegen - 123 en Jhon Zambrano
# Procesando imaegen - 124 en Jhon Zambrano
# Procesando imaegen - 125 en Jhon Zambrano
# Procesando imaegen - 126 en Jhon Zambrano
# Procesando imaegen - 127 en Jhon Zambrano
# Procesando imaegen - 128 en Jhon Zambrano
# Procesando imaegen - 129 en Jhon Zambrano
# Procesando imaegen - 130 en Jhon Zambrano
# Procesando imaegen - 131 en Jhon Zambrano
# Procesando imaegen - 132 en Jhon Zambrano
# Procesando imaegen - 133 en Jhon Zambrano
# Procesando imaegen - 134 en Jhon Zambrano
# Procesando imaegen - 135 en Jhon Zambrano
# Procesando imaegen - 136 en Jhon Zambrano
# Procesando imaegen - 137 en Jhon Zambrano
# Procesando imaegen - 138 en Jhon Zambrano
# Procesando imaegen - 139 en Jhon Zambrano
# Procesando imaegen - 140 en Jhon Zambrano
# Procesando imaegen - 141 en Jhon Zambrano
# Procesando imaegen - 142 en Jhon Zambrano
# Procesando imaegen - 143 en Jhon Zambrano
# Procesando imaegen - 1 en Joan Cevallos
# Procesando imaegen - 2 en Joan Cevallos
# Procesando imaegen - 3 en Joan Cevallos
# Procesando imaegen - 4 en Joan Cevallos
# Procesando imaegen - 5 en Joan Cevallos
# Procesando imaegen - 6 en Joan Cevallos
# Procesando imaegen - 7 en Joan Cevallos
# Procesando imaegen - 8 en Joan Cevallos
# Procesando imaegen - 9 en Joan Cevallos
# Procesando imaegen - 10 en Joan Cevallos
# Procesando imaegen - 11 en Joan Cevallos
# Procesando imaegen - 12 en Joan Cevallos
# Procesando imaegen - 13 en Joan Cevallos
# Procesando imaegen - 14 en Joan Cevallos
# Procesando imaegen - 15 en Joan Cevallos
# Procesando imaegen - 16 en Joan Cevallos
# Procesando imaegen - 17 en Joan Cevallos
# Procesando imaegen - 18 en Joan Cevallos
# Procesando imaegen - 19 en Joan Cevallos
# Procesando imaegen - 20 en Joan Cevallos
# Procesando imaegen - 21 en Joan Cevallos
# Procesando imaegen - 22 en Joan Cevallos
# Procesando imaegen - 23 en Joan Cevallos
# Procesando imaegen - 24 en Joan Cevallos
# Procesando imaegen - 25 en Joan Cevallos
# Procesando imaegen - 26 en Joan Cevallos
# Procesando imaegen - 27 en Joan Cevallos
# Procesando imaegen - 28 en Joan Cevallos
# Procesando imaegen - 29 en Joan Cevallos
# Procesando imaegen - 30 en Joan Cevallos
# Procesando imaegen - 31 en Joan Cevallos
# Procesando imaegen - 32 en Joan Cevallos
# Procesando imaegen - 33 en Joan Cevallos
# Procesando imaegen - 34 en Joan Cevallos
# Procesando imaegen - 35 en Joan Cevallos
# Procesando imaegen - 36 en Joan Cevallos
# Procesando imaegen - 37 en Joan Cevallos
# Procesando imaegen - 38 en Joan Cevallos
# Procesando imaegen - 39 en Joan Cevallos
# Procesando imaegen - 40 en Joan Cevallos
# Procesando imaegen - 41 en Joan Cevallos
# Procesando imaegen - 42 en Joan Cevallos
# Procesando imaegen - 43 en Joan Cevallos
# Procesando imaegen - 44 en Joan Cevallos
# Procesando imaegen - 45 en Joan Cevallos
# Procesando imaegen - 46 en Joan Cevallos
# Procesando imaegen - 47 en Joan Cevallos
# Procesando imaegen - 48 en Joan Cevallos
# Procesando imaegen - 49 en Joan Cevallos
# Procesando imaegen - 50 en Joan Cevallos
# Procesando imaegen - 51 en Joan Cevallos
# Procesando imaegen - 52 en Joan Cevallos
# Procesando imaegen - 53 en Joan Cevallos
# Procesando imaegen - 54 en Joan Cevallos
# Procesando imaegen - 55 en Joan Cevallos
# Procesando imaegen - 56 en Joan Cevallos
# Procesando imaegen - 57 en Joan Cevallos
# Procesando imaegen - 58 en Joan Cevallos
# Procesando imaegen - 59 en Joan Cevallos
# Procesando imaegen - 60 en Joan Cevallos
# Procesando imaegen - 61 en Joan Cevallos
# Procesando imaegen - 62 en Joan Cevallos
# Procesando imaegen - 63 en Joan Cevallos
# Procesando imaegen - 64 en Joan Cevallos
# Procesando imaegen - 65 en Joan Cevallos
# Procesando imaegen - 66 en Joan Cevallos
# Procesando imaegen - 67 en Joan Cevallos
# Procesando imaegen - 68 en Joan Cevallos
# Procesando imaegen - 69 en Joan Cevallos
# Procesando imaegen - 70 en Joan Cevallos
# Procesando imaegen - 71 en Joan Cevallos
# Procesando imaegen - 72 en Joan Cevallos
# Procesando imaegen - 73 en Joan Cevallos
# Procesando imaegen - 74 en Joan Cevallos
# Procesando imaegen - 75 en Joan Cevallos
# Procesando imaegen - 76 en Joan Cevallos
# Procesando imaegen - 77 en Joan Cevallos
# Procesando imaegen - 78 en Joan Cevallos
# Procesando imaegen - 79 en Joan Cevallos
# Procesando imaegen - 80 en Joan Cevallos
# Procesando imaegen - 81 en Joan Cevallos
# Procesando imaegen - 82 en Joan Cevallos
# Procesando imaegen - 83 en Joan Cevallos
# Procesando imaegen - 84 en Joan Cevallos
# Procesando imaegen - 85 en Joan Cevallos
# Procesando imaegen - 86 en Joan Cevallos
# Procesando imaegen - 87 en Joan Cevallos
# Procesando imaegen - 88 en Joan Cevallos
# Procesando imaegen - 89 en Joan Cevallos
# Procesando imaegen - 90 en Joan Cevallos
# Procesando imaegen - 91 en Joan Cevallos
# Procesando imaegen - 92 en Joan Cevallos
# Procesando imaegen - 93 en Joan Cevallos
# Procesando imaegen - 94 en Joan Cevallos
# Procesando imaegen - 95 en Joan Cevallos
# Procesando imaegen - 96 en Joan Cevallos
# Procesando imaegen - 97 en Joan Cevallos
# Procesando imaegen - 98 en Joan Cevallos
# Procesando imaegen - 99 en Joan Cevallos
# Procesando imaegen - 1 en Johana Salazar
# Procesando imaegen - 2 en Johana Salazar
# Procesando imaegen - 3 en Johana Salazar
# Procesando imaegen - 4 en Johana Salazar
# Procesando imaegen - 5 en Johana Salazar
# Procesando imaegen - 6 en Johana Salazar
# Procesando imaegen - 7 en Johana Salazar
# Procesando imaegen - 8 en Johana Salazar
# Procesando imaegen - 9 en Johana Salazar
# Procesando imaegen - 10 en Johana Salazar
# Procesando imaegen - 11 en Johana Salazar
# Procesando imaegen - 12 en Johana Salazar
# Procesando imaegen - 13 en Johana Salazar
# Procesando imaegen - 14 en Johana Salazar
# Procesando imaegen - 15 en Johana Salazar
# Procesando imaegen - 16 en Johana Salazar
# Procesando imaegen - 17 en Johana Salazar
# Procesando imaegen - 18 en Johana Salazar
# Procesando imaegen - 19 en Johana Salazar
# Procesando imaegen - 20 en Johana Salazar
# Procesando imaegen - 21 en Johana Salazar
# Procesando imaegen - 22 en Johana Salazar
# Procesando imaegen - 23 en Johana Salazar
# Procesando imaegen - 24 en Johana Salazar
# Procesando imaegen - 25 en Johana Salazar
# Procesando imaegen - 26 en Johana Salazar
# Procesando imaegen - 27 en Johana Salazar
# Procesando imaegen - 28 en Johana Salazar
# Procesando imaegen - 29 en Johana Salazar
# Procesando imaegen - 30 en Johana Salazar
# Procesando imaegen - 31 en Johana Salazar
# Procesando imaegen - 32 en Johana Salazar
# Procesando imaegen - 33 en Johana Salazar
# Procesando imaegen - 34 en Johana Salazar
# Procesando imaegen - 35 en Johana Salazar
# Procesando imaegen - 36 en Johana Salazar
# Procesando imaegen - 37 en Johana Salazar
# Procesando imaegen - 38 en Johana Salazar
# Procesando imaegen - 39 en Johana Salazar
# Procesando imaegen - 40 en Johana Salazar
# Procesando imaegen - 41 en Johana Salazar
# Procesando imaegen - 42 en Johana Salazar
# Procesando imaegen - 43 en Johana Salazar
# Procesando imaegen - 44 en Johana Salazar
# Procesando imaegen - 45 en Johana Salazar
# Procesando imaegen - 46 en Johana Salazar
# Procesando imaegen - 47 en Johana Salazar
# Procesando imaegen - 48 en Johana Salazar
# Procesando imaegen - 49 en Johana Salazar
# Procesando imaegen - 50 en Johana Salazar
# Procesando imaegen - 51 en Johana Salazar
# Procesando imaegen - 52 en Johana Salazar
# Procesando imaegen - 53 en Johana Salazar
# Procesando imaegen - 54 en Johana Salazar
# Procesando imaegen - 55 en Johana Salazar
# Procesando imaegen - 56 en Johana Salazar
# Procesando imaegen - 57 en Johana Salazar
# Procesando imaegen - 58 en Johana Salazar
# Procesando imaegen - 59 en Johana Salazar
# Procesando imaegen - 60 en Johana Salazar
# Procesando imaegen - 61 en Johana Salazar
# Procesando imaegen - 62 en Johana Salazar
# Procesando imaegen - 63 en Johana Salazar
# Procesando imaegen - 64 en Johana Salazar
# Procesando imaegen - 65 en Johana Salazar
# Procesando imaegen - 66 en Johana Salazar
# Procesando imaegen - 67 en Johana Salazar
# Procesando imaegen - 68 en Johana Salazar
# Procesando imaegen - 69 en Johana Salazar
# Procesando imaegen - 70 en Johana Salazar
# Procesando imaegen - 71 en Johana Salazar
# Procesando imaegen - 72 en Johana Salazar
# Procesando imaegen - 73 en Johana Salazar
# Procesando imaegen - 74 en Johana Salazar
# Procesando imaegen - 75 en Johana Salazar
# Procesando imaegen - 76 en Johana Salazar
# Procesando imaegen - 77 en Johana Salazar
# Procesando imaegen - 78 en Johana Salazar
# Procesando imaegen - 79 en Johana Salazar
# Procesando imaegen - 80 en Johana Salazar
# Procesando imaegen - 81 en Johana Salazar
# Procesando imaegen - 82 en Johana Salazar
# Procesando imaegen - 83 en Johana Salazar
# Procesando imaegen - 84 en Johana Salazar
# Procesando imaegen - 85 en Johana Salazar
# Procesando imaegen - 86 en Johana Salazar
# Procesando imaegen - 87 en Johana Salazar
# Procesando imaegen - 1 en Jordan Espinosa
# Procesando imaegen - 2 en Jordan Espinosa
# Procesando imaegen - 3 en Jordan Espinosa
# Procesando imaegen - 4 en Jordan Espinosa
# Procesando imaegen - 5 en Jordan Espinosa
# Procesando imaegen - 6 en Jordan Espinosa
# Procesando imaegen - 7 en Jordan Espinosa
# Procesando imaegen - 72 en Jordan Espinosa
# Procesando imaegen - 73 en Jordan Espinosa
# Procesando imaegen - 74 en Jordan Espinosa
# Procesando imaegen - 75 en Jordan Espinosa
# Procesando imaegen - 76 en Jordan Espinosa
# Procesando imaegen - 77 en Jordan Espinosa
# Procesando imaegen - 78 en Jordan Espinosa
# Procesando imaegen - 79 en Jordan Espinosa
# Procesando imaegen - 80 en Jordan Espinosa
# Procesando imaegen - 81 en Jordan Espinosa
# Procesando imaegen - 82 en Jordan Espinosa
# Procesando imaegen - 83 en Jordan Espinosa
# Procesando imaegen - 84 en Jordan Espinosa
# Procesando imaegen - 85 en Jordan Espinosa
# Procesando imaegen - 86 en Jordan Espinosa
# Procesando imaegen - 87 en Jordan Espinosa
# Procesando imaegen - 88 en Jordan Espinosa
# Procesando imaegen - 1 en Jorge Borrero
# Procesando imaegen - 2 en Jorge Borrero
# Procesando imaegen - 3 en Jorge Borrero
# Procesando imaegen - 4 en Jorge Borrero
# Procesando imaegen - 5 en Jorge Borrero
# ...
# Procesando imaegen - 36 en Selena Enriquez
# Procesando imaegen - 37 en Selena Enriquez
# Procesando imaegen - 38 en Selena Enriquez
# Procesando imaegen - 39 en Selena Enriquez
# Procesando imaegen - 40 en Selena Enriquez
# Procesando imaegen - 41 en Selena Enriquez
# Procesando imaegen - 42 en Selena Enriquez
# Procesando imaegen - 43 en Selena Enriquez
# Procesando imaegen - 44 en Selena Enriquez
# Procesando imaegen - 45 en Selena Enriquez
# Procesando imaegen - 46 en Selena Enriquez
# Procesando imaegen - 47 en Selena Enriquez
# Procesando imaegen - 48 en Selena Enriquez
# Procesando imaegen - 49 en Selena Enriquez
# Procesando imaegen - 50 en Selena Enriquez
# Procesando imaegen - 51 en Selena Enriquez
# Procesando imaegen - 52 en Selena Enriquez
# Procesando imaegen - 53 en Selena Enriquez
# Procesando imaegen - 54 en Selena Enriquez
# Procesando imaegen - 55 en Selena Enriquez
# Procesando imaegen - 56 en Selena Enriquez
# Procesando imaegen - 57 en Selena Enriquez
# Procesando imaegen - 58 en Selena Enriquez
# Procesando imaegen - 59 en Selena Enriquez
# Procesando imaegen - 60 en Selena Enriquez
# Procesando imaegen - 61 en Selena Enriquez
# Procesando imaegen - 62 en Selena Enriquez
# Procesando imaegen - 63 en Selena Enriquez
# Procesando imaegen - 64 en Selena Enriquez
# Procesando imaegen - 65 en Selena Enriquez
# Procesando imaegen - 66 en Selena Enriquez
# Procesando imaegen - 67 en Selena Enriquez
# Procesando imaegen - 68 en Selena Enriquez
# Procesando imaegen - 69 en Selena Enriquez
# Procesando imaegen - 70 en Selena Enriquez
# Procesando imaegen - 71 en Selena Enriquez
# Procesando imaegen - 72 en Selena Enriquez
# Procesando imaegen - 73 en Selena Enriquez
# Procesando imaegen - 74 en Selena Enriquez
# Procesando imaegen - 75 en Selena Enriquez
# Procesando imaegen - 76 en Selena Enriquez
# Procesando imaegen - 77 en Selena Enriquez
# Procesando imaegen - 78 en Selena Enriquez
# Procesando imaegen - 79 en Selena Enriquez
# Procesando imaegen - 80 en Selena Enriquez
# Procesando imaegen - 81 en Selena Enriquez
# Procesando imaegen - 82 en Selena Enriquez
# Procesando imaegen - 83 en Selena Enriquez
# Procesando imaegen - 84 en Selena Enriquez
# Procesando imaegen - 85 en Selena Enriquez
# Procesando imaegen - 86 en Selena Enriquez
# Procesando imaegen - 87 en Selena Enriquez
# Procesando imaegen - 88 en Selena Enriquez
# Procesando imaegen - 1 en Selena Rivas
# Procesando imaegen - 2 en Selena Rivas
# Procesando imaegen - 3 en Selena Rivas
# Procesando imaegen - 4 en Selena Rivas
# Procesando imaegen - 5 en Selena Rivas
# Procesando imaegen - 6 en Selena Rivas
# Procesando imaegen - 7 en Selena Rivas
# Procesando imaegen - 8 en Selena Rivas
# Procesando imaegen - 9 en Selena Rivas
# Procesando imaegen - 10 en Selena Rivas
# Procesando imaegen - 11 en Selena Rivas
# Procesando imaegen - 12 en Selena Rivas
# Procesando imaegen - 13 en Selena Rivas
# Procesando imaegen - 14 en Selena Rivas
# Procesando imaegen - 15 en Selena Rivas
# Procesando imaegen - 16 en Selena Rivas
# Procesando imaegen - 17 en Selena Rivas
# Procesando imaegen - 18 en Selena Rivas
# Procesando imaegen - 19 en Selena Rivas
# Procesando imaegen - 20 en Selena Rivas
# Procesando imaegen - 21 en Selena Rivas
# Procesando imaegen - 22 en Selena Rivas
# Procesando imaegen - 23 en Selena Rivas
# Procesando imaegen - 24 en Selena Rivas
# Procesando imaegen - 25 en Selena Rivas
# Procesando imaegen - 26 en Selena Rivas
# Procesando imaegen - 27 en Selena Rivas
# Procesando imaegen - 28 en Selena Rivas
# Procesando imaegen - 29 en Selena Rivas
# Procesando imaegen - 30 en Selena Rivas
# Procesando imaegen - 31 en Selena Rivas
# Procesando imaegen - 32 en Selena Rivas
# Procesando imaegen - 33 en Selena Rivas
# Procesando imaegen - 34 en Selena Rivas
# Procesando imaegen - 35 en Selena Rivas
# Procesando imaegen - 36 en Selena Rivas
# Procesando imaegen - 37 en Selena Rivas
# Procesando imaegen - 38 en Selena Rivas
# Procesando imaegen - 39 en Selena Rivas
# Procesando imaegen - 40 en Selena Rivas
# Procesando imaegen - 41 en Selena Rivas
# Procesando imaegen - 42 en Selena Rivas
# Procesando imaegen - 43 en Selena Rivas
# Procesando imaegen - 44 en Selena Rivas
# Procesando imaegen - 45 en Selena Rivas
# Procesando imaegen - 46 en Selena Rivas
# Procesando imaegen - 47 en Selena Rivas
# Procesando imaegen - 48 en Selena Rivas
# Procesando imaegen - 49 en Selena Rivas
# Procesando imaegen - 50 en Selena Rivas
# Procesando imaegen - 51 en Selena Rivas
# Procesando imaegen - 52 en Selena Rivas
# Procesando imaegen - 53 en Selena Rivas
# Procesando imaegen - 54 en Selena Rivas
# Procesando imaegen - 55 en Selena Rivas
# Procesando imaegen - 56 en Selena Rivas
# Procesando imaegen - 57 en Selena Rivas
# Procesando imaegen - 58 en Selena Rivas
# Procesando imaegen - 59 en Selena Rivas
# Procesando imaegen - 60 en Selena Rivas
# Procesando imaegen - 61 en Selena Rivas
# Procesando imaegen - 62 en Selena Rivas
# Procesando imaegen - 63 en Selena Rivas
# Procesando imaegen - 64 en Selena Rivas
# Procesando imaegen - 65 en Selena Rivas
# Procesando imaegen - 66 en Selena Rivas
# Procesando imaegen - 67 en Selena Rivas
# Procesando imaegen - 68 en Selena Rivas
# Procesando imaegen - 69 en Selena Rivas
# Procesando imaegen - 70 en Selena Rivas
# Procesando imaegen - 71 en Selena Rivas
# Procesando imaegen - 72 en Selena Rivas
# Procesando imaegen - 73 en Selena Rivas
# Procesando imaegen - 74 en Selena Rivas
# Procesando imaegen - 75 en Selena Rivas
# Procesando imaegen - 76 en Selena Rivas
# Procesando imaegen - 77 en Selena Rivas
# Procesando imaegen - 78 en Selena Rivas
# Procesando imaegen - 79 en Selena Rivas
# Procesando imaegen - 80 en Selena Rivas
# Procesando imaegen - 81 en Selena Rivas
# Procesando imaegen - 82 en Selena Rivas
# Procesando imaegen - 83 en Selena Rivas
# Procesando imaegen - 84 en Selena Rivas
# Procesando imaegen - 85 en Selena Rivas
# Procesando imaegen - 86 en Selena Rivas
# Procesando imaegen - 87 en Selena Rivas
# Procesando imaegen - 88 en Selena Rivas
# Procesando imaegen - 89 en Selena Rivas
# Procesando imaegen - 90 en Selena Rivas
# Procesando imaegen - 91 en Selena Rivas
# Procesando imaegen - 92 en Selena Rivas
# Procesando imaegen - 93 en Selena Rivas
# Procesando imaegen - 94 en Selena Rivas
# Procesando imaegen - 95 en Selena Rivas
# Procesando imaegen - 96 en Selena Rivas
# Procesando imaegen - 97 en Selena Rivas
# Procesando imaegen - 98 en Selena Rivas
# Procesando imaegen - 99 en Selena Rivas
# Procesando imaegen - 100 en Selena Rivas
# Procesando imaegen - 101 en Selena Rivas
# Procesando imaegen - 102 en Selena Rivas
# Procesando imaegen - 103 en Selena Rivas
# Procesando imaegen - 104 en Selena Rivas
# Procesando imaegen - 105 en Selena Rivas
# Procesando imaegen - 106 en Selena Rivas
# Procesando imaegen - 107 en Selena Rivas
# Procesando imaegen - 108 en Selena Rivas
# Procesando imaegen - 109 en Selena Rivas
# Procesando imaegen - 110 en Selena Rivas
# Procesando imaegen - 111 en Selena Rivas
# Procesando imaegen - 112 en Selena Rivas
# Procesando imaegen - 113 en Selena Rivas
# Procesando imaegen - 114 en Selena Rivas
# Procesando imaegen - 115 en Selena Rivas
# Procesando imaegen - 116 en Selena Rivas
# Procesando imaegen - 117 en Selena Rivas
# Procesando imaegen - 118 en Selena Rivas
# Procesando imaegen - 119 en Selena Rivas
# Procesando imaegen - 1 en Solano Wilmer
# Procesando imaegen - 2 en Solano Wilmer
# Procesando imaegen - 3 en Solano Wilmer
# Procesando imaegen - 4 en Solano Wilmer
# Procesando imaegen - 5 en Solano Wilmer
# Procesando imaegen - 6 en Solano Wilmer
# Procesando imaegen - 7 en Solano Wilmer
# Procesando imaegen - 8 en Solano Wilmer
# Procesando imaegen - 9 en Solano Wilmer
# Procesando imaegen - 10 en Solano Wilmer
# Procesando imaegen - 11 en Solano Wilmer
# Procesando imaegen - 12 en Solano Wilmer
# Procesando imaegen - 13 en Solano Wilmer
# Procesando imaegen - 14 en Solano Wilmer
# Procesando imaegen - 15 en Solano Wilmer
# Procesando imaegen - 16 en Solano Wilmer
# Procesando imaegen - 17 en Solano Wilmer
# Procesando imaegen - 18 en Solano Wilmer
# Procesando imaegen - 19 en Solano Wilmer
# Procesando imaegen - 20 en Solano Wilmer
# Procesando imaegen - 21 en Solano Wilmer
# Procesando imaegen - 22 en Solano Wilmer
# Procesando imaegen - 23 en Solano Wilmer
# Procesando imaegen - 24 en Solano Wilmer
# Procesando imaegen - 25 en Solano Wilmer
# Procesando imaegen - 26 en Solano Wilmer
# Procesando imaegen - 27 en Solano Wilmer
# Procesando imaegen - 28 en Solano Wilmer
# Procesando imaegen - 29 en Solano Wilmer
# Procesando imaegen - 30 en Solano Wilmer
# Procesando imaegen - 31 en Solano Wilmer
# Procesando imaegen - 32 en Solano Wilmer
# Procesando imaegen - 33 en Solano Wilmer
# Procesando imaegen - 34 en Solano Wilmer
# Procesando imaegen - 35 en Solano Wilmer
# Procesando imaegen - 36 en Solano Wilmer
# Procesando imaegen - 37 en Solano Wilmer
# Procesando imaegen - 38 en Solano Wilmer
# Procesando imaegen - 39 en Solano Wilmer
# Procesando imaegen - 40 en Solano Wilmer
# Procesando imaegen - 41 en Solano Wilmer
# Procesando imaegen - 42 en Solano Wilmer
# Procesando imaegen - 43 en Solano Wilmer
# Procesando imaegen - 44 en Solano Wilmer
# Procesando imaegen - 45 en Solano Wilmer
# Procesando imaegen - 46 en Solano Wilmer
# Procesando imaegen - 47 en Solano Wilmer
# Procesando imaegen - 48 en Solano Wilmer
# Procesando imaegen - 49 en Solano Wilmer
# Procesando imaegen - 50 en Solano Wilmer
# Procesando imaegen - 51 en Solano Wilmer
# Procesando imaegen - 52 en Solano Wilmer
# Procesando imaegen - 53 en Solano Wilmer
# Procesando imaegen - 54 en Solano Wilmer
# Procesando imaegen - 55 en Solano Wilmer
# Procesando imaegen - 1 en Steven Barragan
# Procesando imaegen - 2 en Steven Barragan
# Procesando imaegen - 3 en Steven Barragan
# Procesando imaegen - 4 en Steven Barragan
# Procesando imaegen - 5 en Steven Barragan
# Procesando imaegen - 6 en Steven Barragan
# Procesando imaegen - 7 en Steven Barragan
# Procesando imaegen - 8 en Steven Barragan
# Procesando imaegen - 9 en Steven Barragan
# Procesando imaegen - 10 en Steven Barragan
# Procesando imaegen - 11 en Steven Barragan
# Procesando imaegen - 12 en Steven Barragan
# Procesando imaegen - 13 en Steven Barragan
# Procesando imaegen - 14 en Steven Barragan
# Procesando imaegen - 15 en Steven Barragan
# Procesando imaegen - 16 en Steven Barragan
# Procesando imaegen - 17 en Steven Barragan
# Procesando imaegen - 18 en Steven Barragan
# Procesando imaegen - 19 en Steven Barragan
# Procesando imaegen - 20 en Steven Barragan
# Procesando imaegen - 21 en Steven Barragan
# Procesando imaegen - 22 en Steven Barragan
# Procesando imaegen - 23 en Steven Barragan
# Procesando imaegen - 24 en Steven Barragan
# Procesando imaegen - 25 en Steven Barragan
# Procesando imaegen - 26 en Steven Barragan
# Procesando imaegen - 27 en Steven Barragan
# Procesando imaegen - 28 en Steven Barragan
# Procesando imaegen - 29 en Steven Barragan
# Procesando imaegen - 30 en Steven Barragan
# Procesando imaegen - 31 en Steven Barragan
# Procesando imaegen - 32 en Steven Barragan
# Procesando imaegen - 33 en Steven Barragan
# Procesando imaegen - 34 en Steven Barragan
# Procesando imaegen - 35 en Steven Barragan
# Procesando imaegen - 36 en Steven Barragan
# Procesando imaegen - 37 en Steven Barragan
# Procesando imaegen - 38 en Steven Barragan
# Procesando imaegen - 39 en Steven Barragan
# Procesando imaegen - 40 en Steven Barragan
# Procesando imaegen - 41 en Steven Barragan
# Procesando imaegen - 42 en Steven Barragan
# Procesando imaegen - 43 en Steven Barragan
# Procesando imaegen - 44 en Steven Barragan
# Procesando imaegen - 45 en Steven Barragan
# Procesando imaegen - 46 en Steven Barragan
# Procesando imaegen - 47 en Steven Barragan
# Procesando imaegen - 48 en Steven Barragan
# Procesando imaegen - 49 en Steven Barragan
# Procesando imaegen - 50 en Steven Barragan
# Procesando imaegen - 51 en Steven Barragan
# Procesando imaegen - 52 en Steven Barragan
# Procesando imaegen - 53 en Steven Barragan
# Procesando imaegen - 54 en Steven Barragan
# Procesando imaegen - 55 en Steven Barragan
# Procesando imaegen - 56 en Steven Barragan
# Procesando imaegen - 57 en Steven Barragan
# Procesando imaegen - 58 en Steven Barragan
# Procesando imaegen - 59 en Steven Barragan
# Procesando imaegen - 60 en Steven Barragan
# Procesando imaegen - 61 en Steven Barragan
# Procesando imaegen - 62 en Steven Barragan
# Procesando imaegen - 63 en Steven Barragan
# Procesando imaegen - 64 en Steven Barragan
# Procesando imaegen - 65 en Steven Barragan
# Procesando imaegen - 66 en Steven Barragan
# Procesando imaegen - 67 en Steven Barragan
# Procesando imaegen - 68 en Steven Barragan
# Procesando imaegen - 69 en Steven Barragan
# Procesando imaegen - 70 en Steven Barragan
# Procesando imaegen - 71 en Steven Barragan
# Procesando imaegen - 72 en Steven Barragan
# Procesando imaegen - 73 en Steven Barragan
# Procesando imaegen - 74 en Steven Barragan
# Procesando imaegen - 75 en Steven Barragan
# Procesando imaegen - 76 en Steven Barragan
# Procesando imaegen - 77 en Steven Barragan
# Procesando imaegen - 78 en Steven Barragan
# Procesando imaegen - 79 en Steven Barragan
# Procesando imaegen - 80 en Steven Barragan
# Procesando imaegen - 81 en Steven Barragan
# Procesando imaegen - 82 en Steven Barragan
# Procesando imaegen - 83 en Steven Barragan
# Procesando imaegen - 84 en Steven Barragan
# Procesando imaegen - 85 en Steven Barragan
# Procesando imaegen - 86 en Steven Barragan
# Procesando imaegen - 87 en Steven Barragan
# Procesando imaegen - 88 en Steven Barragan
# Procesando imaegen - 89 en Steven Barragan
# Procesando imaegen - 90 en Steven Barragan
# Procesando imaegen - 91 en Steven Barragan
# Procesando imaegen - 92 en Steven Barragan
# Procesando imaegen - 93 en Steven Barragan
# Procesando imaegen - 94 en Steven Barragan
# Procesando imaegen - 95 en Steven Barragan
# Procesando imaegen - 96 en Steven Barragan
# Procesando imaegen - 97 en Steven Barragan
# Procesando imaegen - 98 en Steven Barragan
# Procesando imaegen - 99 en Steven Barragan
# Procesando imaegen - 100 en Steven Barragan
# Procesando imaegen - 101 en Steven Barragan
# Procesando imaegen - 102 en Steven Barragan
# Procesando imaegen - 103 en Steven Barragan
# Procesando imaegen - 104 en Steven Barragan
# Procesando imaegen - 105 en Steven Barragan
# Procesando imaegen - 106 en Steven Barragan
# Procesando imaegen - 107 en Steven Barragan
# Procesando imaegen - 108 en Steven Barragan
# Procesando imaegen - 109 en Steven Barragan
# Procesando imaegen - 110 en Steven Barragan
# Procesando imaegen - 111 en Steven Barragan
# Procesando imaegen - 112 en Steven Barragan
# Procesando imaegen - 113 en Steven Barragan
# Procesando imaegen - 114 en Steven Barragan
# Procesando imaegen - 115 en Steven Barragan
# Procesando imaegen - 116 en Steven Barragan
# Procesando imaegen - 117 en Steven Barragan
# Procesando imaegen - 118 en Steven Barragan
# Procesando imaegen - 119 en Steven Barragan
# Procesando imaegen - 120 en Steven Barragan
# Procesando imaegen - 121 en Steven Barragan
# Procesando imaegen - 122 en Steven Barragan
# Procesando imaegen - 123 en Steven Barragan
# Procesando imaegen - 124 en Steven Barragan
# Procesando imaegen - 125 en Steven Barragan
# Procesando imaegen - 126 en Steven Barragan
# Procesando imaegen - 127 en Steven Barragan
# Procesando imaegen - 128 en Steven Barragan
# Procesando imaegen - 129 en Steven Barragan
# Procesando imaegen - 130 en Steven Barragan
# Procesando imaegen - 131 en Steven Barragan
# Procesando imaegen - 132 en Steven Barragan
# Procesando imaegen - 133 en Steven Barragan
# Procesando imaegen - 134 en Steven Barragan
# Procesando imaegen - 135 en Steven Barragan
# Procesando imaegen - 136 en Steven Barragan
# Procesando imaegen - 137 en Steven Barragan
# Procesando imaegen - 138 en Steven Barragan
# Procesando imaegen - 139 en Steven Barragan
# Procesando imaegen - 140 en Steven Barragan
# Procesando imaegen - 141 en Steven Barragan
# Procesando imaegen - 142 en Steven Barragan
# Procesando imaegen - 143 en Steven Barragan
# Procesando imaegen - 144 en Steven Barragan
# Procesando imaegen - 145 en Steven Barragan
# Procesando imaegen - 146 en Steven Barragan
# Procesando imaegen - 147 en Steven Barragan
# Procesando imaegen - 148 en Steven Barragan
# Procesando imaegen - 149 en Steven Barragan
# Procesando imaegen - 150 en Steven Barragan
# Procesando imaegen - 151 en Steven Barragan
# Procesando imaegen - 152 en Steven Barragan
# Procesando imaegen - 153 en Steven Barragan
# Procesando imaegen - 154 en Steven Barragan

# %%
'''Se establece la ruta que contiene a las clases del dataset a usar'''
ruta_imagenes = "./Estudiantes_datos_fondoEliminadoNLM"
'''Se llama al método para cargar las imágenes de la ruta'''
cargarImagenes(ruta_imagenes)

# %% [markdown]
# ### Después de eliminar datos sucios

# %%
cargarImagenes(ruta_imagenes)
